# %% [markdown]
# # Evaluation
#
# doing evaluation stuff here...

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from iclingo import Clingo, Model
import funcs
from funcs import BMDataFormat, AccumulatedStats
import matplotlib.pyplot as plt
import numpy as np
import os
import files
import glob
import json

# %%
#create a data frame
benchmarks = funcs.getAllBenchmarks('../benchmarks')
cols = ['total','ground','solve']
rows = ['BM{}'.format(i+1) for i, bm in enumerate(benchmarks)]
dct = {}
for c in cols:
    dct[c] = [0.0]*len(rows)
df = pd.DataFrame(dct, index=rows)

# %%
# reading json benchmark data
def readJSONs(path):
    files = glob.glob(path)
    bmdfs = []
    for file in files:
        bmdfs.append(BMDataFormat())
        bmdfs[-1].load(file)
    return bmdfs
bmdfs = readJSONs("../benchmark_data/*det*/*.json")

# %%
# insert benchmark data into data frame
for bmdf in bmdfs:
    df.loc[df.index[int(bmdf.data['instance'][0:2])-1]] = [
                  bmdf.data['statistics']['total'],
                  bmdf.data['statistics']['groundingTime'],
                  bmdf.data['statistics']['solvingTime']
                 ]
#df.to_csv('../benchmark_data/det_approach/det_approach.csv')
df
# Out:
#          total    ground     solve
# BM1   0.021969  0.021969  0.000000
# BM2   0.033909  0.030918  0.002991
# BM3   0.020945  0.018950  0.001995
# BM4   0.000000  0.000000  0.000000
# BM5   0.017950  0.017950  0.000000
# BM6   0.020945  0.019947  0.000998
# BM7   0.020945  0.019945  0.000999
# BM8   0.034908  0.033909  0.000999
# BM9   0.027920  0.026922  0.000998
# BM10  0.025938  0.023943  0.001995
# BM11  0.021942  0.020945  0.000998
# BM12  0.023937  0.022938  0.000999
# BM13  0.358728  0.314840  0.043888
# BM14  0.711729  0.299833  0.411896
# BM15  0.022230  0.021233  0.000998
# BM16  0.033913  0.032934  0.000978
# BM17  0.033907  0.030914  0.002993
# BM18  0.029922  0.027929  0.001993
# BM19  0.043880  0.036898  0.006983
# BM20  0.074800  0.051863  0.022938
# BM21  0.037901  0.034908  0.002993
# BM22  3.358461  3.291176  0.067286
# BM23  0.487207  0.470253  0.016954
# BM24  0.074326  0.069324  0.005001
# BM25  1.412695  0.631762  0.780933
# BM26  1.770454  0.301662  1.468792

# %%
from merger import Merger
# initialize merger
merger = Merger("../encodings/sequential", "../benchmark_data")
def merge(benchmark_id):
        benchmark = benchmarks[benchmark_id-1]
        return merger.merge(benchmark, vizualize=False, save_data=False, deterministic_waiter=True, check_validity=True, automated=False)
        
def mergeAll(exclude=[22,23,26]):
    for i in range(len(benchmarks)):
        benchmark_id = i+1
        benchmark = benchmarks[i]
        if benchmark_id in exclude:
            continue
        print("################## {} ###################".format(benchmark))
        merger.merge(benchmark, vizualize=False, save_data=True, automated=False, deterministic_waiter=True, check_validity=True)

# %%
# test merging here
#m, _ = merger.merge(benchmarks[26-1], vizualize=True, save_data=False, automated=True, deterministic_waiter=True, check_validity=True)
#m.model
#s, _ = merger.retrieveBenchmarkMetrics(m)

#mergeAll([])
li = []
bm_id = 25
m,_ = merger.switchPlans(merger.getBenchmarkModel(benchmarks[bm_id-1]), small=True)
m,_ = merger.switchPlans(m, small=False)
for i in range(500):
    #m_, acc_stats = merger.fix_point_solve(m, merger.waiter_det_big, AccumulatedStats())
    #m, acc_stats = merger.fix_point_solve(m, merger.waiter_inc, acc_stats)
    #metrics, _ = merger.retrieveBenchmarkMetrics(m)
    #m, _ = merger.convertToAsprilo(m, benchmarks[bm_id-1])
    #m, _ = merger.checkValidity(m)
    #li.append(acc_stats.total)
    pass
li
# Out:
# Encoding: ../encodings/sequential\inputter.lp
# Satisfiable
# Total time: 0.046833038330078125 sec
# CPU time: 0.03125 sec
# Grounding time: 0.041996002197265625 sec
# Solving time: 0.0048370361328125 sec
# Atoms : 2238
# Rules : 2238
#
# Fix Point Solving Iteration: 1
# Encoding: ../encodings/sequential\merger_ps_small_final.lp
# Satisfiable
# Total time: 0.19963455200195312 sec
# CPU time: 0.171875 sec
# Grounding time: 0.037067413330078125 sec
# Solving time: 0.162567138671875 sec
# Atoms : 8465
# Rules : 9363
#
# Cost: [29, 562, 3, 0, 4]
#
# Fix Point Solving Iteration: 2
# Encoding: ../encodings/sequential\merger_ps_small_final.lp
# Satisfiable
# Total time: 0.06385231018066406 sec
# CPU time: 0.0625 sec
# Grounding time: 0.024951934814453125 sec
# Solving time: 0.03890037536621094 sec
# Atoms : 6732
# Rules : 7200
#
# Cost: [25, 546, 2, 0, 0]
#
# Fix Point Solving Iteration: 3
# Encoding: ../encodings/sequential\merger_ps_small_final.lp
# Satisfiable
# Total time: 0.0279541015625 sec
# CPU time: 0.015625 sec
# Grounding time: 0.019977569580078125 sec
# Solving time: 0.007976531982421875 sec
# Atoms : 5769
# Rules : 5933
#
# Cost: [25, 540, 1, 0]
#
# Fix Point Solving Iteration: 4
# Encoding: ../encodings/sequential\merger_ps_small_final.lp
# Satisfiable
# Total time: 0.02695465087890625 sec
# CPU time: 0.015625 sec
# Grounding time: 0.018949508666992188 sec
# Solving time: 0.008005142211914062 sec
# Atoms : 5505
# Rules : 5579
#
# Cost: [25, 538, 0, 0]
#
# Fix Point Solving Iteration: 5
# Encoding: ../encodings/sequential\merger_ps_small_final.lp
# Satisfiable
# Total time: 0.023935317993164062 sec
# CPU time: 0.03125 sec
# Grounding time: 0.018968582153320312 sec
# Solving time: 0.00496673583984375 sec
# Atoms : 5272
# Rules : 5273
#
# Cost: [25, 538]
#
# Fix Point Solving Iteration: 6
# Encoding: ../encodings/sequential\merger_ps_small_final.lp
# Satisfiable
# Total time: 0.022962570190429688 sec
# CPU time: 0.03125 sec
# Grounding time: 0.018978118896484375 sec
# Solving time: 0.0039844512939453125 sec
# Atoms : 5272
# Rules : 5273
#
# Cost: [25, 538]
#
# Fix Point Solving Iteration: 1
# Encoding: ../encodings/sequential\merger_ps_big_final.lp
# Satisfiable
# Total time: 0.6328620910644531 sec
# CPU time: 0.609375 sec
# Grounding time: 0.27428627014160156 sec
# Solving time: 0.35857582092285156 sec
# Atoms : 31713
# Rules : 66997
#
# Cost: [462, 22, 4]
#
# Fix Point Solving Iteration: 2
# Encoding: ../encodings/sequential\merger_ps_big_final.lp
# Satisfiable
# Total time: 0.10070991516113281 sec
# CPU time: 0.09375 sec
# Grounding time: 0.0339202880859375 sec
# Solving time: 0.06678962707519531 sec
# Atoms : 8144
# Rules : 10400
#
# Cost: [444, 8, 0, 2]
#
# Fix Point Solving Iteration: 3
# Encoding: ../encodings/sequential\merger_ps_big_final.lp
# Satisfiable
# Total time: 0.04490852355957031 sec
# CPU time: 0.03125 sec
# Grounding time: 0.019975662231445312 sec
# Solving time: 0.024932861328125 sec
# Atoms : 5428
# Rules : 6017
#
# Cost: [432, 2, 0, 1]
#
# Fix Point Solving Iteration: 4
# Encoding: ../encodings/sequential\merger_ps_big_final.lp
# Satisfiable
# Total time: 0.028949737548828125 sec
# CPU time: 0.03125 sec
# Grounding time: 0.015979766845703125 sec
# Solving time: 0.012969970703125 sec
# Atoms : 4127
# Rules : 4156
#
# Cost: [430, 0, 0, 0]
#
# Fix Point Solving Iteration: 5
# Encoding: ../encodings/sequential\merger_ps_big_final.lp
# Satisfiable
# Total time: 0.019937515258789062 sec
# CPU time: 0.015625 sec
# Grounding time: 0.016946792602539062 sec
# Solving time: 0.00299072265625 sec
# Atoms : 4030
# Rules : 4030
#
# Cost: [430]
#
# Fix Point Solving Iteration: 6
# Encoding: ../encodings/sequential\merger_ps_big_final.lp
# Satisfiable
# Total time: 0.01795196533203125 sec
# CPU time: 0.015625 sec
# Grounding time: 0.014959335327148438 sec
# Solving time: 0.0029926300048828125 sec
# Atoms : 4030
# Rules : 4030
#
# Cost: [430]
#
# Fix Point Solving Iteration: 1
# Encoding: ../encodings/sequential\merger_w_det_big_final.lp
# Satisfiable
# Total time: 0.016538619995117188 sec
# CPU time: 0.03125 sec
# Grounding time: 0.016538619995117188 sec
# Solving time: 0.0 sec
# Atoms : 4993
# Rules : 4619
#
# Cost: []
#
# Fix Point Solving Iteration: 2
# Encoding: ../encodings/sequential\merger_w_det_big_final.lp
# Satisfiable
# Total time: 0.03124237060546875 sec
# CPU time: 0.03125 sec
# Grounding time: 0.015653610229492188 sec
# Solving time: 0.015588760375976562 sec
# Atoms : 4494
# Rules : 4083
#
# Cost: []
#
# Fix Point Solving Iteration: 1
# Encoding: ../encodings/sequential\merger_w_det_big_final.lp
# Satisfiable
# Total time: 0.015653610229492188 sec
# CPU time: 0.015625 sec
# Grounding time: 0.015653610229492188 sec
# Solving time: 0.0 sec
# Atoms : 4993
# Rules : 4619
#
# Cost: []
#
# Fix Point Solving Iteration: 2
# Encoding: ../encodings/sequential\merger_w_det_big_final.lp
# Satisfiable
# Total time: 0.031244277954101562 sec
# CPU time: 0.03125 sec
# Grounding time: 0.031244277954101562 sec
# Solving time: 0.0 sec
# Atoms : 4494
# Rules : 4083
#
# Cost: []
#
# Fix Point Solving Iteration: 1
# Encoding: ../encodings/sequential\merger_w_det_big_final.lp
# Satisfiable
# Total time: 0.031209945678710938 sec
# CPU time: 0.03125 sec
# Grounding time: 0.031209945678710938 sec
# Solving time: 0.0 sec
# Atoms : 4993
# Rules : 4619
#
# Cost: []
#
# Fix Point Solving Iteration: 2
# Encoding: ../encodings/sequential\merger_w_det_big_final.lp
# Satisfiable
# Total time: 0.031276702880859375 sec
# CPU time: 0.03125 sec
# Grounding time: 0.015649795532226562 sec
# Solving time: 0.015626907348632812 sec
# Atoms : 4494
# Rules : 4083
#
# Cost: []
#
# Fix Point Solving Iteration: 1
# Encoding: ../encodings/sequential\merger_w_det_big_final.lp
# Satisfiable
# Total time: 0.025918960571289062 sec
# CPU time: 0.015625 sec
# Grounding time: 0.021921157836914062 sec
# Solving time: 0.003997802734375 sec
# Atoms : 4993
# Rules : 4619
#
# Cost: []
#
# Fix Point Solving Iteration: 2
# Encoding: ../encodings/sequential\merger_w_det_big_final.lp
# Satisfiable
# Total time: 0.020963668823242188 sec
# CPU time: 0.015625 sec
# Grounding time: 0.01796722412109375 sec
# Solving time: 0.0029964447021484375 sec
# Atoms : 4494
# Rules : 4083
#
# Cost: []
#
# Fix Point Solving Iteration: 1
# Encoding: ../encodings/sequential\merger_w_det_big_final.lp
# Satisfiable
# Total time: 0.019628524780273438 sec
# CPU time: 0.015625 sec
# Grounding time: 0.003971099853515625 sec
# Solving time: 0.015657424926757812 sec
# Atoms : 4993
# Rules : 4619
#
# Cost: []
#
# Fix Point Solving Iteration: 2
# Encoding: ../encodings/sequential\merger_w_det_big_final.lp
# Satisfiable
# Total time: 0.01561737060546875 sec
# CPU time: 0.015625 sec
# Grounding time: 0.01561737060546875 sec
# Solving time: 0.0 sec
# Atoms : 4494
# Rules : 4083
#
# Cost: []
#
# Fix Point Solving Iteration: 1
# Encoding: ../encodings/sequential\merger_w_det_big_final.lp
# Satisfiable
# Total time: 0.03121185302734375 sec
# CPU time: 0.03125 sec
# Grounding time: 0.03121185302734375 sec
# Solving time: 0.0 sec
# Atoms : 4993
# Rules : 4619
#
# Cost: []
#
# Fix Point Solving Iteration: 2
# Encoding: ../encodings/sequential\merger_w_det_big_final.lp
# Satisfiable
# Total time: 0.022937774658203125 sec
# CPU time: 0.015625 sec
# Grounding time: 0.018945693969726562 sec
# Solving time: 0.0039920806884765625 sec
# Atoms : 4494
# Rules : 4083
#
# Cost: []
#
# Fix Point Solving Iteration: 1
# Encoding: ../encodings/sequential\merger_w_det_big_final.lp
# Satisfiable
# Total time: 0.02495574951171875 sec
# CPU time: 0.03125 sec
# Grounding time: 0.020961761474609375 sec
# Solving time: 0.003993988037109375 sec
# Atoms : 4993
# Rules : 4619
#
# Cost: []
#
# Fix Point Solving Iteration: 2
# Encoding: ../encodings/sequential\merger_w_det_big_final.lp
# Satisfiable
# Total time: 0.021936416625976562 sec
# CPU time: 0.03125 sec
# Grounding time: 0.017940521240234375 sec
# Solving time: 0.0039958953857421875 sec
# Atoms : 4494
# Rules : 4083
#
# Cost: []
#
# Fix Point Solving Iteration: 1
# Encoding: ../encodings/sequential\merger_w_det_big_final.lp
# Satisfiable
# Total time: 0.024959564208984375 sec
# CPU time: 0.015625 sec
# Grounding time: 0.021940231323242188 sec
# Solving time: 0.0030193328857421875 sec
# Atoms : 4993
# Rules : 4619
#
# Cost: []
#
# Fix Point Solving Iteration: 2
# Encoding: ../encodings/sequential\merger_w_det_big_final.lp
# Satisfiable
# Total time: 0.022937774658203125 sec
# CPU time: 0.03125 sec
# Grounding time: 0.01894378662109375 sec
# Solving time: 0.003993988037109375 sec
# Atoms : 4494
# Rules : 4083
#
# Cost: []
#
# Fix Point Solving Iteration: 1
# Encoding: ../encodings/sequential\merger_w_det_big_final.lp
# Satisfiable
# Total time: 0.025928497314453125 sec
# CPU time: 0.03125 sec
# Grounding time: 0.022966384887695312 sec
# Solving time: 0.0029621124267578125 sec
# Atoms : 4993
# Rules : 4619
#
# Cost: []
#
# Fix Point Solving Iteration: 2
# Encoding: ../encodings/sequential\merger_w_det_big_final.lp
# Satisfiable
# Total time: 0.021945953369140625 sec
# CPU time: 0.015625 sec
# Grounding time: 0.018953323364257812 sec
# Solving time: 0.0029926300048828125 sec
# Atoms : 4494
# Rules : 4083
#
# Cost: []
#
# Fix Point Solving Iteration: 1
# Encoding: ../encodings/sequential\merger_w_det_big_final.lp
# Satisfiable
# Total time: 0.025928497314453125 sec
# CPU time: 0.03125 sec
# Grounding time: 0.021966934204101562 sec
# Solving time: 0.0039615631103515625 sec
# Atoms : 4993
# Rules : 4619
#
# Cost: []
#
# Fix Point Solving Iteration: 2
# Encoding: ../encodings/sequential\merger_w_det_big_final.lp
# Satisfiable
# Total time: 0.024944305419921875 sec
# CPU time: 0.03125 sec
# Grounding time: 0.02092742919921875 sec
# Solving time: 0.004016876220703125 sec
# Atoms : 4494
# Rules : 4083
#
# Cost: []
#
# Fix Point Solving Iteration: 1
# Encoding: ../encodings/sequential\merger_w_det_big_final.lp
# Satisfiable
# Total time: 0.025936126708984375 sec
# CPU time: 0.03125 sec
# Grounding time: 0.02194976806640625 sec
# Solving time: 0.003986358642578125 sec
# Atoms : 4993
# Rules : 4619
#
# Cost: []
#
# Fix Point Solving Iteration: 2
# Encoding: ../encodings/sequential\merger_w_det_big_final.lp
# Satisfiable
# Total time: 0.02292633056640625 sec
# CPU time: 0.015625 sec
# Grounding time: 0.018962860107421875 sec
# Solving time: 0.003963470458984375 sec
# Atoms : 4494
# Rules : 4083
#
# Cost: []
#
# Fix Point Solving Iteration: 1
# Encoding: ../encodings/sequential\merger_w_det_big_final.lp
# Satisfiable
# Total time: 0.0259246826171875 sec
# CPU time: 0.015625 sec
# Grounding time: 0.02291107177734375 sec
# Solving time: 0.00301361083984375 sec
# Atoms : 4993
# Rules : 4619
#
# Cost: []
#
# Fix Point Solving Iteration: 2
# Encoding: ../encodings/sequential\merger_w_det_big_final.lp
# Satisfiable
# Total time: 0.02397918701171875 sec
# CPU time: 0.03125 sec
# Grounding time: 0.020956039428710938 sec
# Solving time: 0.0030231475830078125 sec
# Atoms : 4494
# Rules : 4083
#
# Cost: []
#
# Fix Point Solving Iteration: 1
# Encoding: ../encodings/sequential\merger_w_det_big_final.lp
# Satisfiable
# Total time: 0.025960922241210938 sec
# CPU time: 0.03125 sec
# Grounding time: 0.021961212158203125 sec
# Solving time: 0.0039997100830078125 sec
# Atoms : 4993
# Rules : 4619
#
# Cost: []
#
# Fix Point Solving Iteration: 2
# Encoding: ../encodings/sequential\merger_w_det_big_final.lp
# Satisfiable
# Total time: 0.0229644775390625 sec
# CPU time: 0.03125 sec
# Grounding time: 0.019947052001953125 sec
# Solving time: 0.003017425537109375 sec
# Atoms : 4494
# Rules : 4083
#
# Cost: []
#
# Fix Point Solving Iteration: 1
# Encoding: ../encodings/sequential\merger_w_det_big_final.lp
# Satisfiable
# Total time: 0.023935317993164062 sec
# CPU time: 0.015625 sec
# Grounding time: 0.020944595336914062 sec
# Solving time: 0.00299072265625 sec
# Atoms : 4993
# Rules : 4619
#
# Cost: []
#
# Fix Point Solving Iteration: 2
# Encoding: ../encodings/sequential\merger_w_det_big_final.lp
# Satisfiable
# Total time: 0.020971298217773438 sec
# CPU time: 0.03125 sec
# Grounding time: 0.017978668212890625 sec
# Solving time: 0.0029926300048828125 sec
# Atoms : 4494
# Rules : 4083
#
# Cost: []
#
# Fix Point Solving Iteration: 1
# Encoding: ../encodings/sequential\merger_w_det_big_final.lp
# Satisfiable
# Total time: 0.024934768676757812 sec
# CPU time: 0.03125 sec
# Grounding time: 0.020944595336914062 sec
# Solving time: 0.00399017333984375 sec
# Atoms : 4993
# Rules : 4619
#
# Cost: []
#
# Fix Point Solving Iteration: 2
# Encoding: ../encodings/sequential\merger_w_det_big_final.lp
# Satisfiable
# Total time: 0.020944595336914062 sec
# CPU time: 0.015625 sec
# Grounding time: 0.01795196533203125 sec
# Solving time: 0.0029926300048828125 sec
# Atoms : 4494
# Rules : 4083
#
# Cost: []
#
# Fix Point Solving Iteration: 1
# Encoding: ../encodings/sequential\merger_w_det_big_final.lp
# Satisfiable
# Total time: 0.023937225341796875 sec
# CPU time: 0.03125 sec
# Grounding time: 0.02097320556640625 sec
# Solving time: 0.002964019775390625 sec
# Atoms : 4993
# Rules : 4619
#
# Cost: []
#
# Fix Point Solving Iteration: 2
# Encoding: ../encodings/sequential\merger_w_det_big_final.lp
# Satisfiable
# Total time: 0.020975112915039062 sec
# CPU time: 0.015625 sec
# Grounding time: 0.017972946166992188 sec
# Solving time: 0.003002166748046875 sec
# Atoms : 4494
# Rules : 4083
#
# Cost: []
#
# Fix Point Solving Iteration: 1
# Encoding: ../encodings/sequential\merger_w_det_big_final.lp
# Satisfiable
# Total time: 0.023937225341796875 sec
# CPU time: 0.015625 sec
# Grounding time: 0.019948959350585938 sec
# Solving time: 0.0039882659912109375 sec
# Atoms : 4993
# Rules : 4619
#
# Cost: []
#
# Fix Point Solving Iteration: 2
# Encoding: ../encodings/sequential\merger_w_det_big_final.lp
# Satisfiable
# Total time: 0.020977020263671875 sec
# CPU time: 0.03125 sec
# Grounding time: 0.017984390258789062 sec
# Solving time: 0.0029926300048828125 sec
# Atoms : 4494
# Rules : 4083
#
# Cost: []
#
# Fix Point Solving Iteration: 1
# Encoding: ../encodings/sequential\merger_w_det_big_final.lp
# Satisfiable
# Total time: 0.024961471557617188 sec
# CPU time: 0.015625 sec
# Grounding time: 0.020969390869140625 sec
# Solving time: 0.0039920806884765625 sec
# Atoms : 4993
# Rules : 4619
#
# Cost: []
#
# Fix Point Solving Iteration: 2
# Encoding: ../encodings/sequential\merger_w_det_big_final.lp
# Satisfiable
# Total time: 0.020971298217773438 sec
# CPU time: 0.03125 sec
# Grounding time: 0.017978668212890625 sec
# Solving time: 0.0029926300048828125 sec
# Atoms : 4494
# Rules : 4083
#
# Cost: []
#
# Fix Point Solving Iteration: 1
# Encoding: ../encodings/sequential\merger_w_det_big_final.lp
# Satisfiable
# Total time: 0.02496337890625 sec
# CPU time: 0.03125 sec
# Grounding time: 0.020965576171875 sec
# Solving time: 0.003997802734375 sec
# Atoms : 4993
# Rules : 4619
#
# Cost: []
#
# Fix Point Solving Iteration: 2
# Encoding: ../encodings/sequential\merger_w_det_big_final.lp
# Satisfiable
# Total time: 0.020944595336914062 sec
# CPU time: 0.015625 sec
# Grounding time: 0.017972946166992188 sec
# Solving time: 0.002971649169921875 sec
# Atoms : 4494
# Rules : 4083
#
# Cost: []
#
# Fix Point Solving Iteration: 1
# Encoding: ../encodings/sequential\merger_w_det_big_final.lp
# Satisfiable
# Total time: 0.024932861328125 sec
# CPU time: 0.03125 sec
# Grounding time: 0.02094268798828125 sec
# Solving time: 0.00399017333984375 sec
# Atoms : 4993
# Rules : 4619
#
# Cost: []
#
# Fix Point Solving Iteration: 2
# Encoding: ../encodings/sequential\merger_w_det_big_final.lp
# Satisfiable
# Total time: 0.020965576171875 sec
# CPU time: 0.015625 sec
# Grounding time: 0.01795196533203125 sec
# Solving time: 0.00301361083984375 sec
# Atoms : 4494
# Rules : 4083
#
# Cost: []
#
# Fix Point Solving Iteration: 1
# Encoding: ../encodings/sequential\merger_w_det_big_final.lp
# Satisfiable
# Total time: 0.024959564208984375 sec
# CPU time: 0.015625 sec
# Grounding time: 0.021966934204101562 sec
# Solving time: 0.0029926300048828125 sec
# Atoms : 4993
# Rules : 4619
#
# Cost: []
#
# Fix Point Solving Iteration: 2
# Encoding: ../encodings/sequential\merger_w_det_big_final.lp
# Satisfiable
# Total time: 0.021968841552734375 sec
# CPU time: 0.03125 sec
# Grounding time: 0.017978668212890625 sec
# Solving time: 0.00399017333984375 sec
# Atoms : 4494
# Rules : 4083
#
# Cost: []
#
# Fix Point Solving Iteration: 1
# Encoding: ../encodings/sequential\merger_w_det_big_final.lp
# Satisfiable
# Total time: 0.024930953979492188 sec
# CPU time: 0.015625 sec
# Grounding time: 0.020961761474609375 sec
# Solving time: 0.0039691925048828125 sec
# Atoms : 4993
# Rules : 4619
#
# Cost: []
#
# Fix Point Solving Iteration: 2
# Encoding: ../encodings/sequential\merger_w_det_big_final.lp
# Satisfiable
# Total time: 0.021959304809570312 sec
# CPU time: 0.015625 sec
# Grounding time: 0.018962860107421875 sec
# Solving time: 0.0029964447021484375 sec
# Atoms : 4494
# Rules : 4083
#
# Cost: []
#
# Fix Point Solving Iteration: 1
# Encoding: ../encodings/sequential\merger_w_det_big_final.lp
# Satisfiable
# Total time: 0.023935317993164062 sec
# CPU time: 0.03125 sec
# Grounding time: 0.02094268798828125 sec
# Solving time: 0.0029926300048828125 sec
# Atoms : 4993
# Rules : 4619
#
# Cost: []
#
# Fix Point Solving Iteration: 2
# Encoding: ../encodings/sequential\merger_w_det_big_final.lp
# Satisfiable
# Total time: 0.020975112915039062 sec
# CPU time: 0.015625 sec
# Grounding time: 0.017980575561523438 sec
# Solving time: 0.002994537353515625 sec
# Atoms : 4494
# Rules : 4083
#
# Cost: []
#
# Fix Point Solving Iteration: 1
# Encoding: ../encodings/sequential\merger_w_det_big_final.lp
# Satisfiable
# Total time: 0.022935867309570312 sec
# CPU time: 0.03125 sec
# Grounding time: 0.0199432373046875 sec
# Solving time: 0.0029926300048828125 sec
# Atoms : 4993
# Rules : 4619
#
# Cost: []
#
# Fix Point Solving Iteration: 2
# Encoding: ../encodings/sequential\merger_w_det_big_final.lp
# Satisfiable
# Total time: 0.021942138671875 sec
# CPU time: 0.015625 sec
# Grounding time: 0.01795196533203125 sec
# Solving time: 0.00399017333984375 sec
# Atoms : 4494
# Rules : 4083
#
# Cost: []
#
# Fix Point Solving Iteration: 1
# Encoding: ../encodings/sequential\merger_w_det_big_final.lp
# Satisfiable
# Total time: 0.022937774658203125 sec
# CPU time: 0.015625 sec
# Grounding time: 0.019945144653320312 sec
# Solving time: 0.0029926300048828125 sec
# Atoms : 4993
# Rules : 4619
#
# Cost: []
#
# Fix Point Solving Iteration: 2
# Encoding: ../encodings/sequential\merger_w_det_big_final.lp
# Satisfiable
# Total time: 0.020944595336914062 sec
# CPU time: 0.03125 sec
# Grounding time: 0.01795196533203125 sec
# Solving time: 0.0029926300048828125 sec
# Atoms : 4494
# Rules : 4083
#
# Cost: []
#
# Fix Point Solving Iteration: 1
# Encoding: ../encodings/sequential\merger_w_det_big_final.lp
# Satisfiable
# Total time: 0.023937225341796875 sec
# CPU time: 0.015625 sec
# Grounding time: 0.020944595336914062 sec
# Solving time: 0.0029926300048828125 sec
# Atoms : 4993
# Rules : 4619
#
# Cost: []
#
# Fix Point Solving Iteration: 2
# Encoding: ../encodings/sequential\merger_w_det_big_final.lp
# Satisfiable
# Total time: 0.021940231323242188 sec
# CPU time: 0.015625 sec
# Grounding time: 0.01795196533203125 sec
# Solving time: 0.0039882659912109375 sec
# Atoms : 4494
# Rules : 4083
#
# Cost: []
#
# Fix Point Solving Iteration: 1
# Encoding: ../encodings/sequential\merger_w_det_big_final.lp
# Satisfiable
# Total time: 0.023937225341796875 sec
# CPU time: 0.03125 sec
# Grounding time: 0.020944595336914062 sec
# Solving time: 0.0029926300048828125 sec
# Atoms : 4993
# Rules : 4619
#
# Cost: []
#
# Fix Point Solving Iteration: 2
# Encoding: ../encodings/sequential\merger_w_det_big_final.lp
# Satisfiable
# Total time: 0.021938323974609375 sec
# CPU time: 0.015625 sec
# Grounding time: 0.017950057983398438 sec
# Solving time: 0.0039882659912109375 sec
# Atoms : 4494
# Rules : 4083
#
# Cost: []
#
# Fix Point Solving Iteration: 1
# Encoding: ../encodings/sequential\merger_w_det_big_final.lp
# Satisfiable
# Total time: 0.024932861328125 sec
# CPU time: 0.03125 sec
# Grounding time: 0.020944595336914062 sec
# Solving time: 0.0039882659912109375 sec
# Atoms : 4993
# Rules : 4619
#
# Cost: []
#
# Fix Point Solving Iteration: 2
# Encoding: ../encodings/sequential\merger_w_det_big_final.lp
# Satisfiable
# Total time: 0.021940231323242188 sec
# CPU time: 0.03125 sec
# Grounding time: 0.01795196533203125 sec
# Solving time: 0.0039882659912109375 sec
# Atoms : 4494
# Rules : 4083
#
# Cost: []
#
# Fix Point Solving Iteration: 1
# Encoding: ../encodings/sequential\merger_w_det_big_final.lp
# Satisfiable
# Total time: 0.024932861328125 sec
# CPU time: 0.015625 sec
# Grounding time: 0.020944595336914062 sec
# Solving time: 0.0039882659912109375 sec
# Atoms : 4993
# Rules : 4619
#
# Cost: []
#
# Fix Point Solving Iteration: 2
# Encoding: ../encodings/sequential\merger_w_det_big_final.lp
# Satisfiable
# Total time: 0.02197265625 sec
# CPU time: 0.03125 sec
# Grounding time: 0.018976211547851562 sec
# Solving time: 0.0029964447021484375 sec
# Atoms : 4494
# Rules : 4083
#
# Cost: []
#
# Fix Point Solving Iteration: 1
# Encoding: ../encodings/sequential\merger_w_det_big_final.lp
# Satisfiable
# Total time: 0.024965286254882812 sec
# CPU time: 0.03125 sec
# Grounding time: 0.020965576171875 sec
# Solving time: 0.0039997100830078125 sec
# Atoms : 4993
# Rules : 4619
#
# Cost: []
#
# Fix Point Solving Iteration: 2
# Encoding: ../encodings/sequential\merger_w_det_big_final.lp
# Satisfiable
# Total time: 0.020971298217773438 sec
# CPU time: 0.015625 sec
# Grounding time: 0.017972946166992188 sec
# Solving time: 0.00299835205078125 sec
# Atoms : 4494
# Rules : 4083
#
# Cost: []
#
# Fix Point Solving Iteration: 1
# Encoding: ../encodings/sequential\merger_w_det_big_final.lp
# Satisfiable
# Total time: 0.022970199584960938 sec
# CPU time: 0.03125 sec
# Grounding time: 0.019975662231445312 sec
# Solving time: 0.002994537353515625 sec
# Atoms : 4993
# Rules : 4619
#
# Cost: []
#
# Fix Point Solving Iteration: 2
# Encoding: ../encodings/sequential\merger_w_det_big_final.lp
# Satisfiable
# Total time: 0.020954132080078125 sec
# CPU time: 0.015625 sec
# Grounding time: 0.017963409423828125 sec
# Solving time: 0.00299072265625 sec
# Atoms : 4494
# Rules : 4083
#
# Cost: []
#
# Fix Point Solving Iteration: 1
# Encoding: ../encodings/sequential\merger_w_det_big_final.lp
# Satisfiable
# Total time: 0.023962020874023438 sec
# CPU time: 0.03125 sec
# Grounding time: 0.01996612548828125 sec
# Solving time: 0.0039958953857421875 sec
# Atoms : 4993
# Rules : 4619
#
# Cost: []
#
# Fix Point Solving Iteration: 2
# Encoding: ../encodings/sequential\merger_w_det_big_final.lp
# Satisfiable
# Total time: 0.021940231323242188 sec
# CPU time: 0.03125 sec
# Grounding time: 0.018947601318359375 sec
# Solving time: 0.0029926300048828125 sec
# Atoms : 4494
# Rules : 4083
#
# Cost: []
#
# Fix Point Solving Iteration: 1
# Encoding: ../encodings/sequential\merger_w_det_big_final.lp
# Satisfiable
# Total time: 0.023935317993164062 sec
# CPU time: 0.015625 sec
# Grounding time: 0.019947052001953125 sec
# Solving time: 0.0039882659912109375 sec
# Atoms : 4993
# Rules : 4619
#
# Cost: []
#
# Fix Point Solving Iteration: 2
# Encoding: ../encodings/sequential\merger_w_det_big_final.lp
# Satisfiable
# Total time: 0.020931243896484375 sec
# CPU time: 0.03125 sec
# Grounding time: 0.017938613891601562 sec
# Solving time: 0.0029926300048828125 sec
# Atoms : 4494
# Rules : 4083
#
# Cost: []
#
# Fix Point Solving Iteration: 1
# Encoding: ../encodings/sequential\merger_w_det_big_final.lp
# Satisfiable
# Total time: 0.024932861328125 sec
# CPU time: 0.03125 sec
# Grounding time: 0.019947052001953125 sec
# Solving time: 0.004985809326171875 sec
# Atoms : 4993
# Rules : 4619
#
# Cost: []
#
# Fix Point Solving Iteration: 2
# Encoding: ../encodings/sequential\merger_w_det_big_final.lp
# Satisfiable
# Total time: 0.020946502685546875 sec
# CPU time: 0.015625 sec
# Grounding time: 0.01795196533203125 sec
# Solving time: 0.002994537353515625 sec
# Atoms : 4494
# Rules : 4083
#
# Cost: []
#
# Fix Point Solving Iteration: 1
# Encoding: ../encodings/sequential\merger_w_det_big_final.lp
# Satisfiable
# Total time: 0.024932861328125 sec
# CPU time: 0.03125 sec
# Grounding time: 0.020944595336914062 sec
# Solving time: 0.0039882659912109375 sec
# Atoms : 4993
# Rules : 4619
#
# Cost: []
#
# Fix Point Solving Iteration: 2
# Encoding: ../encodings/sequential\merger_w_det_big_final.lp
# Satisfiable
# Total time: 0.021940231323242188 sec
# CPU time: 0.015625 sec
# Grounding time: 0.018949508666992188 sec
# Solving time: 0.00299072265625 sec
# Atoms : 4494
# Rules : 4083
#
# Cost: []
#
# Fix Point Solving Iteration: 1
# Encoding: ../encodings/sequential\merger_w_det_big_final.lp
# Satisfiable
# Total time: 0.024932861328125 sec
# CPU time: 0.046875 sec
# Grounding time: 0.021942138671875 sec
# Solving time: 0.00299072265625 sec
# Atoms : 4993
# Rules : 4619
#
# Cost: []
#
# Fix Point Solving Iteration: 2
# Encoding: ../encodings/sequential\merger_w_det_big_final.lp
# Satisfiable
# Total time: 0.021942138671875 sec
# CPU time: 0.03125 sec
# Grounding time: 0.01795196533203125 sec
# Solving time: 0.00399017333984375 sec
# Atoms : 4494
# Rules : 4083
#
# Cost: []
#
# Fix Point Solving Iteration: 1
# Encoding: ../encodings/sequential\merger_w_det_big_final.lp
# Satisfiable
# Total time: 0.024930953979492188 sec
# CPU time: 0.015625 sec
# Grounding time: 0.020940780639648438 sec
# Solving time: 0.00399017333984375 sec
# Atoms : 4993
# Rules : 4619
#
# Cost: []
#
# Fix Point Solving Iteration: 2
# Encoding: ../encodings/sequential\merger_w_det_big_final.lp
# Satisfiable
# Total time: 0.021928787231445312 sec
# CPU time: 0.046875 sec
# Grounding time: 0.017940521240234375 sec
# Solving time: 0.0039882659912109375 sec
# Atoms : 4494
# Rules : 4083
#
# Cost: []
#
# Fix Point Solving Iteration: 1
# Encoding: ../encodings/sequential\merger_w_det_big_final.lp
# Satisfiable
# Total time: 0.024932861328125 sec
# CPU time: 0.03125 sec
# Grounding time: 0.021940231323242188 sec
# Solving time: 0.0029926300048828125 sec
# Atoms : 4993
# Rules : 4619
#
# Cost: []
#
# Fix Point Solving Iteration: 2
# Encoding: ../encodings/sequential\merger_w_det_big_final.lp
# Satisfiable
# Total time: 0.02094268798828125 sec
# CPU time: 0.015625 sec
# Grounding time: 0.016954421997070312 sec
# Solving time: 0.0039882659912109375 sec
# Atoms : 4494
# Rules : 4083
#
# Cost: []
#
# Fix Point Solving Iteration: 1
# Encoding: ../encodings/sequential\merger_w_det_big_final.lp
# Satisfiable
# Total time: 0.022939682006835938 sec
# CPU time: 0.03125 sec
# Grounding time: 0.019948959350585938 sec
# Solving time: 0.00299072265625 sec
# Atoms : 4993
# Rules : 4619
#
# Cost: []
#
# Fix Point Solving Iteration: 2
# Encoding: ../encodings/sequential\merger_w_det_big_final.lp
# Satisfiable
# Total time: 0.009815216064453125 sec
# CPU time: 0.0 sec
# Grounding time: 0.009815216064453125 sec
# Solving time: 0.0 sec
# Atoms : 4494
# Rules : 4083
#
# Cost: []
#
# Fix Point Solving Iteration: 1
# Encoding: ../encodings/sequential\merger_w_det_big_final.lp
# Satisfiable
# Total time: 0.03127861022949219 sec
# CPU time: 0.03125 sec
# Grounding time: 0.03127861022949219 sec
# Solving time: 0.0 sec
# Atoms : 4993
# Rules : 4619
#
# Cost: []
#
# Fix Point Solving Iteration: 2
# Encoding: ../encodings/sequential\merger_w_det_big_final.lp
# Satisfiable
# Total time: 0.01558685302734375 sec
# CPU time: 0.015625 sec
# Grounding time: 0.01558685302734375 sec
# Solving time: 0.0 sec
# Atoms : 4494
# Rules : 4083
#
# Cost: []
#
# Fix Point Solving Iteration: 1
# Encoding: ../encodings/sequential\merger_w_det_big_final.lp
# Satisfiable
# Total time: 0.03127288818359375 sec
# CPU time: 0.03125 sec
# Grounding time: 0.03127288818359375 sec
# Solving time: 0.0 sec
# Atoms : 4993
# Rules : 4619
#
# Cost: []
#
# Fix Point Solving Iteration: 2
# Encoding: ../encodings/sequential\merger_w_det_big_final.lp
# Satisfiable
# Total time: 0.015590667724609375 sec
# CPU time: 0.015625 sec
# Grounding time: 0.015590667724609375 sec
# Solving time: 0.0 sec
# Atoms : 4494
# Rules : 4083
#
# Cost: []
#
# Fix Point Solving Iteration: 1
# Encoding: ../encodings/sequential\merger_w_det_big_final.lp
# Satisfiable
# Total time: 0.03475761413574219 sec
# CPU time: 0.046875 sec
# Grounding time: 0.03475761413574219 sec
# Solving time: 0.0 sec
# Atoms : 4993
# Rules : 4619
#
# Cost: []
#
# Fix Point Solving Iteration: 2
# Encoding: ../encodings/sequential\merger_w_det_big_final.lp
# Satisfiable
# Total time: 0.021968841552734375 sec
# CPU time: 0.015625 sec
# Grounding time: 0.017978668212890625 sec
# Solving time: 0.00399017333984375 sec
# Atoms : 4494
# Rules : 4083
#
# Cost: []
#
# Fix Point Solving Iteration: 1
# Encoding: ../encodings/sequential\merger_w_det_big_final.lp
# Satisfiable
# Total time: 0.02396392822265625 sec
# CPU time: 0.015625 sec
# Grounding time: 0.019975662231445312 sec
# Solving time: 0.0039882659912109375 sec
# Atoms : 4993
# Rules : 4619
#
# Cost: []
#
# Fix Point Solving Iteration: 2
# Encoding: ../encodings/sequential\merger_w_det_big_final.lp
# Satisfiable
# Total time: 0.015623092651367188 sec
# CPU time: 0.015625 sec
# Grounding time: 0.015623092651367188 sec
# Solving time: 0.0 sec
# Atoms : 4494
# Rules : 4083
#
# Cost: []
#
# Fix Point Solving Iteration: 1
# Encoding: ../encodings/sequential\merger_w_det_big_final.lp
# Satisfiable
# Total time: 0.031269073486328125 sec
# CPU time: 0.03125 sec
# Grounding time: 0.015621185302734375 sec
# Solving time: 0.01564788818359375 sec
# Atoms : 4993
# Rules : 4619
#
# Cost: []
#
# Fix Point Solving Iteration: 2
# Encoding: ../encodings/sequential\merger_w_det_big_final.lp
# Satisfiable
# Total time: 0.015594482421875 sec
# CPU time: 0.015625 sec
# Grounding time: 0.015594482421875 sec
# Solving time: 0.0 sec
# Atoms : 4494
# Rules : 4083
#
# Cost: []
#
# Fix Point Solving Iteration: 1
# Encoding: ../encodings/sequential\merger_w_det_big_final.lp
# Satisfiable
# Total time: 0.031276702880859375 sec
# CPU time: 0.03125 sec
# Grounding time: 0.015621185302734375 sec
# Solving time: 0.015655517578125 sec
# Atoms : 4993
# Rules : 4619
#
# Cost: []
#
# Fix Point Solving Iteration: 2
# Encoding: ../encodings/sequential\merger_w_det_big_final.lp
# Satisfiable
# Total time: 0.027200698852539062 sec
# CPU time: 0.03125 sec
# Grounding time: 0.024209976196289062 sec
# Solving time: 0.00299072265625 sec
# Atoms : 4494
# Rules : 4083
#
# Cost: []
#
# Fix Point Solving Iteration: 1
# Encoding: ../encodings/sequential\merger_w_det_big_final.lp
# Satisfiable
# Total time: 0.022970199584960938 sec
# CPU time: 0.03125 sec
# Grounding time: 0.01996612548828125 sec
# Solving time: 0.0030040740966796875 sec
# Atoms : 4993
# Rules : 4619
#
# Cost: []
#
# Fix Point Solving Iteration: 2
# Encoding: ../encodings/sequential\merger_w_det_big_final.lp
# Satisfiable
# Total time: 0.020952224731445312 sec
# CPU time: 0.015625 sec
# Grounding time: 0.016931533813476562 sec
# Solving time: 0.00402069091796875 sec
# Atoms : 4494
# Rules : 4083
#
# Cost: []
#
# Fix Point Solving Iteration: 1
# Encoding: ../encodings/sequential\merger_w_det_big_final.lp
# Satisfiable
# Total time: 0.024932861328125 sec
# CPU time: 0.03125 sec
# Grounding time: 0.020971298217773438 sec
# Solving time: 0.0039615631103515625 sec
# Atoms : 4993
# Rules : 4619
#
# Cost: []
#
# Fix Point Solving Iteration: 2
# Encoding: ../encodings/sequential\merger_w_det_big_final.lp
# Satisfiable
# Total time: 0.021942138671875 sec
# CPU time: 0.03125 sec
# Grounding time: 0.018951416015625 sec
# Solving time: 0.00299072265625 sec
# Atoms : 4494
# Rules : 4083
#
# Cost: []
#
# Fix Point Solving Iteration: 1
# Encoding: ../encodings/sequential\merger_w_det_big_final.lp
# Satisfiable
# Total time: 0.024951934814453125 sec
# CPU time: 0.015625 sec
# Grounding time: 0.020961761474609375 sec
# Solving time: 0.00399017333984375 sec
# Atoms : 4993
# Rules : 4619
#
# Cost: []
#
# Fix Point Solving Iteration: 2
# Encoding: ../encodings/sequential\merger_w_det_big_final.lp
# Satisfiable
# Total time: 0.02097320556640625 sec
# CPU time: 0.03125 sec
# Grounding time: 0.017971038818359375 sec
# Solving time: 0.003002166748046875 sec
# Atoms : 4494
# Rules : 4083
#
# Cost: []
#
# Fix Point Solving Iteration: 1
# Encoding: ../encodings/sequential\merger_w_det_big_final.lp
# Satisfiable
# Total time: 0.024965286254882812 sec
# CPU time: 0.03125 sec
# Grounding time: 0.0200653076171875 sec
# Solving time: 0.0048999786376953125 sec
# Atoms : 4993
# Rules : 4619
#
# Cost: []
#
# Fix Point Solving Iteration: 2
# Encoding: ../encodings/sequential\merger_w_det_big_final.lp
# Satisfiable
# Total time: 0.020969390869140625 sec
# CPU time: 0.015625 sec
# Grounding time: 0.017971038818359375 sec
# Solving time: 0.00299835205078125 sec
# Atoms : 4494
# Rules : 4083
#
# Cost: []
#
# Fix Point Solving Iteration: 1
# Encoding: ../encodings/sequential\merger_w_det_big_final.lp
# Satisfiable
# Total time: 0.025930404663085938 sec
# CPU time: 0.03125 sec
# Grounding time: 0.02197265625 sec
# Solving time: 0.0039577484130859375 sec
# Atoms : 4993
# Rules : 4619
#
# Cost: []
#
# Fix Point Solving Iteration: 2
# Encoding: ../encodings/sequential\merger_w_det_big_final.lp
# Satisfiable
# Total time: 0.020940780639648438 sec
# CPU time: 0.015625 sec
# Grounding time: 0.017950057983398438 sec
# Solving time: 0.00299072265625 sec
# Atoms : 4494
# Rules : 4083
#
# Cost: []
#
# Fix Point Solving Iteration: 1
# Encoding: ../encodings/sequential\merger_w_det_big_final.lp
# Satisfiable
# Total time: 0.02496337890625 sec
# CPU time: 0.015625 sec
# Grounding time: 0.020963668823242188 sec
# Solving time: 0.0039997100830078125 sec
# Atoms : 4993
# Rules : 4619
#
# Cost: []
#
# Fix Point Solving Iteration: 2
# Encoding: ../encodings/sequential\merger_w_det_big_final.lp
# Satisfiable
# Total time: 0.02097320556640625 sec
# CPU time: 0.03125 sec
# Grounding time: 0.017980575561523438 sec
# Solving time: 0.0029926300048828125 sec
# Atoms : 4494
# Rules : 4083
#
# Cost: []
#
# Fix Point Solving Iteration: 1
# Encoding: ../encodings/sequential\merger_w_det_big_final.lp
# Satisfiable
# Total time: 0.024959564208984375 sec
# CPU time: 0.015625 sec
# Grounding time: 0.021970748901367188 sec
# Solving time: 0.0029888153076171875 sec
# Atoms : 4993
# Rules : 4619
#
# Cost: []
#
# Fix Point Solving Iteration: 2
# Encoding: ../encodings/sequential\merger_w_det_big_final.lp
# Satisfiable
# Total time: 0.020931243896484375 sec
# CPU time: 0.015625 sec
# Grounding time: 0.017940521240234375 sec
# Solving time: 0.00299072265625 sec
# Atoms : 4494
# Rules : 4083
#
# Cost: []
#
# Fix Point Solving Iteration: 1
# Encoding: ../encodings/sequential\merger_w_det_big_final.lp
# Satisfiable
# Total time: 0.023935317993164062 sec
# CPU time: 0.03125 sec
# Grounding time: 0.01996612548828125 sec
# Solving time: 0.0039691925048828125 sec
# Atoms : 4993
# Rules : 4619
#
# Cost: []
#
# Fix Point Solving Iteration: 2
# Encoding: ../encodings/sequential\merger_w_det_big_final.lp
# Satisfiable
# Total time: 0.02095794677734375 sec
# CPU time: 0.015625 sec
# Grounding time: 0.017965316772460938 sec
# Solving time: 0.0029926300048828125 sec
# Atoms : 4494
# Rules : 4083
#
# Cost: []
#
# Fix Point Solving Iteration: 1
# Encoding: ../encodings/sequential\merger_w_det_big_final.lp
# Satisfiable
# Total time: 0.024959564208984375 sec
# CPU time: 0.015625 sec
# Grounding time: 0.020977020263671875 sec
# Solving time: 0.0039825439453125 sec
# Atoms : 4993
# Rules : 4619
#
# Cost: []
#
# Fix Point Solving Iteration: 2
# Encoding: ../encodings/sequential\merger_w_det_big_final.lp
# Satisfiable
# Total time: 0.021928787231445312 sec
# CPU time: 0.03125 sec
# Grounding time: 0.017917633056640625 sec
# Solving time: 0.0040111541748046875 sec
# Atoms : 4494
# Rules : 4083
#
# Cost: []
#
# Fix Point Solving Iteration: 1
# Encoding: ../encodings/sequential\merger_w_det_big_final.lp
# Satisfiable
# Total time: 0.023935317993164062 sec
# CPU time: 0.015625 sec
# Grounding time: 0.020944595336914062 sec
# Solving time: 0.00299072265625 sec
# Atoms : 4993
# Rules : 4619
#
# Cost: []
#
# Fix Point Solving Iteration: 2
# Encoding: ../encodings/sequential\merger_w_det_big_final.lp
# Satisfiable
# Total time: 0.021940231323242188 sec
# CPU time: 0.015625 sec
# Grounding time: 0.016954421997070312 sec
# Solving time: 0.004985809326171875 sec
# Atoms : 4494
# Rules : 4083
#
# Cost: []
#
# Fix Point Solving Iteration: 1
# Encoding: ../encodings/sequential\merger_w_det_big_final.lp
# Satisfiable
# Total time: 0.022937774658203125 sec
# CPU time: 0.03125 sec
# Grounding time: 0.019947052001953125 sec
# Solving time: 0.00299072265625 sec
# Atoms : 4993
# Rules : 4619
#
# Cost: []
#
# Fix Point Solving Iteration: 2
# Encoding: ../encodings/sequential\merger_w_det_big_final.lp
# Satisfiable
# Total time: 0.021942138671875 sec
# CPU time: 0.015625 sec
# Grounding time: 0.01795196533203125 sec
# Solving time: 0.00399017333984375 sec
# Atoms : 4494
# Rules : 4083
#
# Cost: []
#
# Fix Point Solving Iteration: 1
# Encoding: ../encodings/sequential\merger_w_det_big_final.lp
# Satisfiable
# Total time: 0.022937774658203125 sec
# CPU time: 0.03125 sec
# Grounding time: 0.019947052001953125 sec
# Solving time: 0.00299072265625 sec
# Atoms : 4993
# Rules : 4619
#
# Cost: []
#
# Fix Point Solving Iteration: 2
# Encoding: ../encodings/sequential\merger_w_det_big_final.lp
# Satisfiable
# Total time: 0.021942138671875 sec
# CPU time: 0.015625 sec
# Grounding time: 0.01795196533203125 sec
# Solving time: 0.00399017333984375 sec
# Atoms : 4494
# Rules : 4083
#
# Cost: []
#
# Fix Point Solving Iteration: 1
# Encoding: ../encodings/sequential\merger_w_det_big_final.lp
# Satisfiable
# Total time: 0.02393341064453125 sec
# CPU time: 0.03125 sec
# Grounding time: 0.02094268798828125 sec
# Solving time: 0.00299072265625 sec
# Atoms : 4993
# Rules : 4619
#
# Cost: []
#
# Fix Point Solving Iteration: 2
# Encoding: ../encodings/sequential\merger_w_det_big_final.lp
# Satisfiable
# Total time: 0.021942138671875 sec
# CPU time: 0.03125 sec
# Grounding time: 0.01795196533203125 sec
# Solving time: 0.00399017333984375 sec
# Atoms : 4494
# Rules : 4083
#
# Cost: []
#
# Fix Point Solving Iteration: 1
# Encoding: ../encodings/sequential\merger_w_det_big_final.lp
# Satisfiable
# Total time: 0.022939682006835938 sec
# CPU time: 0.015625 sec
# Grounding time: 0.019947052001953125 sec
# Solving time: 0.0029926300048828125 sec
# Atoms : 4993
# Rules : 4619
#
# Cost: []
#
# Fix Point Solving Iteration: 2
# Encoding: ../encodings/sequential\merger_w_det_big_final.lp
# Satisfiable
# Total time: 0.022939682006835938 sec
# CPU time: 0.03125 sec
# Grounding time: 0.018949508666992188 sec
# Solving time: 0.00399017333984375 sec
# Atoms : 4494
# Rules : 4083
#
# Cost: []
#
# Fix Point Solving Iteration: 1
# Encoding: ../encodings/sequential\merger_w_det_big_final.lp
# Satisfiable
# Total time: 0.023935317993164062 sec
# CPU time: 0.015625 sec
# Grounding time: 0.02094268798828125 sec
# Solving time: 0.0029926300048828125 sec
# Atoms : 4993
# Rules : 4619
#
# Cost: []
#
# Fix Point Solving Iteration: 2
# Encoding: ../encodings/sequential\merger_w_det_big_final.lp
# Satisfiable
# Total time: 0.021942138671875 sec
# CPU time: 0.015625 sec
# Grounding time: 0.01795196533203125 sec
# Solving time: 0.00399017333984375 sec
# Atoms : 4494
# Rules : 4083
#
# Cost: []
#
# Fix Point Solving Iteration: 1
# Encoding: ../encodings/sequential\merger_w_det_big_final.lp
# Satisfiable
# Total time: 0.023935317993164062 sec
# CPU time: 0.03125 sec
# Grounding time: 0.02094268798828125 sec
# Solving time: 0.0029926300048828125 sec
# Atoms : 4993
# Rules : 4619
#
# Cost: []
#
# Fix Point Solving Iteration: 2
# Encoding: ../encodings/sequential\merger_w_det_big_final.lp
# Satisfiable
# Total time: 0.021940231323242188 sec
# CPU time: 0.015625 sec
# Grounding time: 0.017978668212890625 sec
# Solving time: 0.0039615631103515625 sec
# Atoms : 4494
# Rules : 4083
#
# Cost: []
#
# Fix Point Solving Iteration: 1
# Encoding: ../encodings/sequential\merger_w_det_big_final.lp
# Satisfiable
# Total time: 0.023965835571289062 sec
# CPU time: 0.03125 sec
# Grounding time: 0.020963668823242188 sec
# Solving time: 0.003002166748046875 sec
# Atoms : 4993
# Rules : 4619
#
# Cost: []
#
# Fix Point Solving Iteration: 2
# Encoding: ../encodings/sequential\merger_w_det_big_final.lp
# Satisfiable
# Total time: 0.021968841552734375 sec
# CPU time: 0.015625 sec
# Grounding time: 0.018951416015625 sec
# Solving time: 0.003017425537109375 sec
# Atoms : 4494
# Rules : 4083
#
# Cost: []
#
# Fix Point Solving Iteration: 1
# Encoding: ../encodings/sequential\merger_w_det_big_final.lp
# Satisfiable
# Total time: 0.023962020874023438 sec
# CPU time: 0.015625 sec
# Grounding time: 0.019971847534179688 sec
# Solving time: 0.00399017333984375 sec
# Atoms : 4993
# Rules : 4619
#
# Cost: []
#
# Fix Point Solving Iteration: 2
# Encoding: ../encodings/sequential\merger_w_det_big_final.lp
# Satisfiable
# Total time: 0.019977569580078125 sec
# CPU time: 0.03125 sec
# Grounding time: 0.016962051391601562 sec
# Solving time: 0.0030155181884765625 sec
# Atoms : 4494
# Rules : 4083
#
# Cost: []
#
# Fix Point Solving Iteration: 1
# Encoding: ../encodings/sequential\merger_w_det_big_final.lp
# Satisfiable
# Total time: 0.023965835571289062 sec
# CPU time: 0.015625 sec
# Grounding time: 0.020961761474609375 sec
# Solving time: 0.0030040740966796875 sec
# Atoms : 4993
# Rules : 4619
#
# Cost: []
#
# Fix Point Solving Iteration: 2
# Encoding: ../encodings/sequential\merger_w_det_big_final.lp
# Satisfiable
# Total time: 0.020956039428710938 sec
# CPU time: 0.015625 sec
# Grounding time: 0.017953872680664062 sec
# Solving time: 0.003002166748046875 sec
# Atoms : 4494
# Rules : 4083
#
# Cost: []
#
# Fix Point Solving Iteration: 1
# Encoding: ../encodings/sequential\merger_w_det_big_final.lp
# Satisfiable
# Total time: 0.022966384887695312 sec
# CPU time: 0.03125 sec
# Grounding time: 0.019971847534179688 sec
# Solving time: 0.002994537353515625 sec
# Atoms : 4993
# Rules : 4619
#
# Cost: []
#
# Fix Point Solving Iteration: 2
# Encoding: ../encodings/sequential\merger_w_det_big_final.lp
# Satisfiable
# Total time: 0.020969390869140625 sec
# CPU time: 0.015625 sec
# Grounding time: 0.017980575561523438 sec
# Solving time: 0.0029888153076171875 sec
# Atoms : 4494
# Rules : 4083
#
# Cost: []
#
# Fix Point Solving Iteration: 1
# Encoding: ../encodings/sequential\merger_w_det_big_final.lp
# Satisfiable
# Total time: 0.023967742919921875 sec
# CPU time: 0.03125 sec
# Grounding time: 0.020969390869140625 sec
# Solving time: 0.00299835205078125 sec
# Atoms : 4993
# Rules : 4619
#
# Cost: []
#
# Fix Point Solving Iteration: 2
# Encoding: ../encodings/sequential\merger_w_det_big_final.lp
# Satisfiable
# Total time: 0.02197265625 sec
# CPU time: 0.03125 sec
# Grounding time: 0.017953872680664062 sec
# Solving time: 0.0040187835693359375 sec
# Atoms : 4494
# Rules : 4083
#
# Cost: []
#
# Fix Point Solving Iteration: 1
# Encoding: ../encodings/sequential\merger_w_det_big_final.lp
# Satisfiable
# Total time: 0.024965286254882812 sec
# CPU time: 0.015625 sec
# Grounding time: 0.020971298217773438 sec
# Solving time: 0.003993988037109375 sec
# Atoms : 4993
# Rules : 4619
#
# Cost: []
#
# Fix Point Solving Iteration: 2
# Encoding: ../encodings/sequential\merger_w_det_big_final.lp
# Satisfiable
# Total time: 0.020971298217773438 sec
# CPU time: 0.03125 sec
# Grounding time: 0.017978668212890625 sec
# Solving time: 0.0029926300048828125 sec
# Atoms : 4494
# Rules : 4083
#
# Cost: []
#
# Fix Point Solving Iteration: 1
# Encoding: ../encodings/sequential\merger_w_det_big_final.lp
# Satisfiable
# Total time: 0.024961471557617188 sec
# CPU time: 0.015625 sec
# Grounding time: 0.020971298217773438 sec
# Solving time: 0.00399017333984375 sec
# Atoms : 4993
# Rules : 4619
#
# Cost: []
#
# Fix Point Solving Iteration: 2
# Encoding: ../encodings/sequential\merger_w_det_big_final.lp
# Satisfiable
# Total time: 0.02197265625 sec
# CPU time: 0.015625 sec
# Grounding time: 0.01795196533203125 sec
# Solving time: 0.00402069091796875 sec
# Atoms : 4494
# Rules : 4083
#
# Cost: []
#
# Fix Point Solving Iteration: 1
# Encoding: ../encodings/sequential\merger_w_det_big_final.lp
# Satisfiable
# Total time: 0.023935317993164062 sec
# CPU time: 0.03125 sec
# Grounding time: 0.020944595336914062 sec
# Solving time: 0.00299072265625 sec
# Atoms : 4993
# Rules : 4619
#
# Cost: []
#
# Fix Point Solving Iteration: 2
# Encoding: ../encodings/sequential\merger_w_det_big_final.lp
# Satisfiable
# Total time: 0.020944595336914062 sec
# CPU time: 0.015625 sec
# Grounding time: 0.01795196533203125 sec
# Solving time: 0.0029926300048828125 sec
# Atoms : 4494
# Rules : 4083
#
# Cost: []
#
# Fix Point Solving Iteration: 1
# Encoding: ../encodings/sequential\merger_w_det_big_final.lp
# Satisfiable
# Total time: 0.024930953979492188 sec
# CPU time: 0.03125 sec
# Grounding time: 0.021942138671875 sec
# Solving time: 0.0029888153076171875 sec
# Atoms : 4993
# Rules : 4619
#
# Cost: []
#
# Fix Point Solving Iteration: 2
# Encoding: ../encodings/sequential\merger_w_det_big_final.lp
# Satisfiable
# Total time: 0.021940231323242188 sec
# CPU time: 0.03125 sec
# Grounding time: 0.018949508666992188 sec
# Solving time: 0.00299072265625 sec
# Atoms : 4494
# Rules : 4083
#
# Cost: []
#
# Fix Point Solving Iteration: 1
# Encoding: ../encodings/sequential\merger_w_det_big_final.lp
# Satisfiable
# Total time: 0.024965286254882812 sec
# CPU time: 0.015625 sec
# Grounding time: 0.020965576171875 sec
# Solving time: 0.0039997100830078125 sec
# Atoms : 4993
# Rules : 4619
#
# Cost: []
#
# Fix Point Solving Iteration: 2
# Encoding: ../encodings/sequential\merger_w_det_big_final.lp
# Satisfiable
# Total time: 0.020961761474609375 sec
# CPU time: 0.015625 sec
# Grounding time: 0.016941070556640625 sec
# Solving time: 0.00402069091796875 sec
# Atoms : 4494
# Rules : 4083
#
# Cost: []
#
# Fix Point Solving Iteration: 1
# Encoding: ../encodings/sequential\merger_w_det_big_final.lp
# Satisfiable
# Total time: 0.024923324584960938 sec
# CPU time: 0.03125 sec
# Grounding time: 0.020931243896484375 sec
# Solving time: 0.0039920806884765625 sec
# Atoms : 4993
# Rules : 4619
#
# Cost: []
#
# Fix Point Solving Iteration: 2
# Encoding: ../encodings/sequential\merger_w_det_big_final.lp
# Satisfiable
# Total time: 0.02094268798828125 sec
# CPU time: 0.015625 sec
# Grounding time: 0.0169525146484375 sec
# Solving time: 0.00399017333984375 sec
# Atoms : 4494
# Rules : 4083
#
# Cost: []
#
# Fix Point Solving Iteration: 1
# Encoding: ../encodings/sequential\merger_w_det_big_final.lp
# Satisfiable
# Total time: 0.023935317993164062 sec
# CPU time: 0.03125 sec
# Grounding time: 0.019947052001953125 sec
# Solving time: 0.0039882659912109375 sec
# Atoms : 4993
# Rules : 4619
#
# Cost: []
#
# Fix Point Solving Iteration: 2
# Encoding: ../encodings/sequential\merger_w_det_big_final.lp
# Satisfiable
# Total time: 0.020944595336914062 sec
# CPU time: 0.015625 sec
# Grounding time: 0.01795196533203125 sec
# Solving time: 0.0029926300048828125 sec
# Atoms : 4494
# Rules : 4083
#
# Cost: []
#
# Fix Point Solving Iteration: 1
# Encoding: ../encodings/sequential\merger_w_det_big_final.lp
# Satisfiable
# Total time: 0.02393341064453125 sec
# CPU time: 0.03125 sec
# Grounding time: 0.02094268798828125 sec
# Solving time: 0.00299072265625 sec
# Atoms : 4993
# Rules : 4619
#
# Cost: []
#
# Fix Point Solving Iteration: 2
# Encoding: ../encodings/sequential\merger_w_det_big_final.lp
# Satisfiable
# Total time: 0.020938873291015625 sec
# CPU time: 0.015625 sec
# Grounding time: 0.017946243286132812 sec
# Solving time: 0.0029926300048828125 sec
# Atoms : 4494
# Rules : 4083
#
# Cost: []
#
# Fix Point Solving Iteration: 1
# Encoding: ../encodings/sequential\merger_w_det_big_final.lp
# Satisfiable
# Total time: 0.023935317993164062 sec
# CPU time: 0.015625 sec
# Grounding time: 0.02094268798828125 sec
# Solving time: 0.0029926300048828125 sec
# Atoms : 4993
# Rules : 4619
#
# Cost: []
#
# Fix Point Solving Iteration: 2
# Encoding: ../encodings/sequential\merger_w_det_big_final.lp
# Satisfiable
# Total time: 0.02094268798828125 sec
# CPU time: 0.03125 sec
# Grounding time: 0.01795196533203125 sec
# Solving time: 0.00299072265625 sec
# Atoms : 4494
# Rules : 4083
#
# Cost: []
#
# Fix Point Solving Iteration: 1
# Encoding: ../encodings/sequential\merger_w_det_big_final.lp
# Satisfiable
# Total time: 0.023965835571289062 sec
# CPU time: 0.015625 sec
# Grounding time: 0.020965576171875 sec
# Solving time: 0.0030002593994140625 sec
# Atoms : 4993
# Rules : 4619
#
# Cost: []
#
# Fix Point Solving Iteration: 2
# Encoding: ../encodings/sequential\merger_w_det_big_final.lp
# Satisfiable
# Total time: 0.02094268798828125 sec
# CPU time: 0.015625 sec
# Grounding time: 0.01795196533203125 sec
# Solving time: 0.00299072265625 sec
# Atoms : 4494
# Rules : 4083
#
# Cost: []
#
# Fix Point Solving Iteration: 1
# Encoding: ../encodings/sequential\merger_w_det_big_final.lp
# Satisfiable
# Total time: 0.023935317993164062 sec
# CPU time: 0.03125 sec
# Grounding time: 0.019945144653320312 sec
# Solving time: 0.00399017333984375 sec
# Atoms : 4993
# Rules : 4619
#
# Cost: []
#
# Fix Point Solving Iteration: 2
# Encoding: ../encodings/sequential\merger_w_det_big_final.lp
# Satisfiable
# Total time: 0.020965576171875 sec
# CPU time: 0.015625 sec
# Grounding time: 0.017961502075195312 sec
# Solving time: 0.0030040740966796875 sec
# Atoms : 4494
# Rules : 4083
#
# Cost: []
#
# Fix Point Solving Iteration: 1
# Encoding: ../encodings/sequential\merger_w_det_big_final.lp
# Satisfiable
# Total time: 0.023935317993164062 sec
# CPU time: 0.03125 sec
# Grounding time: 0.019947052001953125 sec
# Solving time: 0.0039882659912109375 sec
# Atoms : 4993
# Rules : 4619
#
# Cost: []
#
# Fix Point Solving Iteration: 2
# Encoding: ../encodings/sequential\merger_w_det_big_final.lp
# Satisfiable
# Total time: 0.02094268798828125 sec
# CPU time: 0.015625 sec
# Grounding time: 0.017950057983398438 sec
# Solving time: 0.0029926300048828125 sec
# Atoms : 4494
# Rules : 4083
#
# Cost: []
#
# Fix Point Solving Iteration: 1
# Encoding: ../encodings/sequential\merger_w_det_big_final.lp
# Satisfiable
# Total time: 0.022939682006835938 sec
# CPU time: 0.015625 sec
# Grounding time: 0.018949508666992188 sec
# Solving time: 0.00399017333984375 sec
# Atoms : 4993
# Rules : 4619
#
# Cost: []
#
# Fix Point Solving Iteration: 2
# Encoding: ../encodings/sequential\merger_w_det_big_final.lp
# Satisfiable
# Total time: 0.020528793334960938 sec
# CPU time: 0.03125 sec
# Grounding time: 0.00492095947265625 sec
# Solving time: 0.015607833862304688 sec
# Atoms : 4494
# Rules : 4083
#
# Cost: []
#
# Fix Point Solving Iteration: 1
# Encoding: ../encodings/sequential\merger_w_det_big_final.lp
# Satisfiable
# Total time: 0.015621185302734375 sec
# CPU time: 0.015625 sec
# Grounding time: 0.015621185302734375 sec
# Solving time: 0.0 sec
# Atoms : 4993
# Rules : 4619
#
# Cost: []
#
# Fix Point Solving Iteration: 2
# Encoding: ../encodings/sequential\merger_w_det_big_final.lp
# Satisfiable
# Total time: 0.031244277954101562 sec
# CPU time: 0.03125 sec
# Grounding time: 0.015621185302734375 sec
# Solving time: 0.015623092651367188 sec
# Atoms : 4494
# Rules : 4083
#
# Cost: []
#
# Fix Point Solving Iteration: 1
# Encoding: ../encodings/sequential\merger_w_det_big_final.lp
# Satisfiable
# ...
# Atoms : 4494
# Rules : 4083
#
# Cost: []
#
# Fix Point Solving Iteration: 1
# Encoding: ../encodings/sequential\merger_w_det_big_final.lp
# Satisfiable
# Total time: 0.023937225341796875 sec
# CPU time: 0.03125 sec
# Grounding time: 0.020946502685546875 sec
# Solving time: 0.00299072265625 sec
# Atoms : 4993
# Rules : 4619
#
# Cost: []
#
# Fix Point Solving Iteration: 2
# Encoding: ../encodings/sequential\merger_w_det_big_final.lp
# Satisfiable
# Total time: 0.020944595336914062 sec
# CPU time: 0.015625 sec
# Grounding time: 0.016956329345703125 sec
# Solving time: 0.0039882659912109375 sec
# Atoms : 4494
# Rules : 4083
#
# Cost: []
#
# Fix Point Solving Iteration: 1
# Encoding: ../encodings/sequential\merger_w_det_big_final.lp
# Satisfiable
# Total time: 0.024961471557617188 sec
# CPU time: 0.03125 sec
# Grounding time: 0.021955490112304688 sec
# Solving time: 0.0030059814453125 sec
# Atoms : 4993
# Rules : 4619
#
# Cost: []
#
# Fix Point Solving Iteration: 2
# Encoding: ../encodings/sequential\merger_w_det_big_final.lp
# Satisfiable
# Total time: 0.02097320556640625 sec
# CPU time: 0.015625 sec
# Grounding time: 0.016979217529296875 sec
# Solving time: 0.003993988037109375 sec
# Atoms : 4494
# Rules : 4083
#
# Cost: []
#
# Fix Point Solving Iteration: 1
# Encoding: ../encodings/sequential\merger_w_det_big_final.lp
# Satisfiable
# Total time: 0.024932861328125 sec
# CPU time: 0.015625 sec
# Grounding time: 0.021940231323242188 sec
# Solving time: 0.0029926300048828125 sec
# Atoms : 4993
# Rules : 4619
#
# Cost: []
#
# Fix Point Solving Iteration: 2
# Encoding: ../encodings/sequential\merger_w_det_big_final.lp
# Satisfiable
# Total time: 0.02097320556640625 sec
# CPU time: 0.03125 sec
# Grounding time: 0.017972946166992188 sec
# Solving time: 0.0030002593994140625 sec
# Atoms : 4494
# Rules : 4083
#
# Cost: []
#
# Fix Point Solving Iteration: 1
# Encoding: ../encodings/sequential\merger_w_det_big_final.lp
# Satisfiable
# Total time: 0.024967193603515625 sec
# CPU time: 0.015625 sec
# Grounding time: 0.021963119506835938 sec
# Solving time: 0.0030040740966796875 sec
# Atoms : 4993
# Rules : 4619
#
# Cost: []
#
# Fix Point Solving Iteration: 2
# Encoding: ../encodings/sequential\merger_w_det_big_final.lp
# Satisfiable
# Total time: 0.020944595336914062 sec
# CPU time: 0.015625 sec
# Grounding time: 0.017953872680664062 sec
# Solving time: 0.00299072265625 sec
# Atoms : 4494
# Rules : 4083
#
# Cost: []
#
# Fix Point Solving Iteration: 1
# Encoding: ../encodings/sequential\merger_w_det_big_final.lp
# Satisfiable
# Total time: 0.023935317993164062 sec
# CPU time: 0.03125 sec
# Grounding time: 0.02094268798828125 sec
# Solving time: 0.0029926300048828125 sec
# Atoms : 4993
# Rules : 4619
#
# Cost: []
#
# Fix Point Solving Iteration: 2
# Encoding: ../encodings/sequential\merger_w_det_big_final.lp
# Satisfiable
# Total time: 0.020969390869140625 sec
# CPU time: 0.015625 sec
# Grounding time: 0.017978668212890625 sec
# Solving time: 0.00299072265625 sec
# Atoms : 4494
# Rules : 4083
#
# Cost: []
#
# Fix Point Solving Iteration: 1
# Encoding: ../encodings/sequential\merger_w_det_big_final.lp
# Satisfiable
# Total time: 0.024961471557617188 sec
# CPU time: 0.03125 sec
# Grounding time: 0.020965576171875 sec
# Solving time: 0.0039958953857421875 sec
# Atoms : 4993
# Rules : 4619
#
# Cost: []
#
# Fix Point Solving Iteration: 2
# Encoding: ../encodings/sequential\merger_w_det_big_final.lp
# Satisfiable
# Total time: 0.020944595336914062 sec
# CPU time: 0.015625 sec
# Grounding time: 0.01795196533203125 sec
# Solving time: 0.0029926300048828125 sec
# Atoms : 4494
# Rules : 4083
#
# Cost: []
#
# Fix Point Solving Iteration: 1
# Encoding: ../encodings/sequential\merger_w_det_big_final.lp
# Satisfiable
# Total time: 0.024965286254882812 sec
# CPU time: 0.03125 sec
# Grounding time: 0.021961212158203125 sec
# Solving time: 0.0030040740966796875 sec
# Atoms : 4993
# Rules : 4619
#
# Cost: []
#
# Fix Point Solving Iteration: 2
# Encoding: ../encodings/sequential\merger_w_det_big_final.lp
# Satisfiable
# Total time: 0.02197265625 sec
# CPU time: 0.03125 sec
# Grounding time: 0.017984390258789062 sec
# Solving time: 0.0039882659912109375 sec
# Atoms : 4494
# Rules : 4083
#
# Cost: []
#
# Fix Point Solving Iteration: 1
# Encoding: ../encodings/sequential\merger_w_det_big_final.lp
# Satisfiable
# Total time: 0.023956298828125 sec
# CPU time: 0.015625 sec
# Grounding time: 0.020965576171875 sec
# Solving time: 0.00299072265625 sec
# Atoms : 4993
# Rules : 4619
#
# Cost: []
#
# Fix Point Solving Iteration: 2
# Encoding: ../encodings/sequential\merger_w_det_big_final.lp
# Satisfiable
# Total time: 0.021974563598632812 sec
# CPU time: 0.03125 sec
# Grounding time: 0.017971038818359375 sec
# Solving time: 0.0040035247802734375 sec
# Atoms : 4494
# Rules : 4083
#
# Cost: []
#
# Fix Point Solving Iteration: 1
# Encoding: ../encodings/sequential\merger_w_det_big_final.lp
# Satisfiable
# Total time: 0.02396392822265625 sec
# CPU time: 0.015625 sec
# Grounding time: 0.020975112915039062 sec
# Solving time: 0.0029888153076171875 sec
# Atoms : 4993
# Rules : 4619
#
# Cost: []
#
# Fix Point Solving Iteration: 2
# Encoding: ../encodings/sequential\merger_w_det_big_final.lp
# Satisfiable
# Total time: 0.021970748901367188 sec
# CPU time: 0.015625 sec
# Grounding time: 0.017972946166992188 sec
# Solving time: 0.003997802734375 sec
# Atoms : 4494
# Rules : 4083
#
# Cost: []
# [0.04778099060058594,
#  0.04689788818359375,
#  0.06248664855957031,
#  0.04688262939453125,
#  0.03524589538574219,
#  0.054149627685546875,
#  0.04689216613769531,
#  0.0478973388671875,
#  0.04787445068359375,
#  0.050872802734375,
#  0.048862457275390625,
#  0.04990386962890625,
#  0.04892539978027344,
#  0.0449066162109375,
#  0.045879364013671875,
#  0.04491233825683594,
#  0.04491424560546875,
#  0.045932769775390625,
#  0.04590797424316406,
#  0.0458984375,
#  0.04692840576171875,
#  0.0468902587890625,
#  0.044910430908203125,
#  0.04487800598144531,
#  0.04388236999511719,
#  0.04587745666503906,
#  0.04587554931640625,
#  0.04687309265136719,
#  0.046905517578125,
#  0.04593658447265625,
#  0.04392433166503906,
#  0.045902252197265625,
#  0.04486656188964844,
#  0.045879364013671875,
#  0.04687309265136719,
#  0.046875,
#  0.0468597412109375,
#  0.04587554931640625,
#  0.03275489807128906,
#  0.04686546325683594,
#  0.046863555908203125,
#  0.05672645568847656,
#  0.03958702087402344,
#  0.046863555908203125,
#  0.05847740173339844,
#  0.04392242431640625,
#  0.046875,
#  0.045925140380859375,
#  0.04593467712402344,
#  0.046871185302734375,
#  0.04593658447265625,
#  0.04589080810546875,
#  0.04489326477050781,
#  0.04688835144042969,
#  0.04587554931640625,
#  0.044879913330078125,
#  0.044879913330078125,
#  0.04587554931640625,
#  0.045879364013671875,
#  0.04587745666503906,
#  0.04587554931640625,
#  0.04593467712402344,
#  0.04393959045410156,
#  0.044921875,
#  0.04393577575683594,
#  0.045940399169921875,
#  0.04593658447265625,
#  0.04693412780761719,
#  0.044879913330078125,
#  0.046871185302734375,
#  0.04592704772949219,
#  0.04586601257324219,
#  0.044879913330078125,
#  0.044872283935546875,
#  0.04487800598144531,
#  0.04490852355957031,
#  0.04490089416503906,
#  0.04487800598144531,
#  0.043468475341796875,
#  0.04686546325683594,
#  0.04689598083496094,
#  0.03726005554199219,
#  0.03530120849609375,
#  0.046863555908203125,
#  0.06125068664550781,
#  0.04587364196777344,
#  0.04587554931640625,
#  0.04388618469238281,
#  0.04687690734863281,
#  0.04587745666503906,
#  0.04587554931640625,
#  0.0448760986328125,
#  0.044864654541015625,
#  0.04587745666503906,
#  0.044879913330078125,
#  0.04388999938964844,
#  0.04388236999511719,
#  0.044879913330078125,
#  0.04488182067871094,
#  0.0458984375,
#  0.04490852355957031,
#  0.04586982727050781,
#  0.04587745666503906,
#  0.04587745666503906,
#  0.04388236999511719,
#  0.04587745666503906,
#  0.04587745666503906,
#  0.04487800598144531,
#  0.04590606689453125,
#  0.04693412780761719,
#  0.04590606689453125,
#  0.043880462646484375,
#  0.04387474060058594,
#  0.04587554931640625,
#  0.04388427734375,
#  0.044879913330078125,
#  0.0448760986328125,
#  0.04488182067871094,
#  0.030431747436523438,
#  0.03124237060546875,
#  0.031238555908203125,
#  0.04494667053222656,
#  0.03805351257324219,
#  0.046863555908203125,
#  0.058868408203125,
#  0.045879364013671875,
#  0.043880462646484375,
#  0.04487800598144531,
#  0.0448760986328125,
#  0.04388236999511719,
#  0.04388236999511719,
#  0.04587745666503906,
#  0.04586982727050781,
#  0.04489898681640625,
#  0.04590415954589844,
#  0.0449066162109375,
#  0.045909881591796875,
#  0.04490470886230469,
#  0.04685783386230469,
#  0.04388236999511719,
#  0.04587745666503906,
#  0.04587554931640625,
#  0.044887542724609375,
#  0.04388618469238281,
#  0.04587364196777344,
#  0.044879913330078125,
#  0.044887542724609375,
#  0.044879913330078125,
#  0.04587745666503906,
#  0.04388236999511719,
#  0.04388236999511719,
#  0.043880462646484375,
#  0.0438690185546875,
#  0.04587554931640625,
#  0.045925140380859375,
#  0.044910430908203125,
#  0.04587745666503906,
#  0.045928955078125,
#  0.038784027099609375,
#  0.046863555908203125,
#  0.05243682861328125,
#  0.04100990295410156,
#  0.04686546325683594,
#  0.03125762939453125,
#  0.056491851806640625,
#  0.046905517578125,
#  0.04490852355957031,
#  0.04492950439453125,
#  0.04593849182128906,
#  0.04689216613769531,
#  0.04590797424316406,
#  0.04690742492675781,
#  0.04491233825683594,
#  0.04593467712402344,
#  0.04492759704589844,
#  0.04686927795410156,
#  0.04590797424316406,
#  0.04691314697265625,
#  0.04590797424316406,
#  0.044879913330078125,
#  0.04487800598144531,
#  0.044879913330078125,
#  0.04587745666503906,
#  0.04587745666503906,
#  0.04487037658691406,
#  0.044879913330078125,
#  0.04487800598144531,
#  0.04487037658691406,
#  0.04587745666503906,
#  0.044879913330078125,
#  0.045864105224609375,
#  0.04587745666503906,
#  0.05085182189941406,
#  0.05286216735839844,
#  0.050861358642578125,
#  0.051860809326171875,
#  0.051860809326171875,
#  0.048915863037109375,
#  0.049510955810546875,
#  0.046966552734375,
#  0.049510955810546875,
#  0.048870086669921875,
#  0.04587745666503906,
#  0.04587745666503906,
#  0.04388236999511719,
#  0.047931671142578125,
#  0.04886817932128906,
#  0.04986763000488281,
#  0.04787445068359375,
#  0.046875,
#  0.046886444091796875,
#  0.045909881591796875,
#  0.04889488220214844,
#  0.04795646667480469,
#  0.048870086669921875,
#  0.046871185302734375,
#  0.04587745666503906,
#  0.04490852355957031,
#  0.04889488220214844,
#  0.05187797546386719,
#  0.048870086669921875,
#  0.046875,
#  0.04387855529785156,
#  0.04787445068359375,
#  0.047870635986328125,
#  0.046875,
#  0.04687309265136719,
#  0.04688262939453125,
#  0.045917510986328125,
#  0.04493904113769531,
#  0.048862457275390625,
#  0.0478668212890625,
#  0.04687309265136719,
#  0.04587554931640625,
#  0.046875,
#  0.035572052001953125,
#  0.05919075012207031,
#  0.04858207702636719,
#  0.04788780212402344,
#  0.04787254333496094,
#  0.04388236999511719,
#  0.046932220458984375,
#  0.04492950439453125,
#  0.04493904113769531,
#  0.04687309265136719,
#  0.048931121826171875,
#  0.0488739013671875,
#  0.047870635986328125,
#  0.04392433166503906,
#  0.04588890075683594,
#  0.04592704772949219,
#  0.04593658447265625,
#  0.04487419128417969,
#  0.04587364196777344,
#  0.045932769775390625,
#  0.045932769775390625,
#  0.04590797424316406,
#  0.04790306091308594,
#  0.04591560363769531,
#  0.054851531982421875,
#  0.04886817932128906,
#  0.04487800598144531,
#  0.044879913330078125,
#  0.04487800598144531,
#  0.04687309265136719,
#  0.04687690734863281,
#  0.04389762878417969,
#  0.04487800598144531,
#  0.04587554931640625,
#  0.04488372802734375,
#  0.04487800598144531,
#  0.044879913330078125,
#  0.04587745666503906,
#  0.04487800598144531,
#  0.03057098388671875,
#  0.04778099060058594,
#  0.04789543151855469,
#  0.04787254333496094,
#  0.04687690734863281,
#  0.04787254333496094,
#  0.049861907958984375,
#  0.045909881591796875,
#  0.04388236999511719,
#  0.044891357421875,
#  0.044887542724609375,
#  0.043872833251953125,
#  0.04487419128417969,
#  0.04787254333496094,
#  0.0478668212890625,
#  0.046875,
#  0.04687309265136719,
#  0.04689788818359375,
#  0.04587745666503906,
#  0.044879913330078125,
#  0.04593086242675781,
#  0.04593467712402344,
#  0.04593467712402344,
#  0.04589653015136719,
#  0.04587745666503906,
#  0.04886627197265625,
#  0.04687309265136719,
#  0.04690361022949219,
#  0.04785346984863281,
#  0.048900604248046875,
#  0.05188751220703125,
#  0.05087471008300781,
#  0.05285835266113281,
#  0.048931121826171875,
#  0.046489715576171875,
#  0.04487800598144531,
#  0.048870086669921875,
#  0.04693031311035156,
#  0.03141021728515625,
#  0.04798316955566406,
#  0.04855537414550781,
#  0.04689788818359375,
#  0.04697608947753906,
#  0.04494476318359375,
#  0.045902252197265625,
#  0.04590606689453125,
#  0.04587745666503906,
#  0.043888092041015625,
#  0.046875,
#  0.04587745666503906,
#  0.044879913330078125,
#  0.044879913330078125,
#  0.04689598083496094,
#  0.046939849853515625,
#  0.04792594909667969,
#  0.047893524169921875,
#  0.047954559326171875,
#  0.04793739318847656,
#  0.04788970947265625,
#  0.04587745666503906,
#  0.04587364196777344,
#  0.04486656188964844,
#  0.04588508605957031,
#  0.04787445068359375,
#  0.04587745666503906,
#  0.046875,
#  0.048908233642578125,
#  0.048870086669921875,
#  0.045928955078125,
#  0.045932769775390625,
#  0.047924041748046875,
#  0.04786491394042969,
#  0.04787254333496094,
#  0.04687309265136719,
#  0.04786109924316406,
#  0.044879913330078125,
#  0.044872283935546875,
#  0.029672622680664062,
#  0.04504585266113281,
#  0.03144073486328125,
#  0.044429779052734375,
#  0.04848289489746094,
#  0.04888153076171875,
#  0.04879188537597656,
#  0.04889678955078125,
#  0.0478515625,
#  0.04491233825683594,
#  0.04690361022949219,
#  0.04590606689453125,
#  0.04689979553222656,
#  0.04490470886230469,
#  0.04587364196777344,
#  0.04587554931640625,
#  0.0488739013671875,
#  0.04586982727050781,
#  0.047870635986328125,
#  0.047870635986328125,
#  0.04887199401855469,
#  0.04687309265136719,
#  0.04587745666503906,
#  0.04789924621582031,
#  0.04892158508300781,
#  0.046905517578125,
#  0.04590415954589844,
#  0.0468902587890625,
#  0.04393577575683594,
#  0.04488182067871094,
#  0.045886993408203125,
#  0.044879913330078125,
#  0.04488182067871094,
#  0.04388427734375,
#  0.04387855529785156,
#  0.043880462646484375,
#  0.04387664794921875,
#  0.043880462646484375,
#  0.042896270751953125,
#  0.04466438293457031,
#  0.037990570068359375,
#  0.05927467346191406,
#  0.05031013488769531,
#  0.04999542236328125,
#  0.050983428955078125,
#  0.053859710693359375,
#  0.05286407470703125,
#  0.05487823486328125,
#  0.050891876220703125,
#  0.047863006591796875,
#  0.050868988037109375,
#  0.043880462646484375,
#  0.04487800598144531,
#  0.048858642578125,
#  0.04986572265625,
#  0.047878265380859375,
#  0.04986572265625,
#  0.048870086669921875,
#  0.04886817932128906,
#  0.04887199401855469,
#  0.046871185302734375,
#  0.046871185302734375,
#  0.04486274719238281,
#  0.045886993408203125,
#  0.04686737060546875,
#  0.046871185302734375,
#  0.04587745666503906,
#  0.043880462646484375,
#  0.04590797424316406,
#  0.04992103576660156,
#  0.04587745666503906,
#  0.04687309265136719,
#  0.045864105224609375,
#  0.043910980224609375,
#  0.04493904113769531,
#  0.04492950439453125,
#  0.04690361022949219,
#  0.04541969299316406,
#  0.03631591796875,
#  0.046863555908203125,
#  0.058658599853515625,
#  0.0500640869140625,
#  0.05460357666015625,
#  0.051910400390625,
#  0.04886627197265625,
#  0.04687690734863281,
#  0.04487800598144531,
#  0.045917510986328125,
#  0.04789924621582031,
#  0.046901702880859375,
#  0.04890632629394531,
#  0.04693031311035156,
#  0.044879913330078125,
#  0.04486846923828125,
#  0.04486274719238281,
#  0.04486846923828125,
#  0.04587745666503906,
#  0.04585456848144531,
#  0.04487800598144531,
#  0.04487037658691406,
#  0.04587554931640625,
#  0.044879913330078125,
#  0.04487419128417969,
#  0.04486846923828125,
#  0.0448760986328125,
#  0.04488182067871094,
#  0.04388236999511719,
#  0.044879913330078125,
#  0.04587554931640625,
#  0.046875,
#  0.0448760986328125,
#  0.04587554931640625,
#  0.04386711120605469,
#  0.044879913330078125,
#  0.04387664794921875,
#  0.04587745666503906,
#  0.038700103759765625,
#  0.031244277954101562,
#  0.031240463256835938,
#  0.03704643249511719,
#  0.030078887939453125,
#  0.046863555908203125,
#  0.0457916259765625,
#  0.04587554931640625,
#  0.044879913330078125,
#  0.046875,
#  0.04587364196777344,
#  0.04887962341308594,
#  0.048870086669921875,
#  0.04986763000488281,
#  0.05086326599121094,
#  0.05187797546386719,
#  0.05086517333984375,
#  0.04889678955078125,
#  0.04892158508300781,
#  0.045932769775390625,
#  0.046932220458984375,
#  0.04590415954589844,
#  0.04593467712402344,
#  0.04587745666503906,
#  0.04488182067871094,
#  0.04593467712402344,
#  0.04590606689453125,
#  0.04591178894042969,
#  0.04490470886230469,
#  0.04590606689453125,
#  0.04693794250488281,
#  0.04593086242675781,
#  0.04593467712402344]

# %%
print(max(li))
print(min(li))
print(max(li)-min(li))
print(np.var(li))
print(np.std(li))
print(np.std(li)*3)
print(np.mean(li))
print(np.median(li))
plt.hist(li, bins=15)
# Out:
# 0.06248664855957031
# 0.029672622680664062
# 0.03281402587890625
# 1.4230088390526363e-05
# 0.003772278938589558
# 0.011316836815768675
# 0.04612287902832031
# 0.04590415954589844
# (array([ 11.,   1.,   3.,   5.,   3.,   1., 146., 209.,  76.,  21.,  10.,
#           5.,   2.,   5.,   2.]),
#  array([0.02967262, 0.03186022, 0.03404783, 0.03623543, 0.03842303,
#         0.04061063, 0.04279823, 0.04498583, 0.04717344, 0.04936104,
#         0.05154864, 0.05373624, 0.05592384, 0.05811145, 0.06029905,
#         0.06248665]),
#  <BarContainer object of 15 artists>)

# %%
print(np.sqrt(np.var(li)))
count = 0
for i in li:
    if i-np.mean(li)>=-3*np.std(li) and i-np.mean(li)<=3*np.std(li):
        count += 1
print(count/float(len(li)))
# Out:
# 0.003772278938589558
# 0.962

# %%
dct = {}
for c in ['n robots',
          'n pos',
          'longest path',
          'n vcs',
          'n robots had vcs',
          'n ecs',
          'n robots had ecs',
          'n fake ecs',
          'n robots had fake ecs']:
    dct[c] = [0.0]*len(rows)
bm_df = pd.DataFrame(dct, index=rows)
bm_df = bm_df.astype(int)

# %%
for i, bm in enumerate(benchmarks):
    bm_id = i+1
    #m, _ = merger.switchPlans(merger.getBenchmarkModel(bm), small=True)
    #m, _ = merger.switchPlans(merger.getBenchmarkModel(bm), small=False)
    #m, _ = merger.convertToAsprilo(m,bm)
    metrics, _ = merger.retrieveBenchmarkMetrics(bm)
    bm_df.loc[bm_df.index[i]] = [metrics['n_r'],
                           metrics['n_p'],
                           metrics['n_lp'],
                           metrics['n_vc'],
                           metrics['r_vc'],
                           metrics['n_ec'],
                           metrics['r_ec'],
                           metrics['n_fec'],
                           metrics['r_fec']]
#bm_df.to_csv('../benchmark_data/benchmark_metrics/bm_metrics.csv')
bm_df
# Out:
# Encoding: ../encodings/sequential\inputter.lp
# Satisfiable
# Total time: 0.00096893310546875 sec
# CPU time: 0.0 sec
# Grounding time: 0.00096893310546875 sec
# Solving time: 0.0 sec
# Atoms : 26
# Rules : 26
#
# Encoding: ../encodings/sequential\retrieve_bm_metrics.lp
# Satisfiable
# Total time: 0.00798797607421875 sec
# CPU time: 0.0 sec
# Grounding time: 0.00798797607421875 sec
# Solving time: 0.0 sec
# Atoms : 23
# Rules : 23
#
# Encoding: ../encodings/sequential\inputter.lp
# Satisfiable
# Total time: 0.0009975433349609375 sec
# CPU time: 0.0 sec
# Grounding time: 0.0009975433349609375 sec
# Solving time: 0.0 sec
# Atoms : 62
# Rules : 62
#
# Encoding: ../encodings/sequential\retrieve_bm_metrics.lp
# Satisfiable
# Total time: 0.001003265380859375 sec
# CPU time: 0.0 sec
# Grounding time: 0.001003265380859375 sec
# Solving time: 0.0 sec
# Atoms : 59
# Rules : 59
#
# Encoding: ../encodings/sequential\inputter.lp
# Satisfiable
# Total time: 0.0009975433349609375 sec
# CPU time: 0.0 sec
# Grounding time: 0.0009975433349609375 sec
# Solving time: 0.0 sec
# Atoms : 52
# Rules : 52
#
# Encoding: ../encodings/sequential\retrieve_bm_metrics.lp
# Satisfiable
# Total time: 0.0009613037109375 sec
# CPU time: 0.0 sec
# Grounding time: 0.0009613037109375 sec
# Solving time: 0.0 sec
# Atoms : 44
# Rules : 44
#
# Encoding: ../encodings/sequential\inputter.lp
# Satisfiable
# Total time: 0.0 sec
# CPU time: 0.0 sec
# Grounding time: 0.0 sec
# Solving time: 0.0 sec
# Atoms : 28
# Rules : 28
#
# Encoding: ../encodings/sequential\retrieve_bm_metrics.lp
# Satisfiable
# Total time: 0.015661239624023438 sec
# CPU time: 0.015625 sec
# Grounding time: 0.015661239624023438 sec
# Solving time: 0.0 sec
# Atoms : 43
# Rules : 43
#
# Encoding: ../encodings/sequential\inputter.lp
# Satisfiable
# Total time: 0.0033168792724609375 sec
# CPU time: 0.0 sec
# Grounding time: 0.0033168792724609375 sec
# Solving time: 0.0 sec
# Atoms : 42
# Rules : 42
#
# Encoding: ../encodings/sequential\retrieve_bm_metrics.lp
# Satisfiable
# Total time: 0.000995635986328125 sec
# CPU time: 0.0 sec
# Grounding time: 0.000995635986328125 sec
# Solving time: 0.0 sec
# Atoms : 45
# Rules : 45
#
# Encoding: ../encodings/sequential\inputter.lp
# Satisfiable
# Total time: 0.000995635986328125 sec
# CPU time: 0.0 sec
# Grounding time: 0.000995635986328125 sec
# Solving time: 0.0 sec
# Atoms : 54
# Rules : 54
#
# Encoding: ../encodings/sequential\retrieve_bm_metrics.lp
# Satisfiable
# Total time: 0.001995086669921875 sec
# CPU time: 0.0 sec
# Grounding time: 0.001018524169921875 sec
# Solving time: 0.0009765625 sec
# Atoms : 57
# Rules : 57
#
# Encoding: ../encodings/sequential\inputter.lp
# Satisfiable
# Total time: 0.0019969940185546875 sec
# CPU time: 0.0 sec
# Grounding time: 0.001026153564453125 sec
# Solving time: 0.0009708404541015625 sec
# Atoms : 60
# Rules : 60
#
# Encoding: ../encodings/sequential\retrieve_bm_metrics.lp
# Satisfiable
# Total time: 0.001972198486328125 sec
# CPU time: 0.0 sec
# Grounding time: 0.001972198486328125 sec
# Solving time: 0.0 sec
# Atoms : 65
# Rules : 65
#
# Encoding: ../encodings/sequential\inputter.lp
# Satisfiable
# Total time: 0.0028667449951171875 sec
# CPU time: 0.0 sec
# Grounding time: 0.00128173828125 sec
# Solving time: 0.0015850067138671875 sec
# Atoms : 193
# Rules : 193
#
# Encoding: ../encodings/sequential\retrieve_bm_metrics.lp
# Satisfiable
# Total time: 0.0030193328857421875 sec
# CPU time: 0.0 sec
# Grounding time: 0.001995086669921875 sec
# Solving time: 0.0010242462158203125 sec
# Atoms : 186
# Rules : 186
#
# Encoding: ../encodings/sequential\inputter.lp
# Satisfiable
# Total time: 0.0009975433349609375 sec
# CPU time: 0.0 sec
# Grounding time: 0.0009975433349609375 sec
# Solving time: 0.0 sec
# Atoms : 74
# Rules : 74
#
# Encoding: ../encodings/sequential\retrieve_bm_metrics.lp
# Satisfiable
# Total time: 0.002994537353515625 sec
# CPU time: 0.015625 sec
# Grounding time: 0.002994537353515625 sec
# Solving time: 0.0 sec
# Atoms : 78
# Rules : 78
#
# Encoding: ../encodings/sequential\inputter.lp
# Satisfiable
# Total time: 0.00202178955078125 sec
# CPU time: 0.0 sec
# Grounding time: 0.00202178955078125 sec
# Solving time: 0.0 sec
# Atoms : 54
# Rules : 54
#
# Encoding: ../encodings/sequential\retrieve_bm_metrics.lp
# Satisfiable
# Total time: 0.0019779205322265625 sec
# CPU time: 0.0 sec
# Grounding time: 0.0019779205322265625 sec
# Solving time: 0.0 sec
# Atoms : 60
# Rules : 60
#
# Encoding: ../encodings/sequential\inputter.lp
# Satisfiable
# Total time: 0.0019664764404296875 sec
# CPU time: 0.0 sec
# Grounding time: 0.0019664764404296875 sec
# Solving time: 0.0 sec
# Atoms : 67
# Rules : 67
#
# Encoding: ../encodings/sequential\retrieve_bm_metrics.lp
# Satisfiable
# Total time: 0.0019931793212890625 sec
# CPU time: 0.0 sec
# Grounding time: 0.0019931793212890625 sec
# Solving time: 0.0 sec
# Atoms : 72
# Rules : 72
#
# Encoding: ../encodings/sequential\inputter.lp
# Satisfiable
# Total time: 0.001995086669921875 sec
# CPU time: 0.0 sec
# Grounding time: 0.001995086669921875 sec
# Solving time: 0.0 sec
# Atoms : 53
# Rules : 53
#
# Encoding: ../encodings/sequential\retrieve_bm_metrics.lp
# Satisfiable
# Total time: 0.001003265380859375 sec
# CPU time: 0.0 sec
# Grounding time: 0.001003265380859375 sec
# Solving time: 0.0 sec
# Atoms : 55
# Rules : 55
#
# Encoding: ../encodings/sequential\inputter.lp
# Satisfiable
# Total time: 0.012956619262695312 sec
# CPU time: 0.015625 sec
# Grounding time: 0.0099639892578125 sec
# Solving time: 0.0029926300048828125 sec
# Atoms : 1184
# Rules : 1184
#
# Encoding: ../encodings/sequential\retrieve_bm_metrics.lp
# Satisfiable
# Total time: 0.011945724487304688 sec
# CPU time: 0.015625 sec
# Grounding time: 0.008953094482421875 sec
# Solving time: 0.0029926300048828125 sec
# Atoms : 1212
# Rules : 1212
#
# Encoding: ../encodings/sequential\inputter.lp
# Satisfiable
# Total time: 0.022970199584960938 sec
# CPU time: 0.03125 sec
# Grounding time: 0.0169830322265625 sec
# Solving time: 0.0059871673583984375 sec
# Atoms : 2233
# Rules : 2233
#
# Encoding: ../encodings/sequential\retrieve_bm_metrics.lp
# Satisfiable
# Total time: 0.021970748901367188 sec
# CPU time: 0.015625 sec
# Grounding time: 0.014980316162109375 sec
# Solving time: 0.0069904327392578125 sec
# Atoms : 2394
# Rules : 2394
#
# Encoding: ../encodings/sequential\inputter.lp
# Satisfiable
# Total time: 0.0010013580322265625 sec
# CPU time: 0.0 sec
# Grounding time: 0.0010013580322265625 sec
# Solving time: 0.0 sec
# Atoms : 34
# Rules : 34
#
# Encoding: ../encodings/sequential\retrieve_bm_metrics.lp
# Satisfiable
# Total time: 0.0030040740966796875 sec
# CPU time: 0.0 sec
# Grounding time: 0.0030040740966796875 sec
# Solving time: 0.0 sec
# Atoms : 41
# Rules : 41
#
# Encoding: ../encodings/sequential\inputter.lp
# Satisfiable
# Total time: 0.0019664764404296875 sec
# CPU time: 0.0 sec
# Grounding time: 0.00096893310546875 sec
# Solving time: 0.0009975433349609375 sec
# Atoms : 76
# Rules : 76
#
# Encoding: ../encodings/sequential\retrieve_bm_metrics.lp
# Satisfiable
# Total time: 0.001987457275390625 sec
# CPU time: 0.0 sec
# Grounding time: 0.0009899139404296875 sec
# Solving time: 0.0009975433349609375 sec
# Atoms : 80
# Rules : 80
#
# Encoding: ../encodings/sequential\inputter.lp
# Satisfiable
# Total time: 0.003993988037109375 sec
# CPU time: 0.0 sec
# Grounding time: 0.003993988037109375 sec
# Solving time: 0.0 sec
# Atoms : 256
# Rules : 256
#
# Encoding: ../encodings/sequential\retrieve_bm_metrics.lp
# Satisfiable
# Total time: 0.003986358642578125 sec
# CPU time: 0.015625 sec
# Grounding time: 0.0029888153076171875 sec
# Solving time: 0.0009975433349609375 sec
# Atoms : 263
# Rules : 263
#
# Encoding: ../encodings/sequential\inputter.lp
# Satisfiable
# Total time: 0.0019969940185546875 sec
# CPU time: 0.0 sec
# Grounding time: 0.0019969940185546875 sec
# Solving time: 0.0 sec
# Atoms : 107
# Rules : 107
#
# Encoding: ../encodings/sequential\retrieve_bm_metrics.lp
# Satisfiable
# Total time: 0.0029888153076171875 sec
# CPU time: 0.0 sec
# Grounding time: 0.0029888153076171875 sec
# Solving time: 0.0 sec
# Atoms : 122
# Rules : 122
#
# Encoding: ../encodings/sequential\inputter.lp
# Satisfiable
# Total time: 0.0029964447021484375 sec
# CPU time: 0.0 sec
# Grounding time: 0.0029964447021484375 sec
# Solving time: 0.0 sec
# Atoms : 265
# Rules : 265
#
# Encoding: ../encodings/sequential\retrieve_bm_metrics.lp
# Satisfiable
# Total time: 0.0049800872802734375 sec
# CPU time: 0.0 sec
# Grounding time: 0.0039825439453125 sec
# Solving time: 0.0009975433349609375 sec
# Atoms : 304
# Rules : 304
#
# Encoding: ../encodings/sequential\inputter.lp
# Satisfiable
# Total time: 0.010000228881835938 sec
# CPU time: 0.015625 sec
# Grounding time: 0.008005142211914062 sec
# Solving time: 0.001995086669921875 sec
# Atoms : 945
# Rules : 945
#
# Encoding: ../encodings/sequential\retrieve_bm_metrics.lp
# Satisfiable
# Total time: 0.009000778198242188 sec
# CPU time: 0.015625 sec
# Grounding time: 0.006008148193359375 sec
# Solving time: 0.0029926300048828125 sec
# Atoms : 890
# Rules : 890
#
# Encoding: ../encodings/sequential\inputter.lp
# Satisfiable
# Total time: 0.0050182342529296875 sec
# CPU time: 0.0 sec
# Grounding time: 0.00402069091796875 sec
# Solving time: 0.0009975433349609375 sec
# Atoms : 413
# Rules : 413
#
# Encoding: ../encodings/sequential\retrieve_bm_metrics.lp
# Satisfiable
# Total time: 0.005008697509765625 sec
# CPU time: 0.015625 sec
# Grounding time: 0.003017425537109375 sec
# Solving time: 0.00199127197265625 sec
# Atoms : 414
# Rules : 414
#
# Encoding: ../encodings/sequential\inputter.lp
# Satisfiable
# Total time: 0.03389739990234375 sec
# CPU time: 0.046875 sec
# Grounding time: 0.026914596557617188 sec
# Solving time: 0.0069828033447265625 sec
# Atoms : 3200
# Rules : 3200
#
# Encoding: ../encodings/sequential\retrieve_bm_metrics.lp
# Satisfiable
# Total time: 0.05485343933105469 sec
# CPU time: 0.046875 sec
# Grounding time: 0.04390907287597656 sec
# Solving time: 0.010944366455078125 sec
# Atoms : 3235
# Rules : 3235
#
# Encoding: ../encodings/sequential\inputter.lp
# Satisfiable
# Total time: 0.010982513427734375 sec
# CPU time: 0.0 sec
# Grounding time: 0.008985519409179688 sec
# Solving time: 0.0019969940185546875 sec
# Atoms : 1110
# Rules : 1110
#
# Encoding: ../encodings/sequential\retrieve_bm_metrics.lp
# Satisfiable
# Total time: 0.011936187744140625 sec
# CPU time: 0.015625 sec
# Grounding time: 0.008943557739257812 sec
# Solving time: 0.0029926300048828125 sec
# Atoms : 1123
# Rules : 1123
#
# Encoding: ../encodings/sequential\inputter.lp
# Satisfiable
# Total time: 0.0059833526611328125 sec
# CPU time: 0.0 sec
# Grounding time: 0.004985809326171875 sec
# Solving time: 0.0009975433349609375 sec
# Atoms : 408
# Rules : 408
#
# Encoding: ../encodings/sequential\retrieve_bm_metrics.lp
# Satisfiable
# Total time: 0.00501251220703125 sec
# CPU time: 0.0 sec
# Grounding time: 0.0040149688720703125 sec
# Solving time: 0.0009975433349609375 sec
# Atoms : 422
# Rules : 422
#
# Encoding: ../encodings/sequential\inputter.lp
# Satisfiable
# Total time: 0.027936935424804688 sec
# CPU time: 0.03125 sec
# Grounding time: 0.022937774658203125 sec
# Solving time: 0.0049991607666015625 sec
# Atoms : 2238
# Rules : 2238
#
# Encoding: ../encodings/sequential\retrieve_bm_metrics.lp
# Satisfiable
# Total time: 0.018917083740234375 sec
# CPU time: 0.015625 sec
# Grounding time: 0.012958526611328125 sec
# Solving time: 0.00595855712890625 sec
# Atoms : 2043
# Rules : 2043
#
# Encoding: ../encodings/sequential\inputter.lp
# Satisfiable
# Total time: 0.02197265625 sec
# CPU time: 0.015625 sec
# Grounding time: 0.017972946166992188 sec
# Solving time: 0.0039997100830078125 sec
# Atoms : 2130
# Rules : 2130
#
# Encoding: ../encodings/sequential\retrieve_bm_metrics.lp
# Satisfiable
# Total time: 0.023916244506835938 sec
# CPU time: 0.03125 sec
# Grounding time: 0.014972686767578125 sec
# Solving time: 0.008943557739257812 sec
# Atoms : 2250
# Rules : 2250
#       n robots  n pos  longest path  n vcs  n robots had vcs  n ecs  \
# BM1          1      5             5      0                 0      0
# BM2          2     14             7      0                 0      2
# BM3          2     10             5      1                 2      0
# BM4          4      8             2      1                 4      0
# BM5          2     10             5      2                 2      0
# BM6          4     12             3      2                 4      0
# BM7          3     15             5      3                 3      0
# BM8          6     48             9      9                 6      0
# BM9          3     19             7      3                 2      0
# BM10         3     13             5      1                 2      2
# BM11         3     17             6      4                 2      0
# BM12         2     13             8      1                 1      0
# BM13        10    341            48    102                 9      0
# BM14        20    684            55    135                18     26
# BM15         2      8             4      1                 2      0
# BM16         3     19             7      0                 0      4
# BM17         7     68            17      2                 4      6
# BM18         4     28             7      9                 4      0
# BM19         8     72            10     22                 8      4
# BM20        20    244            13     25                20      0
# BM21        12    104             9     13                12      0
# BM22        32    983            36    122                32      0
# BM23        16    327            22     56                16      0
# BM24         8    116            16     26                 8      0
# BM25        30    618            30     33                17      8
# BM26        30    615            26    126                28     40
#
#       n robots had ecs  n fake ecs  n robots had fake ecs
# BM1                  0           0                      0
# BM2                  2           0                      0
# BM3                  0           0                      0
# BM4                  0           0                      0
# BM5                  0           0                      0
# BM6                  0           0                      0
# BM7                  0           0                      0
# BM8                  0           0                      0
# BM9                  0           0                      0
# BM10                 2           0                      0
# BM11                 0           0                      0
# BM12                 0           0                      0
# BM13                 0           0                      0
# BM14                12          24                     12
# BM15                 0           2                      2
# BM16                 3           0                      0
# BM17                 5           2                      2
# BM18                 0           2                      4
# BM19                 8           4                      8
# BM20                 0          20                     20
# BM21                 0          20                     12
# BM22                 0           0                      0
# BM23                 0           0                      0
# BM24                 0           0                      0
# BM25                 7           2                      2
# BM26                26          42                     27

# %%
#pd.concat([df, bm_df], axis=1)
a = pd.read_csv('../benchmark_data/det_approach/det_approach.csv', index_col=0)
b = pd.read_csv('../benchmark_data/inc_approach/inc_approach.csv', index_col=0)
c = pd.read_csv('../benchmark_data/benchmark_metrics/bm_metrics.csv', index_col=0)
d = pd.read_csv('../benchmark_data/benchmark_metrics/bm_metrics_after_ps_small.csv', index_col=0)

e = pd.concat([a,b,c], axis=1)
f = e[['total','n vcs', 'n robots had vcs']].copy()
f['det wins'] = a['total'] - b['total'] < 0
d
# Out:
#       n robots  n pos  horizon  n vcs  n robots had vcs  n ecs  \
# BM1          1      5        5      0                 0      0
# BM2          2     12        6      0                 0      0
# BM3          2     10        5      1                 2      0
# BM4          4      8        2      1                 4      0
# BM5          2     10        5      2                 2      0
# BM6          4     12        3      2                 4      0
# BM7          3     15        5      3                 3      0
# BM8          6     48        9      9                 6      0
# BM9          3     19        7      3                 2      0
# BM10         3     11        4      0                 0      0
# BM11         3     17        6      4                 2      0
# BM12         2     13        7      0                 0      0
# BM13        10    341       47     82                 8      0
# BM14        20    326       32     32                 6      0
# BM15         2      4        2      0                 0      0
# BM16         3     11        6      0                 0      0
# BM17         7     32        9      0                 0      0
# BM18         4     20        5      6                 4      0
# BM19         8     56        7     12                 8      0
# BM20        20    124        7      8                 8      0
# BM21        12     56        5      4                 8      0
# BM22        32    983       36    122                32      0
# BM23        16    327       22     56                16      0
# BM24         8    116       16     26                 8      0
# BM25        30    538       26     18                 9      0
# BM26        30    250       17     16                11      0
#
#       n robots had ecs  n fake ecs  n robots had fake ecs
# BM1                  0           0                      0
# BM2                  0           0                      0
# BM3                  0           0                      0
# BM4                  0           0                      0
# BM5                  0           0                      0
# BM6                  0           0                      0
# BM7                  0           0                      0
# BM8                  0           0                      0
# BM9                  0           0                      0
# BM10                 0           0                      0
# BM11                 0           0                      0
# BM12                 0           0                      0
# BM13                 0           0                      0
# BM14                 0           0                      0
# BM15                 0           0                      0
# BM16                 0           0                      0
# BM17                 0           0                      0
# BM18                 0           0                      0
# BM19                 0           0                      0
# BM20                 0           0                      0
# BM21                 0           0                      0
# BM22                 0           0                      0
# BM23                 0           0                      0
# BM24                 0           0                      0
# BM25                 0           0                      0
# BM26                 0           2                      2

# %%
# creating the comparison table
def createComparisonTable(path, table, bm_table, name):
    selected_bm_ids = [12,13,19,21,22,24,25]
    ct = table.iloc[selected_bm_ids,:].copy()
    ct['dSOAP'] = 0.0
    results = readJSONs(path)
    for result in results:
        bm_id = int(result.data['instance'][0:2])-1
        if bm_id in selected_bm_ids:
            print(bm_id+1)
            m = Model(result.data['model'])
            metrics, _ = merger.retrieveBenchmarkMetrics(m)
            index = 'BM{}'.format(bm_id+1)
            ct.loc[index,'dSOAP'] = metrics['n_p']
    ct['dSOAP'] = ct['dSOAP'] - bm_table['n pos']
    ct = ct[['total','dSOAP']].copy()
    #ct.to_csv('../benchmark_data/comparison_data/{}.csv'.format(name))
    return ct
c1 = createComparisonTable("../benchmark_data/*det*/*.json", a, c, 'det')
c2 = createComparisonTable("../benchmark_data/*inc*/*.json", b, c, 'inc')
print(c1)
print(c2)
# Out:
# 13
# Encoding: ../encodings/sequential\inputter.lp
# Satisfiable
# Total time: 0.01296234130859375 sec
# CPU time: 0.015625 sec
# Grounding time: 0.00997161865234375 sec
# Solving time: 0.00299072265625 sec
# Atoms : 1244
# Rules : 1244
#
# Encoding: ../encodings/sequential\retrieve_bm_metrics.lp
# Satisfiable
# Total time: 0.01194000244140625 sec
# CPU time: 0.0 sec
# Grounding time: 0.008947372436523438 sec
# Solving time: 0.0029926300048828125 sec
# Atoms : 1160
# Rules : 1160
#
# 14
# Encoding: ../encodings/sequential\inputter.lp
# Satisfiable
# Total time: 0.012958526611328125 sec
# CPU time: 0.0 sec
# Grounding time: 0.009962081909179688 sec
# Solving time: 0.0029964447021484375 sec
# Atoms : 1174
# Rules : 1174
#
# Encoding: ../encodings/sequential\retrieve_bm_metrics.lp
# Satisfiable
# Total time: 0.009943008422851562 sec
# CPU time: 0.0 sec
# Grounding time: 0.00695037841796875 sec
# Solving time: 0.0029926300048828125 sec
# Atoms : 1083
# Rules : 1083
#
# 20
# Encoding: ../encodings/sequential\inputter.lp
# Satisfiable
# Total time: 0.00698089599609375 sec
# CPU time: 0.015625 sec
# Grounding time: 0.0059833526611328125 sec
# Solving time: 0.0009975433349609375 sec
# Atoms : 597
# Rules : 597
#
# Encoding: ../encodings/sequential\retrieve_bm_metrics.lp
# Satisfiable
# Total time: 0.0049762725830078125 sec
# CPU time: 0.0 sec
# Grounding time: 0.00299835205078125 sec
# Solving time: 0.0019779205322265625 sec
# Atoms : 452
# Rules : 452
#
# 22
# Encoding: ../encodings/sequential\inputter.lp
# Satisfiable
# Total time: 0.04886817932128906 sec
# CPU time: 0.046875 sec
# Grounding time: 0.0368804931640625 sec
# Solving time: 0.011987686157226562 sec
# Atoms : 4838
# Rules : 4838
#
# Encoding: ../encodings/sequential\retrieve_bm_metrics.lp
# Satisfiable
# Total time: 0.041866302490234375 sec
# CPU time: 0.046875 sec
# Grounding time: 0.02989959716796875 sec
# Solving time: 0.011966705322265625 sec
# Atoms : 4744
# Rules : 4744
#
# 23
# Encoding: ../encodings/sequential\inputter.lp
# Satisfiable
# Total time: 0.013973236083984375 sec
# CPU time: 0.015625 sec
# Grounding time: 0.010982513427734375 sec
# Solving time: 0.00299072265625 sec
# Atoms : 1470
# Rules : 1470
#
# Encoding: ../encodings/sequential\retrieve_bm_metrics.lp
# Satisfiable
# Total time: 0.014949798583984375 sec
# CPU time: 0.015625 sec
# Grounding time: 0.010961532592773438 sec
# Solving time: 0.0039882659912109375 sec
# Atoms : 1422
# Rules : 1422
#
# 25
# Encoding: ../encodings/sequential\inputter.lp
# Satisfiable
# Total time: 0.018924713134765625 sec
# CPU time: 0.015625 sec
# Grounding time: 0.014947891235351562 sec
# Solving time: 0.0039768218994140625 sec
# Atoms : 1707
# Rules : 1707
#
# Encoding: ../encodings/sequential\retrieve_bm_metrics.lp
# Satisfiable
# Total time: 0.012941360473632812 sec
# CPU time: 0.015625 sec
# Grounding time: 0.00897216796875 sec
# Solving time: 0.0039691925048828125 sec
# Atoms : 1445
# Rules : 1445
#
# 26
# Encoding: ../encodings/sequential\inputter.lp
# Satisfiable
# Total time: 0.009973526000976562 sec
# CPU time: 0.015625 sec
# Grounding time: 0.007978439331054688 sec
# Solving time: 0.001995086669921875 sec
# Atoms : 843
# Rules : 843
#
# Encoding: ../encodings/sequential\retrieve_bm_metrics.lp
# Satisfiable
# Total time: 0.00794219970703125 sec
# CPU time: 0.015625 sec
# Grounding time: 0.0059490203857421875 sec
# Solving time: 0.0019931793212890625 sec
# Atoms : 668
# Rules : 668
#
# 13
# Encoding: ../encodings/sequential\inputter.lp
# Satisfiable
# Total time: 0.015625 sec
# CPU time: 0.015625 sec
# Grounding time: 0.015625 sec
# Solving time: 0.0 sec
# Atoms : 1244
# Rules : 1244
#
# Encoding: ../encodings/sequential\retrieve_bm_metrics.lp
# Satisfiable
# Total time: 0.0029010772705078125 sec
# CPU time: 0.0 sec
# Grounding time: 0.0029010772705078125 sec
# Solving time: 0.0 sec
# Atoms : 1160
# Rules : 1160
#
# 14
# Encoding: ../encodings/sequential\inputter.lp
# Satisfiable
# Total time: 0.0139617919921875 sec
# CPU time: 0.015625 sec
# Grounding time: 0.010969161987304688 sec
# Solving time: 0.0029926300048828125 sec
# Atoms : 1186
# Rules : 1186
#
# Encoding: ../encodings/sequential\retrieve_bm_metrics.lp
# Satisfiable
# Total time: 0.01097869873046875 sec
# CPU time: 0.0 sec
# Grounding time: 0.007978439331054688 sec
# Solving time: 0.0030002593994140625 sec
# Atoms : 1097
# Rules : 1097
#
# 20
# Encoding: ../encodings/sequential\inputter.lp
# Satisfiable
# Total time: 0.008975982666015625 sec
# CPU time: 0.0 sec
# Grounding time: 0.007978439331054688 sec
# Solving time: 0.0009975433349609375 sec
# Atoms : 597
# Rules : 597
#
# Encoding: ../encodings/sequential\retrieve_bm_metrics.lp
# Satisfiable
# Total time: 0.004985809326171875 sec
# CPU time: 0.015625 sec
# Grounding time: 0.0039920806884765625 sec
# Solving time: 0.0009937286376953125 sec
# Atoms : 452
# Rules : 452
#
# 23
# Encoding: ../encodings/sequential\inputter.lp
# Satisfiable
# Total time: 0.00386810302734375 sec
# CPU time: 0.0 sec
# Grounding time: 0.00386810302734375 sec
# Solving time: 0.0 sec
# Atoms : 1470
# Rules : 1470
#
# Encoding: ../encodings/sequential\retrieve_bm_metrics.lp
# Satisfiable
# Total time: 0.015649795532226562 sec
# CPU time: 0.015625 sec
# Grounding time: 0.015649795532226562 sec
# Solving time: 0.0 sec
# Atoms : 1426
# Rules : 1426
#
# 25
# Encoding: ../encodings/sequential\inputter.lp
# Satisfiable
# Total time: 0.031213760375976562 sec
# CPU time: 0.03125 sec
# Grounding time: 0.015621185302734375 sec
# Solving time: 0.015592575073242188 sec
# Atoms : 2043
# Rules : 2043
#
# Encoding: ../encodings/sequential\retrieve_bm_metrics.lp
# Satisfiable
# Total time: 0.015651702880859375 sec
# CPU time: 0.015625 sec
# Grounding time: 0.0 sec
# Solving time: 0.015651702880859375 sec
# Atoms : 1777
# Rules : 1777
#
# 26
# Encoding: ../encodings/sequential\inputter.lp
# Satisfiable
# Total time: 0.015623092651367188 sec
# CPU time: 0.015625 sec
# Grounding time: 0.0 sec
# Solving time: 0.015623092651367188 sec
# Atoms : 1050
# Rules : 1050
#
# Encoding: ../encodings/sequential\retrieve_bm_metrics.lp
# Satisfiable
# Total time: 0.0 sec
# CPU time: 0.0 sec
# Grounding time: 0.0 sec
# Solving time: 0.0 sec
# Atoms : 868
# Rules : 868
#
#          total  dSOAP
# BM13  0.358728   20.0
# BM14  0.711729 -353.0
# BM20  0.074800 -116.0
# BM22  3.358461  546.0
# BM23  0.487207  120.0
# BM25  1.412695 -177.0
# BM26  1.770454 -429.0
#          total  dSOAP
# BM13  0.693697   20.0
# BM14  0.717611 -349.0
# BM20  0.072796 -116.0
# BM22  0.000000 -983.0
# BM23  2.826633  120.0
# BM25  0.649776  -65.0
# BM26  1.668715 -362.0

# %%
e = pd.concat([c1,c2,d], axis=1)
e = e.iloc[0:7,:].copy()
#e.to_csv('../benchmark_data/comparison_data/{}.csv'.format('comparison'))
e
# Out:
#          total  dSOAP     total  dSOAP  n robots  n pos  horizon  n vcs  \
# BM13  0.358728   20.0  0.693697   20.0        10    341       47     82
# BM14  0.711729 -353.0  0.717611 -349.0        20    326       32     32
# BM20  0.074800 -116.0  0.072796 -116.0        20    124        7      8
# BM22  3.358461  546.0  0.000000 -983.0        32    983       36    122
# BM23  0.487207  120.0  2.826633  120.0        16    327       22     56
# BM25  1.412695 -177.0  0.649776  -65.0        30    538       26     18
# BM26  1.770454 -429.0  1.668715 -362.0        30    250       17     16
#
#       n robots had vcs  n ecs  n robots had ecs  n fake ecs  \
# BM13                 8      0                 0           0
# BM14                 6      0                 0           0
# BM20                 8      0                 0           0
# BM22                32      0                 0           0
# BM23                16      0                 0           0
# BM25                 9      0                 0           0
# BM26                11      0                 0           2
#
#       n robots had fake ecs
# BM13                      0
# BM14                      0
# BM20                      0
# BM22                      0
# BM23                      0
# BM25                      0
# BM26                      2

# %%
cb = c1.copy()
cb['total'] = c1['total'] < c2['total']
cb['dSOAP'] = c1['dSOAP'] - c2['dSOAP']
#cb.to_csv('../benchmark_data/comparison_data/{}.csv'.format('boolean_comparison'))
cb
# Out:
#       total   dSOAP
# BM13   True     0.0
# BM14   True    -4.0
# BM20  False     0.0
# BM22  False  1529.0
# BM23   True     0.0
# BM25  False  -112.0
# BM26  False   -67.0

# %%
dct = {}
for c in ['total', 'ground', 'solve', 'n conflicts']:
    dct[c] = [0.0]*len(rows)
det_df = pd.DataFrame(dct, index=rows)
det_df = bm_df.astype(int)

# %%
# compare small and big deterministic waiter
for i, bm in enumerate(benchmarks):
    m, _ = merger.switchPlans(merger.getBenchmarkModel(bm), small=True)
    m, _ = merger.switchPlans(m, small=False)
    m, acc_stats = merger.fix_point_solve(m, merger.waiter_det_big, AccumulatedStats())
    occ = m.model.count("final_vertex")
    print("final_vertex occurences: {}\n".format(occ))
    m, acc_stats = merger.convertToAsprilo(m, bm, acc_stats)
    m, _ = merger.checkValidity(m)
    det_df.loc[det_df.index[i]] = [acc_stats.total, acc_stats.groundingTime, acc_stats.solvingTime, occ]
    
#det_df.to_csv('../benchmark_data/comparison_data/det_big_iso.csv')
det_df
# Out:
# Encoding: ../encodings/sequential\inputter.lp
# Satisfiable
# Total time: 0.000988006591796875 sec
# CPU time: 0.0 sec
# Grounding time: 0.000988006591796875 sec
# Solving time: 0.0 sec
# Atoms : 26
# Rules : 26
#
# Fix Point Solving Iteration: 1
# Encoding: ../encodings/sequential\merger_ps_small_final.lp
# Satisfiable
# Total time: 0.0030193328857421875 sec
# CPU time: 0.015625 sec
# Grounding time: 0.0030193328857421875 sec
# Solving time: 0.0 sec
# Atoms : 35
# Rules : 36
#
# Cost: [4, 5]
#
# Fix Point Solving Iteration: 2
# Encoding: ../encodings/sequential\merger_ps_small_final.lp
# Satisfiable
# Total time: 0.0029850006103515625 sec
# CPU time: 0.0 sec
# Grounding time: 0.0029850006103515625 sec
# Solving time: 0.0 sec
# Atoms : 35
# Rules : 36
#
# Cost: [4, 5]
#
# Fix Point Solving Iteration: 1
# Encoding: ../encodings/sequential\merger_ps_big_final.lp
# Satisfiable
# Total time: 0.003017425537109375 sec
# CPU time: 0.0 sec
# Grounding time: 0.003017425537109375 sec
# Solving time: 0.0 sec
# Atoms : 35
# Rules : 35
#
# Cost: [5]
#
# Fix Point Solving Iteration: 2
# Encoding: ../encodings/sequential\merger_ps_big_final.lp
# Satisfiable
# Total time: 0.0030002593994140625 sec
# CPU time: 0.015625 sec
# Grounding time: 0.0030002593994140625 sec
# Solving time: 0.0 sec
# Atoms : 35
# Rules : 35
#
# Cost: [5]
#
# Fix Point Solving Iteration: 1
# Encoding: ../encodings/sequential\merger_w_det_big_final.lp
# Satisfiable
# Total time: 0.0050144195556640625 sec
# CPU time: 0.0 sec
# Grounding time: 0.0050144195556640625 sec
# Solving time: 0.0 sec
# Atoms : 31
# Rules : 27
#
# Cost: []
#
# Fix Point Solving Iteration: 2
# Encoding: ../encodings/sequential\merger_w_det_big_final.lp
# Satisfiable
# Total time: 0.0039958953857421875 sec
# CPU time: 0.0 sec
# Grounding time: 0.0039958953857421875 sec
# Solving time: 0.0 sec
# Atoms : 31
# Rules : 27
#
# Cost: []
#
# final_vertex occurences: 0
#
# Encoding: ../encodings/sequential\outputter.lp
# Satisfiable
# Total time: 0.004985809326171875 sec
# CPU time: 0.0 sec
# Grounding time: 0.004985809326171875 sec
# Solving time: 0.0 sec
# Atoms : 23
# Rules : 22
#
# Encoding: ../encodings/sequential\validity_checker.lp
# Satisfiable
# Total time: 0.010866165161132812 sec
# CPU time: 0.0 sec
# Grounding time: 0.009868621826171875 sec
# Solving time: 0.0009975433349609375 sec
# Atoms : 57
# Rules : 57
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_8904/1987027824.py in <module>
#       8     m, acc_stats = merger.convertToAsprilo(m, bm, acc_stats)
#       9     m, _ = merger.checkValidity(m)
# ---> 10     det_df.loc[det_df.index[i]] = [acc_stats.total, acc_stats.groundingTime, acc_stats.solvingTime, occ]
#      11
#      12 #det_df.to_csv('../benchmark_data/comparison_data/det_big_iso.csv')
#
# ~\miniconda3\envs\py39\lib\site-packages\pandas\core\indexing.py in __setitem__(self, key, value)
#     714
#     715         iloc = self if self.name == "iloc" else self.obj.iloc
# --> 716         iloc._setitem_with_indexer(indexer, value, self.name)
#     717
#     718     def _validate_key(self, key, axis: int):
#
# ~\miniconda3\envs\py39\lib\site-packages\pandas\core\indexing.py in _setitem_with_indexer(self, indexer, value, name)
#    1686         if take_split_path:
#    1687             # We have to operate column-wise
# -> 1688             self._setitem_with_indexer_split_path(indexer, value, name)
#    1689         else:
#    1690             self._setitem_single_block(indexer, value, name)
#
# ~\miniconda3\envs\py39\lib\site-packages\pandas\core\indexing.py in _setitem_with_indexer_split_path(self, indexer, value, name)
#    1768
#    1769             else:
# -> 1770                 raise ValueError(
#    1771                     "Must have equal len keys and value "
#    1772                     "when setting with an iterable"
#
# ValueError: Must have equal len keys and value when setting with an iterable

# %%
det_small = pd.read_csv('../benchmark_data/comparison_data/det_small_iso.csv', index_col=0)
det_big = pd.read_csv('../benchmark_data/comparison_data/det_big_iso.csv', index_col=0)
det_small_inc = pd.read_csv('../benchmark_data/comparison_data/det_small_inc_iso.csv', index_col=0)
#dif_df = det_small.copy()
#dif_df['total'] = det_small['total'] - det_big['total']
#dif_df['total']

# %%
det_small['total']-det_big['total']

# %%
inc = pd.read_csv('../benchmark_data/comparison_data/inc.csv', index_col=0)
det = pd.read_csv('../benchmark_data/comparison_data/det.csv', index_col=0)
#(det-inc).to_csv('../benchmark_data/comparison_data/det-inc.csv')
