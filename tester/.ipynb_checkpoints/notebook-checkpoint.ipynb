# %% [markdown]
# # Evaluation
#
# doing evaluation stuff here...

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from iclingo import Clingo, Model
import funcs
from funcs import BMDataFormat, AccumulatedStats
import matplotlib.pyplot as plt
import numpy as np
import os
import files
import glob
import json

# %%
#create a data frame
benchmarks = funcs.getAllBenchmarks('../benchmarks')
cols = ['total','ground','solve']
rows = ['BM{}'.format(i+1) for i, bm in enumerate(benchmarks)]
dct = {}
for c in cols:
    dct[c] = [0.0]*len(rows)
df = pd.DataFrame(dct, index=rows)
#df.to_csv('../benchmark_data/' + encoding + '.csv')

# %%
# reading json benchmark data
def readJSONs(path):
    files = glob.glob(path)
    bmdfs = []
    for file in files:
        bmdfs.append(BMDataFormat())
        bmdfs[-1].load(file)
    return bmdfs
bmdfs = readJSONs("../benchmark_data/*det*/*.json")

# %%
# insert benchmark data into data frame
for bmdf in bmdfs:
    df.loc[df.index[int(bmdf.data['instance'][0:2])-1]] = [
                  bmdf.data['statistics']['total'],
                  bmdf.data['statistics']['groundingTime'],
                  bmdf.data['statistics']['solvingTime']
                 ]
#df.to_csv('../benchmark_data/merger_ps_rec4_small+merger_w_det2/merger_ps_rec4_small+merger_w_det2.csv')
df
# Out:
#          total    ground     solve
# BM1   0.011969  0.009975  0.001993
# BM2   0.013960  0.012951  0.001009
# BM3   0.010937  0.009937  0.000999
# BM4   0.000000  0.000000  0.000000
# BM5   0.012930  0.011932  0.000998
# BM6   0.010971  0.010971  0.000000
# BM7   0.011969  0.011969  0.000000
# BM8   0.018948  0.016951  0.001997
# BM9   0.013962  0.011965  0.001997
# BM10  0.018950  0.017954  0.000996
# BM11  0.011971  0.010973  0.000998
# BM12  0.015963  0.015963  0.000000
# BM13  0.199526  0.162117  0.037409
# BM14  0.782887  0.261271  0.521616
# BM15  0.016985  0.016985  0.000000
# BM16  0.026924  0.023933  0.002991
# BM17  0.024933  0.023937  0.000996
# BM18  0.020941  0.019943  0.000998
# BM19  0.032909  0.027924  0.004986
# BM20  0.059021  0.037086  0.021935
# BM21  0.026979  0.025011  0.001968
# BM22  0.394056  0.365082  0.028975
# BM23  0.088764  0.078802  0.009962
# BM24  0.028925  0.024937  0.003988
# BM25  0.424944  0.190491  0.234453
# BM26  2.273167  0.302958  1.970209

# %%
from merger import Merger
# initialize merger
merger = Merger("../encodings/sequential", "../benchmark_data")
def merge(benchmark_id):
        benchmark = benchmarks[benchmark_id-1]
        return merger.merge(benchmark, vizualize=True, save_data=True, deterministic_waiter=False, check_validity=False)
        
def mergeAll(exclude=[22,23,26]):
    for i in range(len(benchmarks)):
        benchmark_id = i+1
        benchmark = benchmarks[i]
        if benchmark_id in exclude:
            continue
        print("################## {} ###################".format(benchmark))
        merger.merge(benchmark, vizualize=False, save_data=False, automated=True, deterministic_waiter=False, check_validity=True)

# %%
# test merging here
#m, _ = merger.merge(benchmarks[26-1], vizualize=True, save_data=False, automated=False, deterministic_waiter=True, check_validity=False)
m, _ = merger.convertToPositions(merger.getBenchmarkModel(benchmarks[14-1]))
m, _ = merger.solve(m, merger.plan_switcher_naive, AccumulatedStats())
m, _ = merger.convertToAsprilo(m, benchmarks[14-1])
merger.vizualize(m)
s, _ = merger.retrieveBenchmarkMetrics(m)
s
# Out:
# Encoding: ../encodings/sequential\inputter.lp
# Satisfiable
# Total time: 0.029918670654296875 sec
# CPU time: 0.03125 sec
# Grounding time: 0.023935317993164062 sec
# Solving time: 0.0059833526611328125 sec
# Atoms : 2233
# Rules : 2233
#
# Encoding: ../encodings/sequential\merger_ps_1w.lp
# Satisfiable
# Total time: 0.013683319091796875 sec
# CPU time: 0.0 sec
# Grounding time: 0.013683319091796875 sec
# Solving time: 0.0 sec
# Atoms : 2903
# Rules : 2903
#
# Encoding: ../encodings/sequential\outputter.lp
# Satisfiable
# Total time: 0.03124237060546875 sec
# CPU time: 0.03125 sec
# Grounding time: 0.015621185302734375 sec
# Solving time: 0.015621185302734375 sec
# Atoms : 1592
# Rules : 1591
#
# Encoding: ../encodings/sequential\inputter.lp
# Satisfiable
# Total time: 0.027923583984375 sec
# CPU time: 0.03125 sec
# Grounding time: 0.018947601318359375 sec
# Solving time: 0.008975982666015625 sec
# Atoms : 2677
# Rules : 2677
#
# Encoding: ../encodings/sequential\retrieve_bm_metrics.lp
# Satisfiable
# Total time: 0.04288482666015625 sec
# CPU time: 0.046875 sec
# Grounding time: 0.033908843994140625 sec
# Solving time: 0.008975982666015625 sec
# Atoms : 3403
# Rules : 3403
# {'n_r': 20,
#  'n_p': 1094,
#  'n_lp': 55,
#  'n_vc': 153,
#  'r_vc': 13,
#  'n_ec': 0,
#  'r_ec': 0,
#  'n_fec': 0,
#  'r_fec': 0}

# %%
dct = {}
for c in ['n robots',
          'n pos',
          'longest path',
          'n vcs',
          'n robots had vcs',
          'n ecs',
          'n robots had ecs',
          'n fake ecs',
          'n robots had fake ecs']:
    dct[c] = [0.0]*len(rows)
bm_df = pd.DataFrame(dct, index=rows)
bm_df = bm_df.astype(int)

# %%
for i, bm in enumerate(benchmarks):
    bm_id = i+1
    #m, _ = merger.switchPlans(merger.getBenchmarkModel(bm), small=True)
    #m, _ = merger.convertToAsprilo(m,bm)
    metrics, _ = merger.retrieveBenchmarkMetrics(bm)
    bm_df.loc[bm_df.index[i]] = [metrics['n_r'],
                           metrics['n_p'],
                           metrics['n_lp'],
                           metrics['n_vc'],
                           metrics['r_vc'],
                           metrics['n_ec'],
                           metrics['r_ec'],
                           metrics['n_fec'],
                           metrics['r_fec']]
#bm_df.to_csv('../benchmark_data/benchmark_metrics/bm_metrics.csv')
bm_df
# Out:
# Encoding: ../encodings/sequential\inputter.lp
# Satisfiable
# Total time: 0.003021240234375 sec
# CPU time: 0.0 sec
# Grounding time: 0.002025604248046875 sec
# Solving time: 0.000995635986328125 sec
# Atoms : 26
# Rules : 26
#
# Encoding: ../encodings/sequential\retrieve_bm_metrics.lp
# Satisfiable
# Total time: 0.00399017333984375 sec
# CPU time: 0.0 sec
# Grounding time: 0.00299072265625 sec
# Solving time: 0.00099945068359375 sec
# Atoms : 23
# Rules : 23
#
# Encoding: ../encodings/sequential\inputter.lp
# Satisfiable
# Total time: 0.002964019775390625 sec
# CPU time: 0.0 sec
# Grounding time: 0.002964019775390625 sec
# Solving time: 0.0 sec
# Atoms : 62
# Rules : 62
#
# Encoding: ../encodings/sequential\retrieve_bm_metrics.lp
# Satisfiable
# Total time: 0.003021240234375 sec
# CPU time: 0.0 sec
# Grounding time: 0.003021240234375 sec
# Solving time: 0.0 sec
# Atoms : 59
# Rules : 59
#
# Encoding: ../encodings/sequential\inputter.lp
# Satisfiable
# Total time: 0.00202178955078125 sec
# CPU time: 0.0 sec
# Grounding time: 0.0010242462158203125 sec
# Solving time: 0.0009975433349609375 sec
# Atoms : 52
# Rules : 52
#
# Encoding: ../encodings/sequential\retrieve_bm_metrics.lp
# Satisfiable
# Total time: 0.00299072265625 sec
# CPU time: 0.0 sec
# Grounding time: 0.0019683837890625 sec
# Solving time: 0.0010223388671875 sec
# Atoms : 44
# Rules : 44
#
# Encoding: ../encodings/sequential\inputter.lp
# Satisfiable
# Total time: 0.000995635986328125 sec
# CPU time: 0.0 sec
# Grounding time: 0.000995635986328125 sec
# Solving time: 0.0 sec
# Atoms : 28
# Rules : 28
#
# Encoding: ../encodings/sequential\retrieve_bm_metrics.lp
# Satisfiable
# Total time: 0.00202178955078125 sec
# CPU time: 0.0 sec
# Grounding time: 0.00202178955078125 sec
# Solving time: 0.0 sec
# Atoms : 43
# Rules : 43
#
# Encoding: ../encodings/sequential\inputter.lp
# Satisfiable
# Total time: 0.000995635986328125 sec
# CPU time: 0.0 sec
# Grounding time: 0.000995635986328125 sec
# Solving time: 0.0 sec
# Atoms : 42
# Rules : 42
#
# Encoding: ../encodings/sequential\retrieve_bm_metrics.lp
# Satisfiable
# Total time: 0.0019855499267578125 sec
# CPU time: 0.0 sec
# Grounding time: 0.0019855499267578125 sec
# Solving time: 0.0 sec
# Atoms : 45
# Rules : 45
#
# Encoding: ../encodings/sequential\inputter.lp
# Satisfiable
# Total time: 0.0009975433349609375 sec
# CPU time: 0.0 sec
# Grounding time: 0.0009975433349609375 sec
# Solving time: 0.0 sec
# Atoms : 54
# Rules : 54
#
# Encoding: ../encodings/sequential\retrieve_bm_metrics.lp
# Satisfiable
# Total time: 0.001995086669921875 sec
# CPU time: 0.015625 sec
# Grounding time: 0.001995086669921875 sec
# Solving time: 0.0 sec
# Atoms : 57
# Rules : 57
#
# Encoding: ../encodings/sequential\inputter.lp
# Satisfiable
# Total time: 0.001995086669921875 sec
# CPU time: 0.0 sec
# Grounding time: 0.00099945068359375 sec
# Solving time: 0.000995635986328125 sec
# Atoms : 60
# Rules : 60
#
# Encoding: ../encodings/sequential\retrieve_bm_metrics.lp
# Satisfiable
# Total time: 0.004009246826171875 sec
# CPU time: 0.0 sec
# Grounding time: 0.0029926300048828125 sec
# Solving time: 0.0010166168212890625 sec
# Atoms : 65
# Rules : 65
#
# Encoding: ../encodings/sequential\inputter.lp
# Satisfiable
# Total time: 0.0029926300048828125 sec
# CPU time: 0.015625 sec
# Grounding time: 0.00201416015625 sec
# Solving time: 0.0009784698486328125 sec
# Atoms : 193
# Rules : 193
#
# Encoding: ../encodings/sequential\retrieve_bm_metrics.lp
# Satisfiable
# Total time: 0.002994537353515625 sec
# CPU time: 0.0 sec
# Grounding time: 0.001995086669921875 sec
# Solving time: 0.00099945068359375 sec
# Atoms : 186
# Rules : 186
#
# Encoding: ../encodings/sequential\inputter.lp
# Satisfiable
# Total time: 0.001995086669921875 sec
# CPU time: 0.0 sec
# Grounding time: 0.001995086669921875 sec
# Solving time: 0.0 sec
# Atoms : 74
# Rules : 74
#
# Encoding: ../encodings/sequential\retrieve_bm_metrics.lp
# Satisfiable
# Total time: 0.001995086669921875 sec
# CPU time: 0.015625 sec
# Grounding time: 0.001995086669921875 sec
# Solving time: 0.0 sec
# Atoms : 78
# Rules : 78
#
# Encoding: ../encodings/sequential\inputter.lp
# Satisfiable
# Total time: 0.0010242462158203125 sec
# CPU time: 0.0 sec
# Grounding time: 0.0010242462158203125 sec
# Solving time: 0.0 sec
# Atoms : 54
# Rules : 54
#
# Encoding: ../encodings/sequential\retrieve_bm_metrics.lp
# Satisfiable
# Total time: 0.0 sec
# CPU time: 0.0 sec
# Grounding time: 0.0 sec
# Solving time: 0.0 sec
# Atoms : 60
# Rules : 60
#
# Encoding: ../encodings/sequential\inputter.lp
# Satisfiable
# Total time: 0.000995635986328125 sec
# CPU time: 0.0 sec
# Grounding time: 0.000995635986328125 sec
# Solving time: 0.0 sec
# Atoms : 67
# Rules : 67
#
# Encoding: ../encodings/sequential\retrieve_bm_metrics.lp
# Satisfiable
# Total time: 0.0019893646240234375 sec
# CPU time: 0.0 sec
# Grounding time: 0.0019893646240234375 sec
# Solving time: 0.0 sec
# Atoms : 72
# Rules : 72
#
# Encoding: ../encodings/sequential\inputter.lp
# Satisfiable
# Total time: 0.000995635986328125 sec
# CPU time: 0.0 sec
# Grounding time: 0.000995635986328125 sec
# Solving time: 0.0 sec
# Atoms : 53
# Rules : 53
#
# Encoding: ../encodings/sequential\retrieve_bm_metrics.lp
# Satisfiable
# Total time: 0.001995086669921875 sec
# CPU time: 0.0 sec
# Grounding time: 0.001995086669921875 sec
# Solving time: 0.0 sec
# Atoms : 55
# Rules : 55
#
# Encoding: ../encodings/sequential\inputter.lp
# Satisfiable
# Total time: 0.012964248657226562 sec
# CPU time: 0.0 sec
# Grounding time: 0.009969711303710938 sec
# Solving time: 0.002994537353515625 sec
# Atoms : 1184
# Rules : 1184
#
# Encoding: ../encodings/sequential\retrieve_bm_metrics.lp
# Satisfiable
# Total time: 0.012968063354492188 sec
# CPU time: 0.0 sec
# Grounding time: 0.008975982666015625 sec
# Solving time: 0.0039920806884765625 sec
# Atoms : 1220
# Rules : 1220
#
# Encoding: ../encodings/sequential\inputter.lp
# Satisfiable
# Total time: 0.025930404663085938 sec
# CPU time: 0.015625 sec
# Grounding time: 0.019947052001953125 sec
# Solving time: 0.0059833526611328125 sec
# Atoms : 2233
# Rules : 2233
#
# Encoding: ../encodings/sequential\retrieve_bm_metrics.lp
# Satisfiable
# Total time: 0.024930953979492188 sec
# CPU time: 0.015625 sec
# Grounding time: 0.0169525146484375 sec
# Solving time: 0.007978439331054688 sec
# Atoms : 2428
# Rules : 2428
#
# Encoding: ../encodings/sequential\inputter.lp
# Satisfiable
# Total time: 0.00099945068359375 sec
# CPU time: 0.015625 sec
# Grounding time: 0.00099945068359375 sec
# Solving time: 0.0 sec
# Atoms : 34
# Rules : 34
#
# Encoding: ../encodings/sequential\retrieve_bm_metrics.lp
# Satisfiable
# Total time: 0.001995086669921875 sec
# CPU time: 0.0 sec
# Grounding time: 0.001995086669921875 sec
# Solving time: 0.0 sec
# Atoms : 41
# Rules : 41
#
# Encoding: ../encodings/sequential\inputter.lp
# Satisfiable
# Total time: 0.0019969940185546875 sec
# CPU time: 0.0 sec
# Grounding time: 0.0019969940185546875 sec
# Solving time: 0.0 sec
# Atoms : 76
# Rules : 76
#
# Encoding: ../encodings/sequential\retrieve_bm_metrics.lp
# Satisfiable
# Total time: 0.0019931793212890625 sec
# CPU time: 0.0 sec
# Grounding time: 0.0019931793212890625 sec
# Solving time: 0.0 sec
# Atoms : 80
# Rules : 80
#
# Encoding: ../encodings/sequential\inputter.lp
# Satisfiable
# Total time: 0.0039882659912109375 sec
# CPU time: 0.0 sec
# Grounding time: 0.0029926300048828125 sec
# Solving time: 0.000995635986328125 sec
# Atoms : 256
# Rules : 256
#
# Encoding: ../encodings/sequential\retrieve_bm_metrics.lp
# Satisfiable
# Total time: 0.00399017333984375 sec
# CPU time: 0.0 sec
# Grounding time: 0.00299072265625 sec
# Solving time: 0.00099945068359375 sec
# Atoms : 263
# Rules : 263
#
# Encoding: ../encodings/sequential\inputter.lp
# Satisfiable
# Total time: 0.0019931793212890625 sec
# CPU time: 0.015625 sec
# Grounding time: 0.000995635986328125 sec
# Solving time: 0.0009975433349609375 sec
# Atoms : 107
# Rules : 107
#
# Encoding: ../encodings/sequential\retrieve_bm_metrics.lp
# Satisfiable
# Total time: 0.0029926300048828125 sec
# CPU time: 0.0 sec
# Grounding time: 0.001995086669921875 sec
# Solving time: 0.0009975433349609375 sec
# Atoms : 122
# Rules : 122
#
# Encoding: ../encodings/sequential\inputter.lp
# Satisfiable
# Total time: 0.0029926300048828125 sec
# CPU time: 0.0 sec
# Grounding time: 0.0029926300048828125 sec
# Solving time: 0.0 sec
# Atoms : 265
# Rules : 265
#
# Encoding: ../encodings/sequential\retrieve_bm_metrics.lp
# Satisfiable
# Total time: 0.00399017333984375 sec
# CPU time: 0.015625 sec
# Grounding time: 0.0029926300048828125 sec
# Solving time: 0.0009975433349609375 sec
# Atoms : 308
# Rules : 308
#
# Encoding: ../encodings/sequential\inputter.lp
# Satisfiable
# Total time: 0.010969161987304688 sec
# CPU time: 0.015625 sec
# Grounding time: 0.008975982666015625 sec
# Solving time: 0.0019931793212890625 sec
# Atoms : 945
# Rules : 945
#
# Encoding: ../encodings/sequential\retrieve_bm_metrics.lp
# Satisfiable
# Total time: 0.008996963500976562 sec
# CPU time: 0.015625 sec
# Grounding time: 0.00698089599609375 sec
# Solving time: 0.0020160675048828125 sec
# Atoms : 890
# Rules : 890
#
# Encoding: ../encodings/sequential\inputter.lp
# Satisfiable
# Total time: 0.0051479339599609375 sec
# CPU time: 0.0 sec
# Grounding time: 0.004150390625 sec
# Solving time: 0.0009975433349609375 sec
# Atoms : 413
# Rules : 413
#
# Encoding: ../encodings/sequential\retrieve_bm_metrics.lp
# Satisfiable
# Total time: 0.0049877166748046875 sec
# CPU time: 0.015625 sec
# Grounding time: 0.00399017333984375 sec
# Solving time: 0.0009975433349609375 sec
# Atoms : 414
# Rules : 414
#
# Encoding: ../encodings/sequential\inputter.lp
# Satisfiable
# Total time: 0.0352935791015625 sec
# CPU time: 0.03125 sec
# Grounding time: 0.026765823364257812 sec
# Solving time: 0.008527755737304688 sec
# Atoms : 3200
# Rules : 3200
# Encoding: ../encodings/sequential\retrieve_bm_metrics.lp
# Satisfiable
# Total time: 0.04406547546386719 sec
# CPU time: 0.03125 sec
# Grounding time: 0.025644302368164062 sec
# Solving time: 0.018421173095703125 sec
# Atoms : 3235
# Rules : 3235
#
# Encoding: ../encodings/sequential\inputter.lp
# Satisfiable
# Total time: 0.013584136962890625 sec
# CPU time: 0.015625 sec
# Grounding time: 0.01067352294921875 sec
# Solving time: 0.002910614013671875 sec
# Atoms : 1110
# Rules : 1110
#
# Encoding: ../encodings/sequential\retrieve_bm_metrics.lp
# Satisfiable
# Total time: 0.012966156005859375 sec
# CPU time: 0.0 sec
# Grounding time: 0.008975982666015625 sec
# Solving time: 0.00399017333984375 sec
# Atoms : 1123
# Rules : 1123
#
# Encoding: ../encodings/sequential\inputter.lp
# Satisfiable
# Total time: 0.0059833526611328125 sec
# CPU time: 0.0 sec
# Grounding time: 0.0049877166748046875 sec
# Solving time: 0.000995635986328125 sec
# Atoms : 408
# Rules : 408
#
# Encoding: ../encodings/sequential\retrieve_bm_metrics.lp
# Satisfiable
# Total time: 0.0056171417236328125 sec
# CPU time: 0.015625 sec
# Grounding time: 0.00399017333984375 sec
# Solving time: 0.0016269683837890625 sec
# Atoms : 422
# Rules : 422
#
# Encoding: ../encodings/sequential\inputter.lp
# Satisfiable
# Total time: 0.0244903564453125 sec
# CPU time: 0.03125 sec
# Grounding time: 0.019502639770507812 sec
# Solving time: 0.0049877166748046875 sec
# Atoms : 2238
# Rules : 2238
#
# Encoding: ../encodings/sequential\retrieve_bm_metrics.lp
# Satisfiable
# Total time: 0.021480560302734375 sec
# CPU time: 0.015625 sec
# Grounding time: 0.0136566162109375 sec
# Solving time: 0.007823944091796875 sec
# Atoms : 2048
# Rules : 2048
#
# Encoding: ../encodings/sequential\inputter.lp
# Satisfiable
# Total time: 0.025259017944335938 sec
# CPU time: 0.03125 sec
# Grounding time: 0.01854705810546875 sec
# Solving time: 0.0067119598388671875 sec
# Atoms : 2130
# Rules : 2130
#
# Encoding: ../encodings/sequential\retrieve_bm_metrics.lp
# Satisfiable
# Total time: 0.023557662963867188 sec
# CPU time: 0.03125 sec
# Grounding time: 0.0155792236328125 sec
# Solving time: 0.007978439331054688 sec
# Atoms : 2267
# Rules : 2267
#       n robots  n pos  longest path  n vcs  n robots had vcs  n ecs  \
# BM1          1      5             5      0                 0      0
# BM2          2     14             7      0                 0      2
# BM3          2     10             5      1                 2      0
# BM4          4      8             2      1                 4      0
# BM5          2     10             5      2                 2      0
# BM6          4     12             3      2                 4      0
# BM7          3     15             5      3                 3      0
# BM8          6     48             9      9                 6      0
# BM9          3     19             7      3                 2      0
# BM10         3     13             5      1                 2      2
# BM11         3     17             6      4                 2      0
# BM12         2     13             8      1                 0      0
# BM13        10    341            48    102                 8      0
# BM14        20    684            55    135                14     26
# BM15         2      8             4      1                 2      0
# BM16         3     19             7      0                 0      4
# BM17         7     68            17      2                 4      6
# BM18         4     28             7      9                 4      0
# BM19         8     72            10     22                 8      4
# BM20        20    244            13     25                20      0
# BM21        12    104             9     13                12      0
# BM22        32    983            36    122                32      0
# BM23        16    327            22     56                16      0
# BM24         8    116            16     26                 8      0
# BM25        30    618            30     33                15      8
# BM26        30    615            26    126                28     40
#
#       n robots had ecs  n fake ecs  n robots had fake ecs
# BM1                  0           0                      0
# BM2                  2           0                      0
# BM3                  0           0                      0
# BM4                  0           0                      0
# BM5                  0           0                      0
# BM6                  0           0                      0
# BM7                  0           0                      0
# BM8                  0           0                      0
# BM9                  0           0                      0
# BM10                 2           0                      0
# BM11                 0           0                      0
# BM12                 0           0                      0
# BM13                 0           0                      0
# BM14                12          24                     12
# BM15                 0           2                      2
# BM16                 3           0                      0
# BM17                 5           2                      2
# BM18                 0           2                      4
# BM19                 8           4                      8
# BM20                 0          20                     20
# BM21                 0          20                     12
# BM22                 0           0                      0
# BM23                 0           0                      0
# BM24                 0           0                      0
# BM25                 7           2                      2
# BM26                26          42                     27

# %%
#pd.concat([df, bm_df], axis=1)
a = pd.read_csv('../benchmark_data/merger_ps_rec4_small+merger_w_det2/merger_ps_rec4_small+merger_w_det2.csv', index_col=0)
b = pd.read_csv('../benchmark_data/merger_ps_rec4_small+merger_w_inc2/merger_ps_rec4_small+merger_w_inc2.csv', index_col=0)
c = pd.read_csv('../benchmark_data/benchmark_metrics/bm_metrics.csv', index_col=0)
d = pd.read_csv('../benchmark_data/benchmark_metrics/bm_metrics_after_ps_small.csv', index_col=0)

e = pd.concat([a,b,c], axis=1)
f = e[['total','n vcs', 'n robots had vcs']].copy()
f['det wins'] = a['total'] - b['total'] < 0
d
# Out:
#       n robots  n pos  longest path  n vcs  n robots had vcs  n ecs  \
# BM1          1      5             5      0                 0      0
# BM2          2     12             6      0                 0      0
# BM3          2     10             5      1                 2      0
# BM4          4      8             2      1                 4      0
# BM5          2     10             5      2                 2      0
# BM6          4     12             3      2                 4      0
# BM7          3     15             5      3                 3      0
# BM8          6     48             9      9                 6      0
# BM9          3     19             7      3                 2      0
# BM10         3     11             4      0                 0      0
# BM11         3     17             6      4                 2      0
# BM12         2     13             7      0                 0      0
# BM13        10    341            47     82                 8      0
# BM14        20    326            32     32                 6      0
# BM15         2      4             2      0                 0      0
# BM16         3     11             6      0                 0      0
# BM17         7     32             9      0                 0      0
# BM18         4     20             5      6                 4      0
# BM19         8     56             7     12                 8      0
# BM20        20    124             7      8                 8      0
# BM21        12     56             5      4                 8      0
# BM22        32    983            36    122                32      0
# BM23        16    327            22     56                16      0
# BM24         8    116            16     26                 8      0
# BM25        30    538            26     18                 9      0
# BM26        30    250            17     16                11      0
#
#       n robots had ecs  n fake ecs  n robots had fake ecs
# BM1                  0           0                      0
# BM2                  0           0                      0
# BM3                  0           0                      0
# BM4                  0           0                      0
# BM5                  0           0                      0
# BM6                  0           0                      0
# BM7                  0           0                      0
# BM8                  0           0                      0
# BM9                  0           0                      0
# BM10                 0           0                      0
# BM11                 0           0                      0
# BM12                 0           0                      0
# BM13                 0           0                      0
# BM14                 0           0                      0
# BM15                 0           0                      0
# BM16                 0           0                      0
# BM17                 0           0                      0
# BM18                 0           0                      0
# BM19                 0           0                      0
# BM20                 0           0                      0
# BM21                 0           0                      0
# BM22                 0           0                      0
# BM23                 0           0                      0
# BM24                 0           0                      0
# BM25                 0           0                      0
# BM26                 0           2                      2

# %%
# creating the comparison table
def createComparisonTable(path, table, bm_table, name):
    selected_bm_ids = [12,13,19,21,22,24,25]
    ct = table.iloc[selected_bm_ids,:].copy()
    ct['dSOAP'] = 0.0
    results = readJSONs(path)
    for result in results:
        bm_id = int(result.data['instance'][0:2])-1
        if bm_id in selected_bm_ids:
            print(bm_id+1)
            m = Model(result.data['model'])
            metrics, _ = merger.retrieveBenchmarkMetrics(m)
            index = 'BM{}'.format(bm_id+1)
            ct.loc[index,'dSOAP'] = metrics['n_p']
    ct['dSOAP'] = ct['dSOAP'] - bm_table['n pos']
    ct = ct[['total','dSOAP']].copy()
    ct.to_csv('../benchmark_data/comparison_data/{}.csv'.format(name))
    return ct
c1 = createComparisonTable("../benchmark_data/*det*/*.json", a, c, 'det')
c2 = createComparisonTable("../benchmark_data/*inc*/*.json", b, c, 'inc')
print(c1)
print(c2)
# Out:
# 13
# Encoding: ../encodings/sequential\inputter.lp
# Satisfiable
# Total time: 0.01593780517578125 sec
# CPU time: 0.015625 sec
# Grounding time: 0.0119476318359375 sec
# Solving time: 0.00399017333984375 sec
# Atoms : 1244
# Rules : 1244
#
# Encoding: ../encodings/sequential\retrieve_bm_metrics.lp
# Satisfiable
# Total time: 0.012966156005859375 sec
# CPU time: 0.015625 sec
# Grounding time: 0.008975982666015625 sec
# Solving time: 0.00399017333984375 sec
# Atoms : 1160
# Rules : 1160
#
# 14
# Encoding: ../encodings/sequential\inputter.lp
# Satisfiable
# Total time: 0.01496124267578125 sec
# CPU time: 0.015625 sec
# Grounding time: 0.011003494262695312 sec
# Solving time: 0.0039577484130859375 sec
# Atoms : 1186
# Rules : 1186
#
# Encoding: ../encodings/sequential\retrieve_bm_metrics.lp
# Satisfiable
# Total time: 0.0110015869140625 sec
# CPU time: 0.015625 sec
# Grounding time: 0.007976531982421875 sec
# Solving time: 0.003025054931640625 sec
# Atoms : 1097
# Rules : 1097
#
# 20
# Encoding: ../encodings/sequential\inputter.lp
# Satisfiable
# Total time: 0.007947921752929688 sec
# CPU time: 0.015625 sec
# Grounding time: 0.00695037841796875 sec
# Solving time: 0.0009975433349609375 sec
# Atoms : 597
# Rules : 597
#
# Encoding: ../encodings/sequential\retrieve_bm_metrics.lp
# Satisfiable
# Total time: 0.003223419189453125 sec
# CPU time: 0.0 sec
# Grounding time: 0.003223419189453125 sec
# Solving time: 0.0 sec
# Atoms : 452
# Rules : 452
#
# 22
# Encoding: ../encodings/sequential\inputter.lp
# Satisfiable
# Total time: 0.0468902587890625 sec
# CPU time: 0.046875 sec
# Grounding time: 0.03127861022949219 sec
# Solving time: 0.015611648559570312 sec
# Atoms : 4838
# Rules : 4838
#
# Encoding: ../encodings/sequential\retrieve_bm_metrics.lp
# Satisfiable
# Total time: 0.03124237060546875 sec
# CPU time: 0.03125 sec
# Grounding time: 0.03124237060546875 sec
# Solving time: 0.0 sec
# Atoms : 4744
# Rules : 4744
#
# 23
# Encoding: ../encodings/sequential\inputter.lp
# Satisfiable
# Total time: 0.015626907348632812 sec
# CPU time: 0.015625 sec
# Grounding time: 0.015626907348632812 sec
# Solving time: 0.0 sec
# Atoms : 1470
# Rules : 1470
#
# Encoding: ../encodings/sequential\retrieve_bm_metrics.lp
# Satisfiable
# Total time: 0.015615463256835938 sec
# CPU time: 0.015625 sec
# Grounding time: 0.015615463256835938 sec
# Solving time: 0.0 sec
# Atoms : 1422
# Rules : 1422
#
# 25
# Encoding: ../encodings/sequential\inputter.lp
# Satisfiable
# Total time: 0.022130966186523438 sec
# CPU time: 0.015625 sec
# Grounding time: 0.018133163452148438 sec
# Solving time: 0.003997802734375 sec
# Atoms : 2055
# Rules : 2055
#
# Encoding: ../encodings/sequential\retrieve_bm_metrics.lp
# Satisfiable
# Total time: 0.015956878662109375 sec
# CPU time: 0.015625 sec
# Grounding time: 0.010957717895507812 sec
# Solving time: 0.0049991607666015625 sec
# Atoms : 1806
# Rules : 1806
#
# 26
# Encoding: ../encodings/sequential\inputter.lp
# Satisfiable
# Total time: 0.011966705322265625 sec
# CPU time: 0.0 sec
# Grounding time: 0.00997161865234375 sec
# Solving time: 0.001995086669921875 sec
# Atoms : 1071
# Rules : 1071
#
# Encoding: ../encodings/sequential\retrieve_bm_metrics.lp
# Satisfiable
# Total time: 0.008970260620117188 sec
# CPU time: 0.015625 sec
# Grounding time: 0.006984710693359375 sec
# Solving time: 0.0019855499267578125 sec
# Atoms : 922
# Rules : 922
#
# 13
# Encoding: ../encodings/sequential\inputter.lp
# Satisfiable
# Total time: 0.011966705322265625 sec
# CPU time: 0.0 sec
# Grounding time: 0.009973526000976562 sec
# Solving time: 0.0019931793212890625 sec
# Atoms : 1244
# Rules : 1244
#
# Encoding: ../encodings/sequential\retrieve_bm_metrics.lp
# Satisfiable
# Total time: 0.010934829711914062 sec
# CPU time: 0.0 sec
# Grounding time: 0.00794219970703125 sec
# Solving time: 0.0029926300048828125 sec
# Atoms : 1160
# Rules : 1160
#
# 14
# Encoding: ../encodings/sequential\inputter.lp
# Satisfiable
# Total time: 0.013942718505859375 sec
# CPU time: 0.015625 sec
# Grounding time: 0.010950088500976562 sec
# Solving time: 0.0029926300048828125 sec
# Atoms : 1186
# Rules : 1186
#
# Encoding: ../encodings/sequential\retrieve_bm_metrics.lp
# Satisfiable
# Total time: 0.011968612670898438 sec
# CPU time: 0.015625 sec
# Grounding time: 0.008975982666015625 sec
# Solving time: 0.0029926300048828125 sec
# Atoms : 1097
# Rules : 1097
#
# 20
# Encoding: ../encodings/sequential\inputter.lp
# Satisfiable
# Total time: 0.007976531982421875 sec
# CPU time: 0.015625 sec
# Grounding time: 0.0069599151611328125 sec
# Solving time: 0.0010166168212890625 sec
# Atoms : 597
# Rules : 597
#
# Encoding: ../encodings/sequential\retrieve_bm_metrics.lp
# Satisfiable
# Total time: 0.00698089599609375 sec
# CPU time: 0.0 sec
# Grounding time: 0.004985809326171875 sec
# Solving time: 0.001995086669921875 sec
# Atoms : 452
# Rules : 452
#
# 25
# Encoding: ../encodings/sequential\inputter.lp
# Satisfiable
# Total time: 0.022937774658203125 sec
# CPU time: 0.03125 sec
# Grounding time: 0.01795196533203125 sec
# Solving time: 0.004985809326171875 sec
# Atoms : 2043
# Rules : 2043
#
# Encoding: ../encodings/sequential\retrieve_bm_metrics.lp
# Satisfiable
# Total time: 0.015958786010742188 sec
# CPU time: 0.015625 sec
# Grounding time: 0.010969161987304688 sec
# Solving time: 0.0049896240234375 sec
# Atoms : 1777
# Rules : 1777
#
# 26
# Encoding: ../encodings/sequential\inputter.lp
# Satisfiable
# Total time: 0.011993408203125 sec
# CPU time: 0.015625 sec
# Grounding time: 0.010997772216796875 sec
# Solving time: 0.000995635986328125 sec
# Atoms : 1020
# Rules : 1020
#
# Encoding: ../encodings/sequential\retrieve_bm_metrics.lp
# Satisfiable
# Total time: 0.008007049560546875 sec
# CPU time: 0.015625 sec
# Grounding time: 0.0060100555419921875 sec
# Solving time: 0.0019969940185546875 sec
# Atoms : 812
# Rules : 812
#
#          total  dSOAP
# BM13  0.199526   20.0
# BM14  0.782887 -349.0
# BM20  0.059021 -116.0
# BM22  0.394056  546.0
# BM23  0.088764  120.0
# BM25  0.424944  -61.0
# BM26  2.273167 -351.0
#          total  dSOAP
# BM13  0.775194   20.0
# BM14  0.832670 -349.0
# BM20  0.076792 -116.0
# BM22       NaN -983.0
# BM23       NaN -327.0
# BM25  0.669954  -65.0
# BM26  2.123331 -382.0

# %%
e = pd.concat([c1,c2,d], axis=1)
e = e.iloc[0:7,:].copy()
e.to_csv('../benchmark_data/comparison_data/{}.csv'.format('comparison'))
e
# Out:
#          total  dSOAP     total  dSOAP  n robots  n pos  longest path  n vcs  \
# BM13  0.199526   20.0  0.775194   20.0        10    341            47     82
# BM14  0.782887 -349.0  0.832670 -349.0        20    326            32     32
# BM20  0.059021 -116.0  0.076792 -116.0        20    124             7      8
# BM22  0.394056  546.0       NaN -983.0        32    983            36    122
# BM23  0.088764  120.0       NaN -327.0        16    327            22     56
# BM25  0.424944  -61.0  0.669954  -65.0        30    538            26     18
# BM26  2.273167 -351.0  2.123331 -382.0        30    250            17     16
#
#       n robots had vcs  n ecs  n robots had ecs  n fake ecs  \
# BM13                 8      0                 0           0
# BM14                 6      0                 0           0
# BM20                 8      0                 0           0
# BM22                32      0                 0           0
# BM23                16      0                 0           0
# BM25                 9      0                 0           0
# BM26                11      0                 0           2
#
#       n robots had fake ecs
# BM13                      0
# BM14                      0
# BM20                      0
# BM22                      0
# BM23                      0
# BM25                      0
# BM26                      2

# %%
cb = c1.copy()
cb['total'] = c1['total'] < c2['total']
cb['dSOAP'] = c2['dSOAP'] - c1['dSOAP']
cb.to_csv('../benchmark_data/comparison_data/{}.csv'.format('boolean_comparison'))
cb
# Out:
#       total   dSOAP
# BM13   True     0.0
# BM14   True     0.0
# BM20   True     0.0
# BM22  False -1529.0
# BM23  False  -447.0
# BM25   True    -4.0
# BM26  False   -31.0
