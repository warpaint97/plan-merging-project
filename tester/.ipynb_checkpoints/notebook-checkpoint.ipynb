# %% [markdown]
# # Evaluation
#
# doing evaluation stuff here...

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from iclingo import Clingo, Model
import funcs
from funcs import BMDataFormat, AccumulatedStats
import matplotlib.pyplot as plt
import numpy as np
import os
import files
import glob
import json

# %%
#create a data frame
benchmarks = funcs.getAllBenchmarks('../benchmarks')
cols = ['total','ground','solve']
rows = ['BM{}'.format(i+1) for i, bm in enumerate(benchmarks)]
dct = {}
for c in cols:
    dct[c] = [0.0]*len(rows)
df = pd.DataFrame(dct, index=rows)

# %%
# reading json benchmark data
def readJSONs(path):
    files = glob.glob(path)
    bmdfs = []
    for file in files:
        bmdfs.append(BMDataFormat())
        bmdfs[-1].load(file)
    return bmdfs
bmdfs = readJSONs("../benchmark_data/*det*/*.json")

# %%
# insert benchmark data into data frame
for bmdf in bmdfs:
    df.loc[df.index[int(bmdf.data['instance'][0:2])-1]] = [
                  bmdf.data['statistics']['total'],
                  bmdf.data['statistics']['groundingTime'],
                  bmdf.data['statistics']['solvingTime']
                 ]
#df.to_csv('../benchmark_data/det_approach/det_approach.csv')
df
# Out:
#          total    ground     solve
# BM1   0.021969  0.021969  0.000000
# BM2   0.033909  0.030918  0.002991
# BM3   0.020945  0.018950  0.001995
# BM4   0.000000  0.000000  0.000000
# BM5   0.017950  0.017950  0.000000
# BM6   0.020945  0.019947  0.000998
# BM7   0.020945  0.019945  0.000999
# BM8   0.034908  0.033909  0.000999
# BM9   0.027920  0.026922  0.000998
# BM10  0.025938  0.023943  0.001995
# BM11  0.021942  0.020945  0.000998
# BM12  0.023937  0.022938  0.000999
# BM13  0.358728  0.314840  0.043888
# BM14  0.711729  0.299833  0.411896
# BM15  0.022230  0.021233  0.000998
# BM16  0.033913  0.032934  0.000978
# BM17  0.033907  0.030914  0.002993
# BM18  0.029922  0.027929  0.001993
# BM19  0.043880  0.036898  0.006983
# BM20  0.074800  0.051863  0.022938
# BM21  0.037901  0.034908  0.002993
# BM22  3.358461  3.291176  0.067286
# BM23  0.487207  0.470253  0.016954
# BM24  0.074326  0.069324  0.005001
# BM25  1.412695  0.631762  0.780933
# BM26  1.770454  0.301662  1.468792

# %%
from merger import Merger
# initialize merger
merger = Merger("../encodings/sequential", "../benchmark_data")
def merge(benchmark_id):
        benchmark = benchmarks[benchmark_id-1]
        return merger.merge(benchmark, vizualize=False, save_data=False, deterministic_waiter=False, check_validity=True, automated=False)
        
def mergeAll(exclude=[22,23,26]):
    for i in range(len(benchmarks)):
        benchmark_id = i+1
        benchmark = benchmarks[i]
        if benchmark_id in exclude:
            continue
        print("################## {} ###################".format(benchmark))
        merger.merge(benchmark, vizualize=False, save_data=True, automated=False, deterministic_waiter=True, check_validity=True)

# %%
# test merging here
#m, _ = merger.merge(benchmarks[26-1], vizualize=True, save_data=False, automated=True, deterministic_waiter=True, check_validity=True)
#m.model
#s, _ = merger.retrieveBenchmarkMetrics(m)

#mergeAll([])

# %%
dct = {}
for c in ['n robots',
          'n pos',
          'longest path',
          'n vcs',
          'n robots had vcs',
          'n ecs',
          'n robots had ecs',
          'n fake ecs',
          'n robots had fake ecs']:
    dct[c] = [0.0]*len(rows)
bm_df = pd.DataFrame(dct, index=rows)
bm_df = bm_df.astype(int)

# %%
for i, bm in enumerate(benchmarks):
    bm_id = i+1
    #m, _ = merger.switchPlans(merger.getBenchmarkModel(bm), small=True)
    #m, _ = merger.switchPlans(merger.getBenchmarkModel(bm), small=False)
    #m, _ = merger.convertToAsprilo(m,bm)
    metrics, _ = merger.retrieveBenchmarkMetrics(bm)
    bm_df.loc[bm_df.index[i]] = [metrics['n_r'],
                           metrics['n_p'],
                           metrics['n_lp'],
                           metrics['n_vc'],
                           metrics['r_vc'],
                           metrics['n_ec'],
                           metrics['r_ec'],
                           metrics['n_fec'],
                           metrics['r_fec']]
#bm_df.to_csv('../benchmark_data/benchmark_metrics/bm_metrics.csv')
bm_df
# Out:
# Encoding: ../encodings/sequential\inputter.lp
# Satisfiable
# Total time: 0.000995635986328125 sec
# CPU time: 0.0 sec
# Grounding time: 0.000995635986328125 sec
# Solving time: 0.0 sec
# Atoms : 26
# Rules : 26
#
# Encoding: ../encodings/sequential\retrieve_bm_metrics.lp
# Satisfiable
# Total time: 0.000995635986328125 sec
# CPU time: 0.0 sec
# Grounding time: 0.000995635986328125 sec
# Solving time: 0.0 sec
# Atoms : 23
# Rules : 23
#
# Encoding: ../encodings/sequential\inputter.lp
# Satisfiable
# Total time: 0.00099945068359375 sec
# CPU time: 0.0 sec
# Grounding time: 0.00099945068359375 sec
# Solving time: 0.0 sec
# Atoms : 62
# Rules : 62
#
# Encoding: ../encodings/sequential\retrieve_bm_metrics.lp
# Satisfiable
# Total time: 0.0019931793212890625 sec
# CPU time: 0.0 sec
# Grounding time: 0.0019931793212890625 sec
# Solving time: 0.0 sec
# Atoms : 59
# Rules : 59
#
# Encoding: ../encodings/sequential\inputter.lp
# Satisfiable
# Total time: 0.0009975433349609375 sec
# CPU time: 0.0 sec
# Grounding time: 0.0009975433349609375 sec
# Solving time: 0.0 sec
# Atoms : 52
# Rules : 52
#
# Encoding: ../encodings/sequential\retrieve_bm_metrics.lp
# Satisfiable
# Total time: 0.0009975433349609375 sec
# CPU time: 0.0 sec
# Grounding time: 0.0009975433349609375 sec
# Solving time: 0.0 sec
# Atoms : 44
# Rules : 44
#
# Encoding: ../encodings/sequential\inputter.lp
# Satisfiable
# Total time: 0.001995086669921875 sec
# CPU time: 0.0 sec
# Grounding time: 0.001995086669921875 sec
# Solving time: 0.0 sec
# Atoms : 28
# Rules : 28
#
# Encoding: ../encodings/sequential\retrieve_bm_metrics.lp
# Satisfiable
# Total time: 0.001995086669921875 sec
# CPU time: 0.0 sec
# Grounding time: 0.0009975433349609375 sec
# Solving time: 0.0009975433349609375 sec
# Atoms : 43
# Rules : 43
#
# Encoding: ../encodings/sequential\inputter.lp
# Satisfiable
# Total time: 0.00099945068359375 sec
# CPU time: 0.0 sec
# Grounding time: 0.00099945068359375 sec
# Solving time: 0.0 sec
# Atoms : 42
# Rules : 42
#
# Encoding: ../encodings/sequential\retrieve_bm_metrics.lp
# Satisfiable
# Total time: 0.001995086669921875 sec
# CPU time: 0.0 sec
# Grounding time: 0.001995086669921875 sec
# Solving time: 0.0 sec
# Atoms : 45
# Rules : 45
#
# Encoding: ../encodings/sequential\inputter.lp
# Satisfiable
# Total time: 0.0009975433349609375 sec
# CPU time: 0.0 sec
# Grounding time: 0.0009975433349609375 sec
# Solving time: 0.0 sec
# Atoms : 54
# Rules : 54
#
# Encoding: ../encodings/sequential\retrieve_bm_metrics.lp
# Satisfiable
# Total time: 0.001995086669921875 sec
# CPU time: 0.0 sec
# Grounding time: 0.001995086669921875 sec
# Solving time: 0.0 sec
# Atoms : 57
# Rules : 57
#
# Encoding: ../encodings/sequential\inputter.lp
# Satisfiable
# Total time: 0.0009975433349609375 sec
# CPU time: 0.0 sec
# Grounding time: 0.0009975433349609375 sec
# Solving time: 0.0 sec
# Atoms : 60
# Rules : 60
#
# Encoding: ../encodings/sequential\retrieve_bm_metrics.lp
# Satisfiable
# Total time: 0.001995086669921875 sec
# CPU time: 0.0 sec
# Grounding time: 0.001995086669921875 sec
# Solving time: 0.0 sec
# Atoms : 65
# Rules : 65
#
# Encoding: ../encodings/sequential\inputter.lp
# Satisfiable
# Total time: 0.00299072265625 sec
# CPU time: 0.0 sec
# Grounding time: 0.00299072265625 sec
# Solving time: 0.0 sec
# Atoms : 193
# Rules : 193
#
# Encoding: ../encodings/sequential\retrieve_bm_metrics.lp
# Satisfiable
# Total time: 0.00399017333984375 sec
# CPU time: 0.0 sec
# Grounding time: 0.0029926300048828125 sec
# Solving time: 0.0009975433349609375 sec
# Atoms : 186
# Rules : 186
#
# Encoding: ../encodings/sequential\inputter.lp
# Satisfiable
# Total time: 0.0019931793212890625 sec
# CPU time: 0.0 sec
# Grounding time: 0.0009937286376953125 sec
# Solving time: 0.00099945068359375 sec
# Atoms : 74
# Rules : 74
#
# Encoding: ../encodings/sequential\retrieve_bm_metrics.lp
# Satisfiable
# Total time: 0.0019931793212890625 sec
# CPU time: 0.0 sec
# Grounding time: 0.0019931793212890625 sec
# Solving time: 0.0 sec
# Atoms : 78
# Rules : 78
#
# Encoding: ../encodings/sequential\inputter.lp
# Satisfiable
# Total time: 0.001995086669921875 sec
# CPU time: 0.0 sec
# Grounding time: 0.001995086669921875 sec
# Solving time: 0.0 sec
# Atoms : 54
# Rules : 54
#
# Encoding: ../encodings/sequential\retrieve_bm_metrics.lp
# Satisfiable
# Total time: 0.0019969940185546875 sec
# CPU time: 0.0 sec
# Grounding time: 0.0019969940185546875 sec
# Solving time: 0.0 sec
# Atoms : 60
# Rules : 60
#
# Encoding: ../encodings/sequential\inputter.lp
# Satisfiable
# Total time: 0.0009975433349609375 sec
# CPU time: 0.0 sec
# Grounding time: 0.0009975433349609375 sec
# Solving time: 0.0 sec
# Atoms : 67
# Rules : 67
#
# Encoding: ../encodings/sequential\retrieve_bm_metrics.lp
# Satisfiable
# Total time: 0.001995086669921875 sec
# CPU time: 0.0 sec
# Grounding time: 0.0009975433349609375 sec
# Solving time: 0.0009975433349609375 sec
# Atoms : 72
# Rules : 72
#
# Encoding: ../encodings/sequential\inputter.lp
# Satisfiable
# Total time: 0.0019931793212890625 sec
# CPU time: 0.0 sec
# Grounding time: 0.0019931793212890625 sec
# Solving time: 0.0 sec
# Atoms : 53
# Rules : 53
#
# Encoding: ../encodings/sequential\retrieve_bm_metrics.lp
# Satisfiable
# Total time: 0.001995086669921875 sec
# CPU time: 0.0 sec
# Grounding time: 0.001995086669921875 sec
# Solving time: 0.0 sec
# Atoms : 55
# Rules : 55
#
# Encoding: ../encodings/sequential\inputter.lp
# Satisfiable
# Total time: 0.01296234130859375 sec
# CPU time: 0.015625 sec
# Grounding time: 0.00997161865234375 sec
# Solving time: 0.00299072265625 sec
# Atoms : 1184
# Rules : 1184
#
# Encoding: ../encodings/sequential\retrieve_bm_metrics.lp
# Satisfiable
# Total time: 0.012966156005859375 sec
# CPU time: 0.015625 sec
# Grounding time: 0.008975982666015625 sec
# Solving time: 0.00399017333984375 sec
# Atoms : 1212
# Rules : 1212
#
# Encoding: ../encodings/sequential\inputter.lp
# Satisfiable
# Total time: 0.024932861328125 sec
# CPU time: 0.03125 sec
# Grounding time: 0.018949508666992188 sec
# Solving time: 0.0059833526611328125 sec
# Atoms : 2233
# Rules : 2233
#
# Encoding: ../encodings/sequential\retrieve_bm_metrics.lp
# Satisfiable
# Total time: 0.023937225341796875 sec
# CPU time: 0.015625 sec
# Grounding time: 0.015958786010742188 sec
# Solving time: 0.007978439331054688 sec
# Atoms : 2394
# Rules : 2394
#
# Encoding: ../encodings/sequential\inputter.lp
# Satisfiable
# Total time: 0.000995635986328125 sec
# CPU time: 0.0 sec
# Grounding time: 0.000995635986328125 sec
# Solving time: 0.0 sec
# Atoms : 34
# Rules : 34
#
# Encoding: ../encodings/sequential\retrieve_bm_metrics.lp
# Satisfiable
# Total time: 0.0019969940185546875 sec
# CPU time: 0.0 sec
# Grounding time: 0.0019969940185546875 sec
# Solving time: 0.0 sec
# Atoms : 41
# Rules : 41
#
# Encoding: ../encodings/sequential\inputter.lp
# Satisfiable
# Total time: 0.001995086669921875 sec
# CPU time: 0.015625 sec
# Grounding time: 0.001995086669921875 sec
# Solving time: 0.0 sec
# Atoms : 76
# Rules : 76
#
# Encoding: ../encodings/sequential\retrieve_bm_metrics.lp
# Satisfiable
# Total time: 0.0019931793212890625 sec
# CPU time: 0.0 sec
# Grounding time: 0.0019931793212890625 sec
# Solving time: 0.0 sec
# Atoms : 80
# Rules : 80
#
# Encoding: ../encodings/sequential\inputter.lp
# Satisfiable
# Total time: 0.0039920806884765625 sec
# CPU time: 0.0 sec
# Grounding time: 0.0029926300048828125 sec
# Solving time: 0.00099945068359375 sec
# Atoms : 256
# Rules : 256
#
# Encoding: ../encodings/sequential\retrieve_bm_metrics.lp
# Satisfiable
# Total time: 0.0029926300048828125 sec
# CPU time: 0.015625 sec
# Grounding time: 0.001995086669921875 sec
# Solving time: 0.0009975433349609375 sec
# Atoms : 263
# Rules : 263
#
# Encoding: ../encodings/sequential\inputter.lp
# Satisfiable
# Total time: 0.001995086669921875 sec
# CPU time: 0.0 sec
# Grounding time: 0.001995086669921875 sec
# Solving time: 0.0 sec
# Atoms : 107
# Rules : 107
#
# Encoding: ../encodings/sequential\retrieve_bm_metrics.lp
# Satisfiable
# Total time: 0.0019931793212890625 sec
# CPU time: 0.0 sec
# Grounding time: 0.0019931793212890625 sec
# Solving time: 0.0 sec
# Atoms : 122
# Rules : 122
#
# Encoding: ../encodings/sequential\inputter.lp
# Satisfiable
# Total time: 0.00399017333984375 sec
# CPU time: 0.0 sec
# Grounding time: 0.00299072265625 sec
# Solving time: 0.00099945068359375 sec
# Atoms : 265
# Rules : 265
#
# Encoding: ../encodings/sequential\retrieve_bm_metrics.lp
# Satisfiable
# Total time: 0.00399017333984375 sec
# CPU time: 0.015625 sec
# Grounding time: 0.002994537353515625 sec
# Solving time: 0.000995635986328125 sec
# Atoms : 304
# Rules : 304
#
# Encoding: ../encodings/sequential\inputter.lp
# Satisfiable
# Total time: 0.011966705322265625 sec
# CPU time: 0.015625 sec
# Grounding time: 0.008974075317382812 sec
# Solving time: 0.0029926300048828125 sec
# Atoms : 945
# Rules : 945
#
# Encoding: ../encodings/sequential\retrieve_bm_metrics.lp
# Satisfiable
# Total time: 0.00997161865234375 sec
# CPU time: 0.015625 sec
# Grounding time: 0.00698089599609375 sec
# Solving time: 0.00299072265625 sec
# Atoms : 890
# Rules : 890
#
# Encoding: ../encodings/sequential\inputter.lp
# Satisfiable
# Total time: 0.0059833526611328125 sec
# CPU time: 0.0 sec
# Grounding time: 0.0049839019775390625 sec
# Solving time: 0.00099945068359375 sec
# Atoms : 413
# Rules : 413
#
# Encoding: ../encodings/sequential\retrieve_bm_metrics.lp
# Satisfiable
# Total time: 0.0059833526611328125 sec
# CPU time: 0.015625 sec
# Grounding time: 0.00399017333984375 sec
# Solving time: 0.0019931793212890625 sec
# Atoms : 414
# Rules : 414
#
# Encoding: ../encodings/sequential\inputter.lp
# Satisfiable
# Total time: 0.0399017333984375 sec
# CPU time: 0.03125 sec
# Grounding time: 0.02791595458984375 sec
# Solving time: 0.01198577880859375 sec
# Atoms : 3200
# Rules : 3200
#
# Encoding: ../encodings/sequential\retrieve_bm_metrics.lp
# Satisfiable
# Total time: 0.03588294982910156 sec
# CPU time: 0.015625 sec
# Grounding time: 0.026905059814453125 sec
# Solving time: 0.008977890014648438 sec
# Atoms : 3235
# Rules : 3235
#
# Encoding: ../encodings/sequential\inputter.lp
# Satisfiable
# Total time: 0.011968612670898438 sec
# CPU time: 0.015625 sec
# Grounding time: 0.008975982666015625 sec
# Solving time: 0.0029926300048828125 sec
# Atoms : 1110
# Rules : 1110
#
# Encoding: ../encodings/sequential\retrieve_bm_metrics.lp
# Satisfiable
# Total time: 0.010969161987304688 sec
# CPU time: 0.0 sec
# Grounding time: 0.007976531982421875 sec
# Solving time: 0.0029926300048828125 sec
# Atoms : 1123
# Rules : 1123
#
# Encoding: ../encodings/sequential\inputter.lp
# Satisfiable
# Total time: 0.0059814453125 sec
# CPU time: 0.0 sec
# Grounding time: 0.004985809326171875 sec
# Solving time: 0.000995635986328125 sec
# Atoms : 408
# Rules : 408
#
# Encoding: ../encodings/sequential\retrieve_bm_metrics.lp
# Satisfiable
# Total time: 0.004985809326171875 sec
# CPU time: 0.015625 sec
# Grounding time: 0.0039882659912109375 sec
# Solving time: 0.0009975433349609375 sec
# Atoms : 422
# Rules : 422
#
# Encoding: ../encodings/sequential\inputter.lp
# Satisfiable
# Total time: 0.027925491333007812 sec
# CPU time: 0.03125 sec
# Grounding time: 0.022939682006835938 sec
# Solving time: 0.004985809326171875 sec
# Atoms : 2238
# Rules : 2238
#
# Encoding: ../encodings/sequential\retrieve_bm_metrics.lp
# Satisfiable
# Total time: 0.019456863403320312 sec
# CPU time: 0.03125 sec
# Grounding time: 0.014471054077148438 sec
# Solving time: 0.004985809326171875 sec
# Atoms : 2043
# Rules : 2043
#
# Encoding: ../encodings/sequential\inputter.lp
# Satisfiable
# Total time: 0.025930404663085938 sec
# CPU time: 0.015625 sec
# Grounding time: 0.02094268798828125 sec
# Solving time: 0.0049877166748046875 sec
# Atoms : 2130
# Rules : 2130
#
# Encoding: ../encodings/sequential\retrieve_bm_metrics.lp
# Satisfiable
# Total time: 0.025930404663085938 sec
# CPU time: 0.03125 sec
# Grounding time: 0.018949508666992188 sec
# Solving time: 0.00698089599609375 sec
# Atoms : 2250
# Rules : 2250
#       n robots  n pos  longest path  n vcs  n robots had vcs  n ecs  \
# BM1          1      5             5      0                 0      0
# BM2          2     14             7      0                 0      2
# BM3          2     10             5      1                 2      0
# BM4          4      8             2      1                 4      0
# BM5          2     10             5      2                 2      0
# BM6          4     12             3      2                 4      0
# BM7          3     15             5      3                 3      0
# BM8          6     48             9      9                 6      0
# BM9          3     19             7      3                 2      0
# BM10         3     13             5      1                 2      2
# BM11         3     17             6      4                 2      0
# BM12         2     13             8      1                 1      0
# BM13        10    341            48    102                 9      0
# BM14        20    684            55    135                18     26
# BM15         2      8             4      1                 2      0
# BM16         3     19             7      0                 0      4
# BM17         7     68            17      2                 4      6
# BM18         4     28             7      9                 4      0
# BM19         8     72            10     22                 8      4
# BM20        20    244            13     25                20      0
# BM21        12    104             9     13                12      0
# BM22        32    983            36    122                32      0
# BM23        16    327            22     56                16      0
# BM24         8    116            16     26                 8      0
# BM25        30    618            30     33                17      8
# BM26        30    615            26    126                28     40
#
#       n robots had ecs  n fake ecs  n robots had fake ecs
# BM1                  0           0                      0
# BM2                  2           0                      0
# BM3                  0           0                      0
# BM4                  0           0                      0
# BM5                  0           0                      0
# BM6                  0           0                      0
# BM7                  0           0                      0
# BM8                  0           0                      0
# BM9                  0           0                      0
# BM10                 2           0                      0
# BM11                 0           0                      0
# BM12                 0           0                      0
# BM13                 0           0                      0
# BM14                12          24                     12
# BM15                 0           2                      2
# BM16                 3           0                      0
# BM17                 5           2                      2
# BM18                 0           2                      4
# BM19                 8           4                      8
# BM20                 0          20                     20
# BM21                 0          20                     12
# BM22                 0           0                      0
# BM23                 0           0                      0
# BM24                 0           0                      0
# BM25                 7           2                      2
# BM26                26          42                     27

# %%
#pd.concat([df, bm_df], axis=1)
a = pd.read_csv('../benchmark_data/det_approach/det_approach.csv', index_col=0)
b = pd.read_csv('../benchmark_data/inc_approach/inc_approach.csv', index_col=0)
c = pd.read_csv('../benchmark_data/benchmark_metrics/bm_metrics.csv', index_col=0)
d = pd.read_csv('../benchmark_data/benchmark_metrics/bm_metrics_after_ps_small.csv', index_col=0)

e = pd.concat([a,b,c], axis=1)
f = e[['total','n vcs', 'n robots had vcs']].copy()
f['det wins'] = a['total'] - b['total'] < 0
d
# Out:
#       n robots  n pos  longest path  n vcs  n robots had vcs  n ecs  \
# BM1          1      5             5      0                 0      0
# BM2          2     12             6      0                 0      0
# BM3          2     10             5      1                 2      0
# BM4          4      8             2      1                 4      0
# BM5          2     10             5      2                 2      0
# BM6          4     12             3      2                 4      0
# BM7          3     15             5      3                 3      0
# BM8          6     48             9      9                 6      0
# BM9          3     19             7      3                 2      0
# BM10         3     11             4      0                 0      0
# BM11         3     17             6      4                 2      0
# BM12         2     13             7      0                 0      0
# BM13        10    341            47     82                 8      0
# BM14        20    326            32     32                 6      0
# BM15         2      4             2      0                 0      0
# BM16         3     11             6      0                 0      0
# BM17         7     32             9      0                 0      0
# BM18         4     20             5      6                 4      0
# BM19         8     56             7     12                 8      0
# BM20        20    124             7      8                 8      0
# BM21        12     56             5      4                 8      0
# BM22        32    983            36    122                32      0
# BM23        16    327            22     56                16      0
# BM24         8    116            16     26                 8      0
# BM25        30    538            26     18                 9      0
# BM26        30    250            17     16                11      0
#
#       n robots had ecs  n fake ecs  n robots had fake ecs
# BM1                  0           0                      0
# BM2                  0           0                      0
# BM3                  0           0                      0
# BM4                  0           0                      0
# BM5                  0           0                      0
# BM6                  0           0                      0
# BM7                  0           0                      0
# BM8                  0           0                      0
# BM9                  0           0                      0
# BM10                 0           0                      0
# BM11                 0           0                      0
# BM12                 0           0                      0
# BM13                 0           0                      0
# BM14                 0           0                      0
# BM15                 0           0                      0
# BM16                 0           0                      0
# BM17                 0           0                      0
# BM18                 0           0                      0
# BM19                 0           0                      0
# BM20                 0           0                      0
# BM21                 0           0                      0
# BM22                 0           0                      0
# BM23                 0           0                      0
# BM24                 0           0                      0
# BM25                 0           0                      0
# BM26                 0           2                      2

# %%
# creating the comparison table
def createComparisonTable(path, table, bm_table, name):
    selected_bm_ids = [12,13,19,21,22,24,25]
    ct = table.iloc[selected_bm_ids,:].copy()
    ct['dSOAP'] = 0.0
    results = readJSONs(path)
    for result in results:
        bm_id = int(result.data['instance'][0:2])-1
        if bm_id in selected_bm_ids:
            print(bm_id+1)
            m = Model(result.data['model'])
            metrics, _ = merger.retrieveBenchmarkMetrics(m)
            index = 'BM{}'.format(bm_id+1)
            ct.loc[index,'dSOAP'] = metrics['n_p']
    ct['dSOAP'] = ct['dSOAP'] - bm_table['n pos']
    ct = ct[['total','dSOAP']].copy()
    #ct.to_csv('../benchmark_data/comparison_data/{}.csv'.format(name))
    return ct
c1 = createComparisonTable("../benchmark_data/*det*/*.json", a, c, 'det')
c2 = createComparisonTable("../benchmark_data/*inc*/*.json", b, c, 'inc')
print(c1)
print(c2)
# Out:
# 13
# Encoding: ../encodings/sequential\inputter.lp
# Satisfiable
# Total time: 0.0139617919921875 sec
# CPU time: 0.0 sec
# Grounding time: 0.0109710693359375 sec
# Solving time: 0.00299072265625 sec
# Atoms : 1244
# Rules : 1244
#
# Encoding: ../encodings/sequential\retrieve_bm_metrics.lp
# Satisfiable
# Total time: 0.011966705322265625 sec
# CPU time: 0.0 sec
# Grounding time: 0.008975982666015625 sec
# Solving time: 0.00299072265625 sec
# Atoms : 1160
# Rules : 1160
#
# 14
# Encoding: ../encodings/sequential\inputter.lp
# Satisfiable
# Total time: 0.012964248657226562 sec
# CPU time: 0.0 sec
# Grounding time: 0.00997161865234375 sec
# Solving time: 0.0029926300048828125 sec
# Atoms : 1174
# Rules : 1174
#
# Encoding: ../encodings/sequential\retrieve_bm_metrics.lp
# Satisfiable
# Total time: 0.010969161987304688 sec
# CPU time: 0.0 sec
# Grounding time: 0.007978439331054688 sec
# Solving time: 0.00299072265625 sec
# Atoms : 1083
# Rules : 1083
#
# 20
# Encoding: ../encodings/sequential\inputter.lp
# Satisfiable
# Total time: 0.00698089599609375 sec
# CPU time: 0.015625 sec
# Grounding time: 0.005985260009765625 sec
# Solving time: 0.000995635986328125 sec
# Atoms : 597
# Rules : 597
#
# Encoding: ../encodings/sequential\retrieve_bm_metrics.lp
# Satisfiable
# Total time: 0.004985809326171875 sec
# CPU time: 0.0 sec
# Grounding time: 0.0039882659912109375 sec
# Solving time: 0.0009975433349609375 sec
# Atoms : 452
# Rules : 452
#
# 22
# Encoding: ../encodings/sequential\inputter.lp
# Satisfiable
# Total time: 0.048900604248046875 sec
# CPU time: 0.046875 sec
# Grounding time: 0.03690338134765625 sec
# Solving time: 0.011997222900390625 sec
# Atoms : 4838
# Rules : 4838
#
# Encoding: ../encodings/sequential\retrieve_bm_metrics.lp
# Satisfiable
# Total time: 0.04685020446777344 sec
# CPU time: 0.03125 sec
# Grounding time: 0.033878326416015625 sec
# Solving time: 0.012971878051757812 sec
# Atoms : 4744
# Rules : 4744
#
# 23
# Encoding: ../encodings/sequential\inputter.lp
# Satisfiable
# Total time: 0.01593017578125 sec
# CPU time: 0.015625 sec
# Grounding time: 0.012966156005859375 sec
# Solving time: 0.002964019775390625 sec
# Atoms : 1470
# Rules : 1470
#
# Encoding: ../encodings/sequential\retrieve_bm_metrics.lp
# Satisfiable
# Total time: 0.014957427978515625 sec
# CPU time: 0.015625 sec
# Grounding time: 0.010969161987304688 sec
# Solving time: 0.0039882659912109375 sec
# Atoms : 1422
# Rules : 1422
#
# 25
# Encoding: ../encodings/sequential\inputter.lp
# Satisfiable
# Total time: 0.019947052001953125 sec
# CPU time: 0.03125 sec
# Grounding time: 0.015979766845703125 sec
# Solving time: 0.00396728515625 sec
# Atoms : 1707
# Rules : 1707
#
# Encoding: ../encodings/sequential\retrieve_bm_metrics.lp
# Satisfiable
# Total time: 0.012968063354492188 sec
# CPU time: 0.0 sec
# Grounding time: 0.008975982666015625 sec
# Solving time: 0.0039920806884765625 sec
# Atoms : 1445
# Rules : 1445
#
# 26
# Encoding: ../encodings/sequential\inputter.lp
# Satisfiable
# Total time: 0.011983871459960938 sec
# CPU time: 0.0 sec
# Grounding time: 0.009973526000976562 sec
# Solving time: 0.002010345458984375 sec
# Atoms : 843
# Rules : 843
#
# Encoding: ../encodings/sequential\retrieve_bm_metrics.lp
# Satisfiable
# Total time: 0.007951736450195312 sec
# CPU time: 0.0 sec
# Grounding time: 0.004970550537109375 sec
# Solving time: 0.0029811859130859375 sec
# Atoms : 668
# Rules : 668
#
# 13
# Encoding: ../encodings/sequential\inputter.lp
# Satisfiable
# Total time: 0.0139617919921875 sec
# CPU time: 0.015625 sec
# Grounding time: 0.0109710693359375 sec
# Solving time: 0.00299072265625 sec
# Atoms : 1244
# Rules : 1244
#
# Encoding: ../encodings/sequential\retrieve_bm_metrics.lp
# Satisfiable
# Total time: 0.012966156005859375 sec
# CPU time: 0.015625 sec
# Grounding time: 0.009977340698242188 sec
# Solving time: 0.0029888153076171875 sec
# Atoms : 1160
# Rules : 1160
#
# 14
# Encoding: ../encodings/sequential\inputter.lp
# Satisfiable
# Total time: 0.012964248657226562 sec
# CPU time: 0.015625 sec
# Grounding time: 0.00997161865234375 sec
# Solving time: 0.0029926300048828125 sec
# Atoms : 1186
# Rules : 1186
#
# Encoding: ../encodings/sequential\retrieve_bm_metrics.lp
# Satisfiable
# Total time: 0.00997161865234375 sec
# CPU time: 0.0 sec
# Grounding time: 0.00698089599609375 sec
# Solving time: 0.00299072265625 sec
# Atoms : 1097
# Rules : 1097
#
# 20
# Encoding: ../encodings/sequential\inputter.lp
# Satisfiable
# Total time: 0.0079803466796875 sec
# CPU time: 0.0 sec
# Grounding time: 0.0069828033447265625 sec
# Solving time: 0.0009975433349609375 sec
# Atoms : 597
# Rules : 597
#
# Encoding: ../encodings/sequential\retrieve_bm_metrics.lp
# Satisfiable
# Total time: 0.0049877166748046875 sec
# CPU time: 0.015625 sec
# Grounding time: 0.0039882659912109375 sec
# Solving time: 0.00099945068359375 sec
# Atoms : 452
# Rules : 452
#
# 23
# Encoding: ../encodings/sequential\inputter.lp
# Satisfiable
# Total time: 0.01795196533203125 sec
# CPU time: 0.015625 sec
# Grounding time: 0.012964248657226562 sec
# Solving time: 0.0049877166748046875 sec
# Atoms : 1470
# Rules : 1470
#
# Encoding: ../encodings/sequential\retrieve_bm_metrics.lp
# Satisfiable
# Total time: 0.014949798583984375 sec
# CPU time: 0.015625 sec
# Grounding time: 0.010961532592773438 sec
# Solving time: 0.0039882659912109375 sec
# Atoms : 1426
# Rules : 1426
#
# 25
# Encoding: ../encodings/sequential\inputter.lp
# Satisfiable
# Total time: 0.022939682006835938 sec
# CPU time: 0.03125 sec
# Grounding time: 0.018947601318359375 sec
# Solving time: 0.0039920806884765625 sec
# Atoms : 2043
# Rules : 2043
#
# Encoding: ../encodings/sequential\retrieve_bm_metrics.lp
# Satisfiable
# Total time: 0.016954421997070312 sec
# CPU time: 0.015625 sec
# Grounding time: 0.011966705322265625 sec
# Solving time: 0.0049877166748046875 sec
# Atoms : 1777
# Rules : 1777
#
# 26
# Encoding: ../encodings/sequential\inputter.lp
# Satisfiable
# Total time: 0.012966156005859375 sec
# CPU time: 0.015625 sec
# Grounding time: 0.0109710693359375 sec
# Solving time: 0.001995086669921875 sec
# Atoms : 1050
# Rules : 1050
#
# Encoding: ../encodings/sequential\retrieve_bm_metrics.lp
# Satisfiable
# Total time: 0.008975982666015625 sec
# CPU time: 0.015625 sec
# Grounding time: 0.0059833526611328125 sec
# Solving time: 0.0029926300048828125 sec
# Atoms : 868
# Rules : 868
#
#          total  dSOAP
# BM13  0.358728   20.0
# BM14  0.711729 -353.0
# BM20  0.074800 -116.0
# BM22  3.358461  546.0
# BM23  0.487207  120.0
# BM25  1.412695 -177.0
# BM26  1.770454 -429.0
#          total  dSOAP
# BM13  0.693697   20.0
# BM14  0.717611 -349.0
# BM20  0.072796 -116.0
# BM22  0.000000 -983.0
# BM23  2.826633  120.0
# BM25  0.649776  -65.0
# BM26  1.668715 -362.0

# %%
e = pd.concat([c1,c2,d], axis=1)
e = e.iloc[0:7,:].copy()
#e.to_csv('../benchmark_data/comparison_data/{}.csv'.format('comparison'))
e
# Out:
#          total  dSOAP     total  dSOAP  n robots  n pos  longest path  n vcs  \
# BM13  0.358728   20.0  0.693697   20.0        10    341            47     82
# BM14  0.711729 -353.0  0.717611 -349.0        20    326            32     32
# BM20  0.074800 -116.0  0.072796 -116.0        20    124             7      8
# BM22  3.358461  546.0  0.000000 -983.0        32    983            36    122
# BM23  0.487207  120.0  2.826633  120.0        16    327            22     56
# BM25  1.412695 -177.0  0.649776  -65.0        30    538            26     18
# BM26  1.770454 -429.0  1.668715 -362.0        30    250            17     16
#
#       n robots had vcs  n ecs  n robots had ecs  n fake ecs  \
# BM13                 8      0                 0           0
# BM14                 6      0                 0           0
# BM20                 8      0                 0           0
# BM22                32      0                 0           0
# BM23                16      0                 0           0
# BM25                 9      0                 0           0
# BM26                11      0                 0           2
#
#       n robots had fake ecs
# BM13                      0
# BM14                      0
# BM20                      0
# BM22                      0
# BM23                      0
# BM25                      0
# BM26                      2

# %%
cb = c1.copy()
cb['total'] = c1['total'] < c2['total']
cb['dSOAP'] = c1['dSOAP'] - c2['dSOAP']
#cb.to_csv('../benchmark_data/comparison_data/{}.csv'.format('boolean_comparison'))
cb
# Out:
#       total   dSOAP
# BM13   True     0.0
# BM14   True    -4.0
# BM20  False     0.0
# BM22  False  1529.0
# BM23   True     0.0
# BM25  False  -112.0
# BM26  False   -67.0

# %%
dct = {}
for c in ['total', 'ground', 'solve', 'n conflicts']:
    dct[c] = [0.0]*len(rows)
det_df = pd.DataFrame(dct, index=rows)
det_df = bm_df.astype(int)

# %%
# compare small and big deterministic waiter
for i, bm in enumerate(benchmarks):
    m, _ = merger.switchPlans(merger.getBenchmarkModel(bm), small=True)
    m, _ = merger.switchPlans(m, small=False)
    m, acc_stats = merger.fix_point_solve(m, merger.waiter_det_big, AccumulatedStats())
    occ = m.model.count("final_vertex")
    print("final_vertex occurences: {}\n".format(occ))
    m, acc_stats = merger.convertToAsprilo(m, bm, acc_stats)
    m, _ = merger.checkValidity(m)
    det_df.loc[det_df.index[i]] = [acc_stats.total, acc_stats.groundingTime, acc_stats.solvingTime, occ]
    
#det_df.to_csv('../benchmark_data/comparison_data/det_big_iso.csv')
det_df
# Out:
# Encoding: ../encodings/sequential\inputter.lp
# Satisfiable
# Total time: 0.0009975433349609375 sec
# CPU time: 0.0 sec
# Grounding time: 0.0 sec
# Solving time: 0.0009975433349609375 sec
# Atoms : 26
# Rules : 26
#
# Fix Point Solving Iteration: 1
# Encoding: ../encodings/sequential\merger_ps_small_final.lp
# Satisfiable
# Total time: 0.00698089599609375 sec
# CPU time: 0.0 sec
# Grounding time: 0.00698089599609375 sec
# Solving time: 0.0 sec
# Atoms : 35
# Rules : 36
#
# Cost: [4, 5]
#
# Fix Point Solving Iteration: 2
# Encoding: ../encodings/sequential\merger_ps_small_final.lp
# Satisfiable
# Total time: 0.0039882659912109375 sec
# CPU time: 0.03125 sec
# Grounding time: 0.0039882659912109375 sec
# Solving time: 0.0 sec
# Atoms : 35
# Rules : 36
#
# Cost: [4, 5]
#
# Fix Point Solving Iteration: 1
# Encoding: ../encodings/sequential\merger_ps_big_final.lp
# Satisfiable
# Total time: 0.00698089599609375 sec
# CPU time: 0.0 sec
# Grounding time: 0.00698089599609375 sec
# Solving time: 0.0 sec
# Atoms : 35
# Rules : 35
#
# Cost: [5]
#
# Fix Point Solving Iteration: 2
# Encoding: ../encodings/sequential\merger_ps_big_final.lp
# Satisfiable
# Total time: 0.0039882659912109375 sec
# CPU time: 0.015625 sec
# Grounding time: 0.0039882659912109375 sec
# Solving time: 0.0 sec
# Atoms : 35
# Rules : 35
#
# Cost: [5]
#
# Fix Point Solving Iteration: 1
# Encoding: ../encodings/sequential\merger_w_det_big_final.lp
# Satisfiable
# Total time: 0.0039882659912109375 sec
# CPU time: 0.0 sec
# Grounding time: 0.0039882659912109375 sec
# Solving time: 0.0 sec
# Atoms : 31
# Rules : 27
#
# Cost: []
#
# Fix Point Solving Iteration: 2
# Encoding: ../encodings/sequential\merger_w_det_big_final.lp
# Satisfiable
# Total time: 0.0049877166748046875 sec
# CPU time: 0.0 sec
# Grounding time: 0.00399017333984375 sec
# Solving time: 0.0009975433349609375 sec
# Atoms : 31
# Rules : 27
#
# Cost: []
#
# final_vertex occurences: 0
#
# Encoding: ../encodings/sequential\outputter.lp
# Satisfiable
# Total time: 0.0050067901611328125 sec
# CPU time: 0.0 sec
# Grounding time: 0.0050067901611328125 sec
# Solving time: 0.0 sec
# Atoms : 23
# Rules : 22
#
# Encoding: ../encodings/sequential\validity_checker.lp
# Satisfiable
# Total time: 0.001995086669921875 sec
# CPU time: 0.0 sec
# Grounding time: 0.001995086669921875 sec
# Solving time: 0.0 sec
# Atoms : 57
# Rules : 57
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_17792/1987027824.py in <module>
#       8     m, acc_stats = merger.convertToAsprilo(m, bm, acc_stats)
#       9     m, _ = merger.checkValidity(m)
# ---> 10     det_df.loc[det_df.index[i]] = [acc_stats.total, acc_stats.groundingTime, acc_stats.solvingTime, occ]
#      11
#      12 #det_df.to_csv('../benchmark_data/comparison_data/det_big_iso.csv')
#
# ~\miniconda3\envs\py39\lib\site-packages\pandas\core\indexing.py in __setitem__(self, key, value)
#     714
#     715         iloc = self if self.name == "iloc" else self.obj.iloc
# --> 716         iloc._setitem_with_indexer(indexer, value, self.name)
#     717
#     718     def _validate_key(self, key, axis: int):
#
# ~\miniconda3\envs\py39\lib\site-packages\pandas\core\indexing.py in _setitem_with_indexer(self, indexer, value, name)
#    1686         if take_split_path:
#    1687             # We have to operate column-wise
# -> 1688             self._setitem_with_indexer_split_path(indexer, value, name)
#    1689         else:
#    1690             self._setitem_single_block(indexer, value, name)
#
# ~\miniconda3\envs\py39\lib\site-packages\pandas\core\indexing.py in _setitem_with_indexer_split_path(self, indexer, value, name)
#    1768
#    1769             else:
# -> 1770                 raise ValueError(
#    1771                     "Must have equal len keys and value "
#    1772                     "when setting with an iterable"
#
# ValueError: Must have equal len keys and value when setting with an iterable

# %%
det_small = pd.read_csv('../benchmark_data/comparison_data/det_small_iso.csv', index_col=0)
det_big = pd.read_csv('../benchmark_data/comparison_data/det_big_iso.csv', index_col=0)
#dif_df = det_small.copy()
#dif_df['total'] = det_small['total'] - det_big['total']
#dif_df['total']
# Out:
#               total  n conflicts
# det small
# BM13       0.171535            0
# BM14       0.064825            0
# BM20       0.027929            0
# BM22       2.940250            0
# BM23       0.292009            0
# BM25       0.064825           12
# BM26       0.033897           10

# %%
det_small['total']
# Out:
# BM1     0.009983
# BM2     0.008997
# BM3     0.009008
# BM4     0.009987
# BM5     0.008980
# BM6     0.008007
# BM7     0.009991
# BM8     0.020489
# BM9     0.011971
# BM10    0.010906
# BM11    0.009972
# BM12    0.011980
# BM13    0.171535
# BM14    0.064825
# BM15    0.008951
# BM16    0.011946
# BM17    0.017986
# BM18    0.014006
# BM19    0.015928
# BM20    0.027929
# BM21    0.015965
# BM22    2.940250
# BM23    0.292009
# BM24    0.042248
# BM25    0.064825
# BM26    0.033897
# Name: total, dtype: float64
