# %% [markdown]
# # Evaluation
#
# doing evaluation stuff here...

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from iclingo import Clingo, Model
import funcs
from funcs import BMDataFormat, AccumulatedStats
import matplotlib.pyplot as plt
import numpy as np
import os
import files
import glob
import json

# %%
#create a data frame
benchmarks = funcs.getAllBenchmarks('../benchmarks')
cols = ['total','ground','solve']
rows = ['BM{}'.format(i+1) for i, bm in enumerate(benchmarks)]
dct = {}
for c in cols:
    dct[c] = [0.0]*len(rows)
df = pd.DataFrame(dct, index=rows)

# %%
# reading json benchmark data
def readJSONs(path):
    files = glob.glob(path)
    bmdfs = []
    for file in files:
        bmdfs.append(BMDataFormat())
        bmdfs[-1].load(file)
    return bmdfs
bmdfs = readJSONs("../benchmark_data/*inc*/*.json")

# %%
# insert benchmark data into data frame
for bmdf in bmdfs:
    df.loc[df.index[int(bmdf.data['instance'][0:2])-1]] = [
                  bmdf.data['statistics']['total'],
                  bmdf.data['statistics']['groundingTime'],
                  bmdf.data['statistics']['solvingTime']
                 ]
df.to_csv('../benchmark_data/merger_ps_small_final+merger_w_inc2/merger_ps_small_final+merger_w_inc2.csv')
df
# Out:
#          total    ground     solve
# BM1   0.010992  0.009985  0.001007
# BM2   0.015923  0.014925  0.000998
# BM3   0.013985  0.013985  0.000000
# BM4   0.000000  0.000000  0.000000
# BM5   0.018906  0.018906  0.000000
# BM6   0.014938  0.013922  0.001017
# BM7   0.019947  0.017950  0.001997
# BM8   0.074802  0.059841  0.014961
# BM9   0.016977  0.014982  0.001995
# BM10  0.015957  0.013960  0.001997
# BM11  0.017969  0.016972  0.000998
# BM12  0.013985  0.013985  0.000000
# BM13  0.693697  0.579319  0.114378
# BM14  0.717611  0.307650  0.409962
# BM15  0.015938  0.015938  0.000000
# BM16  0.022938  0.022938  0.000000
# BM17  0.022938  0.019947  0.002991
# BM18  0.023933  0.021942  0.001991
# BM19  0.049864  0.034906  0.014957
# BM20  0.072796  0.041878  0.030918
# BM21  0.035904  0.026926  0.008978
# BM22  0.000000  0.000000  0.000000
# BM23  2.826633  1.622564  1.204069
# BM24  0.271311  0.189558  0.081753
# BM25  0.649776  0.239357  0.410419
# BM26  1.668715  0.231394  1.437321

# %%
from merger import Merger
# initialize merger
merger = Merger("../encodings/sequential", "../benchmark_data")
def merge(benchmark_id):
        benchmark = benchmarks[benchmark_id-1]
        return merger.merge(benchmark, vizualize=True, save_data=True, deterministic_waiter=True, check_validity=True, automated=False)
        
def mergeAll(exclude=[22,23,26]):
    for i in range(len(benchmarks)):
        benchmark_id = i+1
        benchmark = benchmarks[i]
        if benchmark_id in exclude:
            continue
        print("################## {} ###################".format(benchmark))
        merger.merge(benchmark, vizualize=False, save_data=True, automated=False, deterministic_waiter=True, check_validity=True)

# %%
# test merging here
#m, _ = merger.merge(benchmarks[26-1], vizualize=True, save_data=False, automated=True, deterministic_waiter=True, check_validity=True)
#m.model
#s, _ = merger.retrieveBenchmarkMetrics(m)
#s:q

#mergeAll([])

# %%
dct = {}
for c in ['n robots',
          'n pos',
          'longest path',
          'n vcs',
          'n robots had vcs',
          'n ecs',
          'n robots had ecs',
          'n fake ecs',
          'n robots had fake ecs']:
    dct[c] = [0.0]*len(rows)
bm_df = pd.DataFrame(dct, index=rows)
bm_df = bm_df.astype(int)

# %%
for i, bm in enumerate(benchmarks):
    bm_id = i+1
    #m, _ = merger.switchPlans(merger.getBenchmarkModel(bm), small=True)
    #m, _ = merger.switchPlans(merger.getBenchmarkModel(bm), small=False)
    #m, _ = merger.convertToAsprilo(m,bm)
    metrics, _ = merger.retrieveBenchmarkMetrics(bm)
    bm_df.loc[bm_df.index[i]] = [metrics['n_r'],
                           metrics['n_p'],
                           metrics['n_lp'],
                           metrics['n_vc'],
                           metrics['r_vc'],
                           metrics['n_ec'],
                           metrics['r_ec'],
                           metrics['n_fec'],
                           metrics['r_fec']]
#bm_df.to_csv('../benchmark_data/benchmark_metrics/bm_metrics.csv')
bm_df
# Out:
# Encoding: ../encodings/sequential\inputter.lp
# Satisfiable
# Total time: 0.0009975433349609375 sec
# CPU time: 0.0 sec
# Grounding time: 0.0009975433349609375 sec
# Solving time: 0.0 sec
# Atoms : 26
# Rules : 26
#
# Encoding: ../encodings/sequential\retrieve_bm_metrics.lp
# Satisfiable
# Total time: 0.000995635986328125 sec
# CPU time: 0.0 sec
# Grounding time: 0.000995635986328125 sec
# Solving time: 0.0 sec
# Atoms : 23
# Rules : 23
#
# Encoding: ../encodings/sequential\inputter.lp
# Satisfiable
# Total time: 0.0019931793212890625 sec
# CPU time: 0.0 sec
# Grounding time: 0.0019931793212890625 sec
# Solving time: 0.0 sec
# Atoms : 62
# Rules : 62
#
# Encoding: ../encodings/sequential\retrieve_bm_metrics.lp
# Satisfiable
# Total time: 0.00201416015625 sec
# CPU time: 0.0 sec
# Grounding time: 0.00201416015625 sec
# Solving time: 0.0 sec
# Atoms : 59
# Rules : 59
#
# Encoding: ../encodings/sequential\inputter.lp
# Satisfiable
# Total time: 0.0020160675048828125 sec
# CPU time: 0.0 sec
# Grounding time: 0.0010204315185546875 sec
# Solving time: 0.000995635986328125 sec
# Atoms : 52
# Rules : 52
#
# Encoding: ../encodings/sequential\retrieve_bm_metrics.lp
# Satisfiable
# Total time: 0.001995086669921875 sec
# CPU time: 0.015625 sec
# Grounding time: 0.001995086669921875 sec
# Solving time: 0.0 sec
# Atoms : 44
# Rules : 44
#
# Encoding: ../encodings/sequential\inputter.lp
# Satisfiable
# Total time: 0.0009975433349609375 sec
# CPU time: 0.0 sec
# Grounding time: 0.0009975433349609375 sec
# Solving time: 0.0 sec
# Atoms : 28
# Rules : 28
#
# Encoding: ../encodings/sequential\retrieve_bm_metrics.lp
# Satisfiable
# Total time: 0.000995635986328125 sec
# CPU time: 0.0 sec
# Grounding time: 0.000995635986328125 sec
# Solving time: 0.0 sec
# Atoms : 43
# Rules : 43
#
# Encoding: ../encodings/sequential\inputter.lp
# Satisfiable
# Total time: 0.0019931793212890625 sec
# CPU time: 0.0 sec
# Grounding time: 0.000995635986328125 sec
# Solving time: 0.0009975433349609375 sec
# Atoms : 42
# Rules : 42
#
# Encoding: ../encodings/sequential\retrieve_bm_metrics.lp
# Satisfiable
# Total time: 0.001995086669921875 sec
# CPU time: 0.015625 sec
# Grounding time: 0.001995086669921875 sec
# Solving time: 0.0 sec
# Atoms : 45
# Rules : 45
#
# Encoding: ../encodings/sequential\inputter.lp
# Satisfiable
# Total time: 0.0009975433349609375 sec
# CPU time: 0.0 sec
# Grounding time: 0.0009975433349609375 sec
# Solving time: 0.0 sec
# Atoms : 54
# Rules : 54
#
# Encoding: ../encodings/sequential\retrieve_bm_metrics.lp
# Satisfiable
# Total time: 0.00199127197265625 sec
# CPU time: 0.0 sec
# Grounding time: 0.00199127197265625 sec
# Solving time: 0.0 sec
# Atoms : 57
# Rules : 57
#
# Encoding: ../encodings/sequential\inputter.lp
# Satisfiable
# Total time: 0.000995635986328125 sec
# CPU time: 0.0 sec
# Grounding time: 0.000995635986328125 sec
# Solving time: 0.0 sec
# Atoms : 60
# Rules : 60
#
# Encoding: ../encodings/sequential\retrieve_bm_metrics.lp
# Satisfiable
# Total time: 0.001995086669921875 sec
# CPU time: 0.015625 sec
# Grounding time: 0.001995086669921875 sec
# Solving time: 0.0 sec
# Atoms : 65
# Rules : 65
#
# Encoding: ../encodings/sequential\inputter.lp
# Satisfiable
# Total time: 0.00299072265625 sec
# CPU time: 0.0 sec
# Grounding time: 0.00299072265625 sec
# Solving time: 0.0 sec
# Atoms : 193
# Rules : 193
#
# Encoding: ../encodings/sequential\retrieve_bm_metrics.lp
# Satisfiable
# Total time: 0.00299072265625 sec
# CPU time: 0.0 sec
# Grounding time: 0.00299072265625 sec
# Solving time: 0.0 sec
# Atoms : 186
# Rules : 186
#
# Encoding: ../encodings/sequential\inputter.lp
# Satisfiable
# Total time: 0.000995635986328125 sec
# CPU time: 0.0 sec
# Grounding time: 0.000995635986328125 sec
# Solving time: 0.0 sec
# Atoms : 74
# Rules : 74
#
# Encoding: ../encodings/sequential\retrieve_bm_metrics.lp
# Satisfiable
# Total time: 0.001995086669921875 sec
# CPU time: 0.0 sec
# Grounding time: 0.0009975433349609375 sec
# Solving time: 0.0009975433349609375 sec
# Atoms : 78
# Rules : 78
#
# Encoding: ../encodings/sequential\inputter.lp
# Satisfiable
# Total time: 0.0019931793212890625 sec
# CPU time: 0.0 sec
# Grounding time: 0.000995635986328125 sec
# Solving time: 0.0009975433349609375 sec
# Atoms : 54
# Rules : 54
#
# Encoding: ../encodings/sequential\retrieve_bm_metrics.lp
# Satisfiable
# Total time: 0.000995635986328125 sec
# CPU time: 0.0 sec
# Grounding time: 0.000995635986328125 sec
# Solving time: 0.0 sec
# Atoms : 60
# Rules : 60
#
# Encoding: ../encodings/sequential\inputter.lp
# Satisfiable
# Total time: 0.0009975433349609375 sec
# CPU time: 0.0 sec
# Grounding time: 0.0009975433349609375 sec
# Solving time: 0.0 sec
# Atoms : 67
# Rules : 67
#
# Encoding: ../encodings/sequential\retrieve_bm_metrics.lp
# Satisfiable
# Total time: 0.001995086669921875 sec
# CPU time: 0.0 sec
# Grounding time: 0.001995086669921875 sec
# Solving time: 0.0 sec
# Atoms : 72
# Rules : 72
#
# Encoding: ../encodings/sequential\inputter.lp
# Satisfiable
# Total time: 0.0019931793212890625 sec
# CPU time: 0.0 sec
# Grounding time: 0.0009975433349609375 sec
# Solving time: 0.000995635986328125 sec
# Atoms : 53
# Rules : 53
#
# Encoding: ../encodings/sequential\retrieve_bm_metrics.lp
# Satisfiable
# Total time: 0.001995086669921875 sec
# CPU time: 0.0 sec
# Grounding time: 0.000995635986328125 sec
# Solving time: 0.00099945068359375 sec
# Atoms : 55
# Rules : 55
#
# Encoding: ../encodings/sequential\inputter.lp
# Satisfiable
# Total time: 0.011968612670898438 sec
# CPU time: 0.015625 sec
# Grounding time: 0.008975982666015625 sec
# Solving time: 0.0029926300048828125 sec
# Atoms : 1184
# Rules : 1184
#
# Encoding: ../encodings/sequential\retrieve_bm_metrics.lp
# Satisfiable
# Total time: 0.0109710693359375 sec
# CPU time: 0.015625 sec
# Grounding time: 0.00698089599609375 sec
# Solving time: 0.00399017333984375 sec
# Atoms : 1212
# Rules : 1212
#
# Encoding: ../encodings/sequential\inputter.lp
# Satisfiable
# Total time: 0.02294921875 sec
# CPU time: 0.03125 sec
# Grounding time: 0.017953872680664062 sec
# Solving time: 0.0049953460693359375 sec
# Atoms : 2233
# Rules : 2233
#
# Encoding: ../encodings/sequential\retrieve_bm_metrics.lp
# Satisfiable
# Total time: 0.020917892456054688 sec
# CPU time: 0.015625 sec
# Grounding time: 0.014934539794921875 sec
# Solving time: 0.0059833526611328125 sec
# Atoms : 2394
# Rules : 2394
#
# Encoding: ../encodings/sequential\inputter.lp
# Satisfiable
# Total time: 0.001026153564453125 sec
# CPU time: 0.0 sec
# Grounding time: 0.001026153564453125 sec
# Solving time: 0.0 sec
# Atoms : 34
# Rules : 34
#
# Encoding: ../encodings/sequential\retrieve_bm_metrics.lp
# Satisfiable
# Total time: 0.0010166168212890625 sec
# CPU time: 0.0 sec
# Grounding time: 0.0010166168212890625 sec
# Solving time: 0.0 sec
# Atoms : 41
# Rules : 41
#
# Encoding: ../encodings/sequential\inputter.lp
# Satisfiable
# Total time: 0.00202178955078125 sec
# CPU time: 0.0 sec
# Grounding time: 0.001018524169921875 sec
# Solving time: 0.001003265380859375 sec
# Atoms : 76
# Rules : 76
#
# Encoding: ../encodings/sequential\retrieve_bm_metrics.lp
# Satisfiable
# Total time: 0.001995086669921875 sec
# CPU time: 0.0 sec
# Grounding time: 0.001995086669921875 sec
# Solving time: 0.0 sec
# Atoms : 80
# Rules : 80
#
# Encoding: ../encodings/sequential\inputter.lp
# Satisfiable
# Total time: 0.004009246826171875 sec
# CPU time: 0.0 sec
# Grounding time: 0.003009796142578125 sec
# Solving time: 0.00099945068359375 sec
# Atoms : 256
# Rules : 256
#
# Encoding: ../encodings/sequential\retrieve_bm_metrics.lp
# Satisfiable
# Total time: 0.0040149688720703125 sec
# CPU time: 0.0 sec
# Grounding time: 0.0030117034912109375 sec
# Solving time: 0.001003265380859375 sec
# Atoms : 263
# Rules : 263
#
# Encoding: ../encodings/sequential\inputter.lp
# Satisfiable
# Total time: 0.0020236968994140625 sec
# CPU time: 0.0 sec
# Grounding time: 0.0020236968994140625 sec
# Solving time: 0.0 sec
# Atoms : 107
# Rules : 107
#
# Encoding: ../encodings/sequential\retrieve_bm_metrics.lp
# Satisfiable
# Total time: 0.00200653076171875 sec
# CPU time: 0.0 sec
# Grounding time: 0.00200653076171875 sec
# Solving time: 0.0 sec
# Atoms : 122
# Rules : 122
#
# Encoding: ../encodings/sequential\inputter.lp
# Satisfiable
# Total time: 0.0040149688720703125 sec
# CPU time: 0.0 sec
# Grounding time: 0.003021240234375 sec
# Solving time: 0.0009937286376953125 sec
# Atoms : 265
# Rules : 265
#
# Encoding: ../encodings/sequential\retrieve_bm_metrics.lp
# Satisfiable
# Total time: 0.0039920806884765625 sec
# CPU time: 0.015625 sec
# Grounding time: 0.00299072265625 sec
# Solving time: 0.0010013580322265625 sec
# Atoms : 304
# Rules : 304
#
# Encoding: ../encodings/sequential\inputter.lp
# Satisfiable
# Total time: 0.009979248046875 sec
# CPU time: 0.015625 sec
# Grounding time: 0.007984161376953125 sec
# Solving time: 0.001995086669921875 sec
# Atoms : 945
# Rules : 945
#
# Encoding: ../encodings/sequential\retrieve_bm_metrics.lp
# Satisfiable
# Total time: 0.008968353271484375 sec
# CPU time: 0.0 sec
# Grounding time: 0.0059757232666015625 sec
# Solving time: 0.0029926300048828125 sec
# Atoms : 890
# Rules : 890
#
# Encoding: ../encodings/sequential\inputter.lp
# Satisfiable
# Total time: 0.004985809326171875 sec
# CPU time: 0.015625 sec
# Grounding time: 0.0039882659912109375 sec
# Solving time: 0.0009975433349609375 sec
# Atoms : 413
# Rules : 413
#
# Encoding: ../encodings/sequential\retrieve_bm_metrics.lp
# Satisfiable
# Total time: 0.005008697509765625 sec
# CPU time: 0.0 sec
# Grounding time: 0.0030155181884765625 sec
# Solving time: 0.0019931793212890625 sec
# Atoms : 414
# Rules : 414
#
# Encoding: ../encodings/sequential\inputter.lp
# Satisfiable
# Total time: 0.03191947937011719 sec
# CPU time: 0.03125 sec
# Grounding time: 0.024934768676757812 sec
# Solving time: 0.006984710693359375 sec
# Atoms : 3200
# Rules : 3200
#
# Encoding: ../encodings/sequential\retrieve_bm_metrics.lp
# Satisfiable
# Total time: 0.030885696411132812 sec
# CPU time: 0.03125 sec
# Grounding time: 0.022905349731445312 sec
# Solving time: 0.0079803466796875 sec
# Atoms : 3235
# Rules : 3235
#
# Encoding: ../encodings/sequential\inputter.lp
# Satisfiable
# Total time: 0.010942459106445312 sec
# CPU time: 0.015625 sec
# Grounding time: 0.00894927978515625 sec
# Solving time: 0.0019931793212890625 sec
# Atoms : 1110
# Rules : 1110
#
# Encoding: ../encodings/sequential\retrieve_bm_metrics.lp
# Satisfiable
# Total time: 0.010980606079101562 sec
# CPU time: 0.015625 sec
# Grounding time: 0.007976531982421875 sec
# Solving time: 0.0030040740966796875 sec
# Atoms : 1123
# Rules : 1123
#
# Encoding: ../encodings/sequential\inputter.lp
# Satisfiable
# Total time: 0.0039615631103515625 sec
# CPU time: 0.0 sec
# Grounding time: 0.0029621124267578125 sec
# Solving time: 0.00099945068359375 sec
# Atoms : 408
# Rules : 408
#
# Encoding: ../encodings/sequential\retrieve_bm_metrics.lp
# Satisfiable
# Total time: 0.0049953460693359375 sec
# CPU time: 0.015625 sec
# Grounding time: 0.00399017333984375 sec
# Solving time: 0.0010051727294921875 sec
# Atoms : 422
# Rules : 422
#
# Encoding: ../encodings/sequential\inputter.lp
# Satisfiable
# Total time: 0.023942947387695312 sec
# CPU time: 0.03125 sec
# Grounding time: 0.018957138061523438 sec
# Solving time: 0.004985809326171875 sec
# Atoms : 2238
# Rules : 2238
#
# Encoding: ../encodings/sequential\retrieve_bm_metrics.lp
# Satisfiable
# Total time: 0.017948150634765625 sec
# CPU time: 0.015625 sec
# Grounding time: 0.012960433959960938 sec
# Solving time: 0.0049877166748046875 sec
# Atoms : 2043
# Rules : 2043
#
# Encoding: ../encodings/sequential\inputter.lp
# Satisfiable
# Total time: 0.021913528442382812 sec
# CPU time: 0.03125 sec
# Grounding time: 0.016958236694335938 sec
# Solving time: 0.004955291748046875 sec
# Atoms : 2130
# Rules : 2130
#
# Encoding: ../encodings/sequential\retrieve_bm_metrics.lp
# Satisfiable
# Total time: 0.021944046020507812 sec
# CPU time: 0.015625 sec
# Grounding time: 0.01493072509765625 sec
# Solving time: 0.0070133209228515625 sec
# Atoms : 2250
# Rules : 2250
#       n robots  n pos  longest path  n vcs  n robots had vcs  n ecs  \
# BM1          1      5             5      0                 0      0
# BM2          2     14             7      0                 0      2
# BM3          2     10             5      1                 2      0
# BM4          4      8             2      1                 4      0
# BM5          2     10             5      2                 2      0
# BM6          4     12             3      2                 4      0
# BM7          3     15             5      3                 3      0
# BM8          6     48             9      9                 6      0
# BM9          3     19             7      3                 2      0
# BM10         3     13             5      1                 2      2
# BM11         3     17             6      4                 2      0
# BM12         2     13             8      1                 1      0
# BM13        10    341            48    102                 9      0
# BM14        20    684            55    135                18     26
# BM15         2      8             4      1                 2      0
# BM16         3     19             7      0                 0      4
# BM17         7     68            17      2                 4      6
# BM18         4     28             7      9                 4      0
# BM19         8     72            10     22                 8      4
# BM20        20    244            13     25                20      0
# BM21        12    104             9     13                12      0
# BM22        32    983            36    122                32      0
# BM23        16    327            22     56                16      0
# BM24         8    116            16     26                 8      0
# BM25        30    618            30     33                17      8
# BM26        30    615            26    126                28     40
#
#       n robots had ecs  n fake ecs  n robots had fake ecs
# BM1                  0           0                      0
# BM2                  2           0                      0
# BM3                  0           0                      0
# BM4                  0           0                      0
# BM5                  0           0                      0
# BM6                  0           0                      0
# BM7                  0           0                      0
# BM8                  0           0                      0
# BM9                  0           0                      0
# BM10                 2           0                      0
# BM11                 0           0                      0
# BM12                 0           0                      0
# BM13                 0           0                      0
# BM14                12          24                     12
# BM15                 0           2                      2
# BM16                 3           0                      0
# BM17                 5           2                      2
# BM18                 0           2                      4
# BM19                 8           4                      8
# BM20                 0          20                     20
# BM21                 0          20                     12
# BM22                 0           0                      0
# BM23                 0           0                      0
# BM24                 0           0                      0
# BM25                 7           2                      2
# BM26                26          42                     27

# %%
#pd.concat([df, bm_df], axis=1)
a = pd.read_csv('../benchmark_data/merger_ps_small_final+merger_ps_big_final+merger_w_det_big_final/merger_ps_small_final+merger_ps_big_final+merger_w_det_big_final.csv', index_col=0)
b = pd.read_csv('../benchmark_data/merger_ps_small_final+merger_w_inc2/merger_ps_small_final+merger_w_inc2.csv', index_col=0)
c = pd.read_csv('../benchmark_data/benchmark_metrics/bm_metrics.csv', index_col=0)
d = pd.read_csv('../benchmark_data/benchmark_metrics/bm_metrics_after_ps_small.csv', index_col=0)

e = pd.concat([a,b,c], axis=1)
f = e[['total','n vcs', 'n robots had vcs']].copy()
f['det wins'] = a['total'] - b['total'] < 0
d
# Out:
#       n robots  n pos  longest path  n vcs  n robots had vcs  n ecs  \
# BM1          1      5             5      0                 0      0
# BM2          2     12             6      0                 0      0
# BM3          2     10             5      1                 2      0
# BM4          4      8             2      1                 4      0
# BM5          2     10             5      2                 2      0
# BM6          4     12             3      2                 4      0
# BM7          3     15             5      3                 3      0
# BM8          6     48             9      9                 6      0
# BM9          3     19             7      3                 2      0
# BM10         3     11             4      0                 0      0
# BM11         3     17             6      4                 2      0
# BM12         2     13             7      0                 0      0
# BM13        10    341            47     82                 8      0
# BM14        20    326            32     32                 6      0
# BM15         2      4             2      0                 0      0
# BM16         3     11             6      0                 0      0
# BM17         7     32             9      0                 0      0
# BM18         4     20             5      6                 4      0
# BM19         8     56             7     12                 8      0
# BM20        20    124             7      8                 8      0
# BM21        12     56             5      4                 8      0
# BM22        32    983            36    122                32      0
# BM23        16    327            22     56                16      0
# BM24         8    116            16     26                 8      0
# BM25        30    538            26     18                 9      0
# BM26        30    250            17     16                11      0
#
#       n robots had ecs  n fake ecs  n robots had fake ecs
# BM1                  0           0                      0
# BM2                  0           0                      0
# BM3                  0           0                      0
# BM4                  0           0                      0
# BM5                  0           0                      0
# BM6                  0           0                      0
# BM7                  0           0                      0
# BM8                  0           0                      0
# BM9                  0           0                      0
# BM10                 0           0                      0
# BM11                 0           0                      0
# BM12                 0           0                      0
# BM13                 0           0                      0
# BM14                 0           0                      0
# BM15                 0           0                      0
# BM16                 0           0                      0
# BM17                 0           0                      0
# BM18                 0           0                      0
# BM19                 0           0                      0
# BM20                 0           0                      0
# BM21                 0           0                      0
# BM22                 0           0                      0
# BM23                 0           0                      0
# BM24                 0           0                      0
# BM25                 0           0                      0
# BM26                 0           2                      2

# %%
# creating the comparison table
def createComparisonTable(path, table, bm_table, name):
    selected_bm_ids = [12,13,19,21,22,24,25]
    ct = table.iloc[selected_bm_ids,:].copy()
    ct['dSOAP'] = 0.0
    results = readJSONs(path)
    for result in results:
        bm_id = int(result.data['instance'][0:2])-1
        if bm_id in selected_bm_ids:
            print(bm_id+1)
            m = Model(result.data['model'])
            metrics, _ = merger.retrieveBenchmarkMetrics(m)
            index = 'BM{}'.format(bm_id+1)
            ct.loc[index,'dSOAP'] = metrics['n_p']
    ct['dSOAP'] = ct['dSOAP'] - bm_table['n pos']
    ct = ct[['total','dSOAP']].copy()
    #ct.to_csv('../benchmark_data/comparison_data/{}.csv'.format(name))
    return ct
c1 = createComparisonTable("../benchmark_data/*det*/*.json", a, c, 'det')
c2 = createComparisonTable("../benchmark_data/*inc*/*.json", b, c, 'inc')
print(c1)
print(c2)
# Out:
# 13
# Encoding: ../encodings/sequential\inputter.lp
# Satisfiable
# Total time: 0.014959335327148438 sec
# CPU time: 0.015625 sec
# Grounding time: 0.011968612670898438 sec
# Solving time: 0.00299072265625 sec
# Atoms : 1244
# Rules : 1244
#
# Encoding: ../encodings/sequential\retrieve_bm_metrics.lp
# Satisfiable
# Total time: 0.011964797973632812 sec
# CPU time: 0.015625 sec
# Grounding time: 0.00897216796875 sec
# Solving time: 0.0029926300048828125 sec
# Atoms : 1160
# Rules : 1160
#
# 14
# Encoding: ../encodings/sequential\inputter.lp
# Satisfiable
# Total time: 0.012937545776367188 sec
# CPU time: 0.015625 sec
# Grounding time: 0.009979248046875 sec
# Solving time: 0.0029582977294921875 sec
# Atoms : 1174
# Rules : 1174
#
# Encoding: ../encodings/sequential\retrieve_bm_metrics.lp
# Satisfiable
# Total time: 0.010000228881835938 sec
# CPU time: 0.015625 sec
# Grounding time: 0.00701141357421875 sec
# Solving time: 0.0029888153076171875 sec
# Atoms : 1083
# Rules : 1083
#
# 20
# Encoding: ../encodings/sequential\inputter.lp
# Satisfiable
# Total time: 0.006992340087890625 sec
# CPU time: 0.0 sec
# Grounding time: 0.0059947967529296875 sec
# Solving time: 0.0009975433349609375 sec
# Atoms : 597
# Rules : 597
#
# Encoding: ../encodings/sequential\retrieve_bm_metrics.lp
# Satisfiable
# Total time: 0.00399017333984375 sec
# CPU time: 0.0 sec
# Grounding time: 0.002994537353515625 sec
# Solving time: 0.000995635986328125 sec
# Atoms : 452
# Rules : 452
#
# 22
# Encoding: ../encodings/sequential\inputter.lp
# Satisfiable
# Total time: 0.03127288818359375 sec
# CPU time: 0.03125 sec
# Grounding time: 0.03127288818359375 sec
# Solving time: 0.0 sec
# Atoms : 4838
# Rules : 4838
#
# Encoding: ../encodings/sequential\retrieve_bm_metrics.lp
# Satisfiable
# Total time: 0.031244277954101562 sec
# CPU time: 0.03125 sec
# Grounding time: 0.015588760375976562 sec
# Solving time: 0.015655517578125 sec
# Atoms : 4744
# Rules : 4744
#
# 23
# Encoding: ../encodings/sequential\inputter.lp
# Satisfiable
# Total time: 0.015613555908203125 sec
# CPU time: 0.015625 sec
# Grounding time: 0.015613555908203125 sec
# Solving time: 0.0 sec
# Atoms : 1470
# Rules : 1470
#
# Encoding: ../encodings/sequential\retrieve_bm_metrics.lp
# Satisfiable
# Total time: 0.015626907348632812 sec
# CPU time: 0.015625 sec
# Grounding time: 0.015626907348632812 sec
# Solving time: 0.0 sec
# Atoms : 1422
# Rules : 1422
#
# 25
# Encoding: ../encodings/sequential\inputter.lp
# Satisfiable
# Total time: 0.0182952880859375 sec
# CPU time: 0.015625 sec
# Grounding time: 0.014295578002929688 sec
# Solving time: 0.0039997100830078125 sec
# Atoms : 1707
# Rules : 1707
#
# Encoding: ../encodings/sequential\retrieve_bm_metrics.lp
# Satisfiable
# Total time: 0.012956619262695312 sec
# CPU time: 0.015625 sec
# Grounding time: 0.008966445922851562 sec
# Solving time: 0.00399017333984375 sec
# Atoms : 1445
# Rules : 1445
#
# 26
# Encoding: ../encodings/sequential\inputter.lp
# Satisfiable
# Total time: 0.00897979736328125 sec
# CPU time: 0.0 sec
# Grounding time: 0.0079803466796875 sec
# Solving time: 0.00099945068359375 sec
# Atoms : 843
# Rules : 843
#
# Encoding: ../encodings/sequential\retrieve_bm_metrics.lp
# Satisfiable
# Total time: 0.00595855712890625 sec
# CPU time: 0.015625 sec
# Grounding time: 0.004962921142578125 sec
# Solving time: 0.000995635986328125 sec
# Atoms : 668
# Rules : 668
#
# 13
# Encoding: ../encodings/sequential\inputter.lp
# Satisfiable
# Total time: 0.012983322143554688 sec
# CPU time: 0.015625 sec
# Grounding time: 0.009990692138671875 sec
# Solving time: 0.0029926300048828125 sec
# Atoms : 1244
# Rules : 1244
#
# Encoding: ../encodings/sequential\retrieve_bm_metrics.lp
# Satisfiable
# Total time: 0.0109710693359375 sec
# CPU time: 0.015625 sec
# Grounding time: 0.0079803466796875 sec
# Solving time: 0.00299072265625 sec
# Atoms : 1160
# Rules : 1160
#
# 14
# Encoding: ../encodings/sequential\inputter.lp
# Satisfiable
# Total time: 0.012964248657226562 sec
# CPU time: 0.015625 sec
# Grounding time: 0.0109710693359375 sec
# Solving time: 0.0019931793212890625 sec
# Atoms : 1186
# Rules : 1186
#
# Encoding: ../encodings/sequential\retrieve_bm_metrics.lp
# Satisfiable
# Total time: 0.00997161865234375 sec
# CPU time: 0.015625 sec
# Grounding time: 0.006977081298828125 sec
# Solving time: 0.002994537353515625 sec
# Atoms : 1097
# Rules : 1097
#
# 20
# Encoding: ../encodings/sequential\inputter.lp
# Satisfiable
# Total time: 0.0069789886474609375 sec
# CPU time: 0.0 sec
# Grounding time: 0.0059814453125 sec
# Solving time: 0.0009975433349609375 sec
# Atoms : 597
# Rules : 597
#
# Encoding: ../encodings/sequential\retrieve_bm_metrics.lp
# Satisfiable
# Total time: 0.0049571990966796875 sec
# CPU time: 0.015625 sec
# Grounding time: 0.00395965576171875 sec
# Solving time: 0.0009975433349609375 sec
# Atoms : 452
# Rules : 452
#
# 23
# Encoding: ../encodings/sequential\inputter.lp
# Satisfiable
# Total time: 0.0149383544921875 sec
# CPU time: 0.015625 sec
# Grounding time: 0.010974884033203125 sec
# Solving time: 0.003963470458984375 sec
# Atoms : 1470
# Rules : 1470
#
# Encoding: ../encodings/sequential\retrieve_bm_metrics.lp
# Satisfiable
# Total time: 0.012966156005859375 sec
# CPU time: 0.015625 sec
# Grounding time: 0.008974075317382812 sec
# Solving time: 0.0039920806884765625 sec
# Atoms : 1426
# Rules : 1426
#
# 25
# Encoding: ../encodings/sequential\inputter.lp
# Satisfiable
# Total time: 0.02094268798828125 sec
# CPU time: 0.015625 sec
# Grounding time: 0.016954421997070312 sec
# Solving time: 0.0039882659912109375 sec
# Atoms : 2043
# Rules : 2043
#
# Encoding: ../encodings/sequential\retrieve_bm_metrics.lp
# Satisfiable
# Total time: 0.0159912109375 sec
# CPU time: 0.015625 sec
# Grounding time: 0.010969161987304688 sec
# Solving time: 0.0050220489501953125 sec
# Atoms : 1777
# Rules : 1777
#
# 26
# Encoding: ../encodings/sequential\inputter.lp
# Satisfiable
# Total time: 0.011968612670898438 sec
# CPU time: 0.015625 sec
# Grounding time: 0.009973526000976562 sec
# Solving time: 0.001995086669921875 sec
# Atoms : 1050
# Rules : 1050
#
# Encoding: ../encodings/sequential\retrieve_bm_metrics.lp
# Satisfiable
# Total time: 0.007993698120117188 sec
# CPU time: 0.015625 sec
# Grounding time: 0.0059986114501953125 sec
# Solving time: 0.001995086669921875 sec
# Atoms : 868
# Rules : 868
#
#          total  dSOAP
# BM13  1.102079   20.0
# BM14  0.746315 -353.0
# BM20  0.082775 -116.0
# BM22  1.462580  546.0
# BM23  0.246344  120.0
# BM25  1.390945 -177.0
# BM26  1.727230 -429.0
#          total  dSOAP
# BM13  0.693697   20.0
# BM14  0.717611 -349.0
# BM20  0.072796 -116.0
# BM22  0.000000 -983.0
# BM23  2.826633  120.0
# BM25  0.649776  -65.0
# BM26  1.668715 -362.0

# %%
e = pd.concat([c1,c2,d], axis=1)
e = e.iloc[0:7,:].copy()
#e.to_csv('../benchmark_data/comparison_data/{}.csv'.format('comparison'))
e
# Out:
#          total  dSOAP     total  dSOAP  n robots  n pos  longest path  n vcs  \
# BM13  1.102079   20.0  0.693697   20.0        10    341            47     82
# BM14  0.746315 -353.0  0.717611 -349.0        20    326            32     32
# BM20  0.082775 -116.0  0.072796 -116.0        20    124             7      8
# BM22  1.462580  546.0  0.000000 -983.0        32    983            36    122
# BM23  0.246344  120.0  2.826633  120.0        16    327            22     56
# BM25  1.390945 -177.0  0.649776  -65.0        30    538            26     18
# BM26  1.727230 -429.0  1.668715 -362.0        30    250            17     16
#
#       n robots had vcs  n ecs  n robots had ecs  n fake ecs  \
# BM13                 8      0                 0           0
# BM14                 6      0                 0           0
# BM20                 8      0                 0           0
# BM22                32      0                 0           0
# BM23                16      0                 0           0
# BM25                 9      0                 0           0
# BM26                11      0                 0           2
#
#       n robots had fake ecs
# BM13                      0
# BM14                      0
# BM20                      0
# BM22                      0
# BM23                      0
# BM25                      0
# BM26                      2

# %%
cb = c1.copy()
cb['total'] = c1['total'] < c2['total']
cb['dSOAP'] = c1['dSOAP'] - c2['dSOAP']
#cb.to_csv('../benchmark_data/comparison_data/{}.csv'.format('boolean_comparison'))
cb
# Out:
#       total   dSOAP
# BM13  False     0.0
# BM14  False    -4.0
# BM20  False     0.0
# BM22  False  1529.0
# BM23   True     0.0
# BM25  False  -112.0
# BM26  False   -67.0
